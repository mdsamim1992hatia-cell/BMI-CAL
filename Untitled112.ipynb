# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled112.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data_dic={
    'col_1':[1,2,3,4,5],
    'col_2':[111,222,333,111,555],
    'col_3':['a','b','c','d','e']
}
df=pd.DataFrame(data_dic)
df
# Out:
#    col_1  col_2 col_3
# 0      1    111     a
# 1      2    222     b
# 2      3    333     c
# 3      4    111     d
# 4      5    555     e

# %%
df['col_1'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(df['col_1'].nunique()),print(df['col_2'].nunique())
print(df['col_2'].unique()),print(df['col_3'].unique())
# Out:
# 5
# 4
# [111 222 333 555]
# ['a' 'b' 'c' 'd' 'e']
# (None, None)

# %%
print(df['col_1'].value_counts()),print(df['col_2'].value_counts())
# Out:
# col_1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64
# col_2
# 111    2
# 222    1
# 333    1
# 555    1
# Name: count, dtype: int64
# (None, None)

# %%
print(df['col_1'].nunique()),print(df['col_2'].nunique())
# Out:
# 5
# 4
# (None, None)

# %%
print(df['col_1'].nunique()),print(df['col_2'].nunique()),print(df['col_3'].nunique())
# Out:
# 5
# 4
# 5
# (None, None, None)

# %%
df['col_1'].count()
# Out:
# np.int64(5)

# %%
df['col_2'].count()
# Out:
# np.int64(5)

# %%
df.sort_values(by='col_2',ascending=False)
# Out:
#    col_1  col_2 col_3
# 4      5    555     e
# 2      3    333     c
# 1      2    222     b
# 0      1    111     a
# 3      4    111     d

# %%
df.sort_values(by='col_2',ascending=True)
# Out:
#    col_1  col_2 col_3
# 0      1    111     a
# 3      4    111     d
# 1      2    222     b
# 2      3    333     c
# 4      5    555     e

# %%
df.sort_values(by=['col_1','col_2'],ascending=False)
# Out:
#    col_1  col_2 col_3
# 4      5    555     e
# 3      4    111     d
# 2      3    333     c
# 1      2    222     b
# 0      1    111     a

# %%
def squer(value):
    return value*value

# %%
df
squer(2)
# Out:
# 4

# %%
df['col_1'].apply(squer)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: col_1, dtype: int64

# %%
x=lambda value:value*value
df['col_1'].apply(x)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: col_1, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
newdf=df.copy
aa=df
aa
# Out:
#    col_1  col_2 col_3
# 0      1    111     a
# 1      2    222     b
# 2      3    333     c
# 3      4    111     d
# 4      5    555     e

# %%
del aa['col_1']
aa
# Out:
#    col_2 col_3
# 0    111     a
# 1    222     b
# 2    333     c
# 3    111     d
# 4    555     e
