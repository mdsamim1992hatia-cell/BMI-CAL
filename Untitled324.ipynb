# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled324.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'order_id':[101,102,103,104,105,106,107,108],
    'customer':['samim','adib','ajij','jamil','daed','jeaj','samim','samim',],
    'product':['laptop','dekstop','light','tv','werw','tv','laptop','tv'],
    'catagories':['accesories','glosary','electric','acess','samud','glosary','glosary','samud'],
    'quantity' :[1,2,3,6,5,6,8,9],
    'price':[100,555,444,555,5566,9996,23232,25252],
    'order_date':pd.date_range('20230101',periods=8)

}
df=pd.DataFrame(data)
df
# Out:
#    order_id customer  product  catagories  quantity  price order_date
# 0       101    samim   laptop  accesories         1    100 2023-01-01
# 1       102     adib  dekstop     glosary         2    555 2023-01-02
# 2       103     ajij    light    electric         3    444 2023-01-03
# 3       104    jamil       tv       acess         6    555 2023-01-04
# 4       105     daed     werw       samud         5   5566 2023-01-05
# 5       106     jeaj       tv     glosary         6   9996 2023-01-06
# 6       107    samim   laptop     glosary         8  23232 2023-01-07
# 7       108    samim       tv       samud         9  25252 2023-01-08

# %%
df['total_sales']=df['quantity']*df['price']
df
# Out:
#    order_id customer  product  catagories  quantity  price order_date  \
# 0       101    samim   laptop  accesories         1    100 2023-01-01
# 1       102     adib  dekstop     glosary         2    555 2023-01-02
# 2       103     ajij    light    electric         3    444 2023-01-03
# 3       104    jamil       tv       acess         6    555 2023-01-04
# 4       105     daed     werw       samud         5   5566 2023-01-05
# 5       106     jeaj       tv     glosary         6   9996 2023-01-06
# 6       107    samim   laptop     glosary         8  23232 2023-01-07
# 7       108    samim       tv       samud         9  25252 2023-01-08
#
#    total_sales
# 0          100
# 1         1110
# 2         1332
# 3         3330
# 4        27830
# 5        59976
# 6       185856
# 7       227268

# %%
total_revenue=df['total_sales'].sum()
total_revenue
# Out:
# np.int64(506802)

# %%
best_product=df.groupby('product')['total_sales'].sum().idxmax()
best_product
# Out:
# 'tv'

# %%
categories_sales=df.groupby('catagories')['total_sales'].sum().sort_values(ascending=False)
categories_sales
# Out:
# catagories
# samud         255098
# glosary       246942
# acess           3330
# electric        1332
# accesories       100
# Name: total_sales, dtype: int64

# %%
customer_spending=df.groupby('customer')['total_sales'].sum().sort_values(ascending=False)
customer_spending
# Out:
# customer
# samim    413224
# jeaj      59976
# daed      27830
# jamil      3330
# ajij       1332
# adib       1110
# Name: total_sales, dtype: int64

# %%
df['order_date']=pd.to_datetime(df['order_date'])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     8 non-null      int64
#  1   customer     8 non-null      object
#  2   product      8 non-null      object
#  3   catagories   8 non-null      object
#  4   quantity     8 non-null      int64
#  5   price        8 non-null      int64
#  6   order_date   8 non-null      datetime64[ns]
#  7   total_sales  8 non-null      int64
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 644.0+ bytes
# None

# %%
daily_sales=df.groupby(df['order_date'].dt.date)['total_sales'].sum()
daily_sales
# Out:
# order_date
# 2023-01-01       100
# 2023-01-02      1110
# 2023-01-03      1332
# 2023-01-04      3330
# 2023-01-05     27830
# 2023-01-06     59976
# 2023-01-07    185856
# 2023-01-08    227268
# Name: total_sales, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.plot(daily_sales.index,daily_sales.values,marker='o',linestyle='-')
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
daily_sales.plot(kind='bar',color='blue')
plt.title('Best Selling Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# %%
from numpy.random.mtrand import f
plt.figure(figsize=(10,6))
plt.pie(categories_sales,labels=categories_sales.index,autopct='%1.1f%%',startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79197172d340>,
# ...
#  [Text(-0.6981630349916876, -0.8500402205608837, 'samud'),
#   Text(0.7229473678541293, 0.8290639922905749, 'glosary'),
#   Text(-0.8148861829173157, 0.7388914053434695, 'acess'),
#   Text(-0.8358963181188688, 0.7150366042066093, 'electric'),
#   Text(-0.8422098641738356, 0.7075892485674791, 'accesories')],
#  [Text(-0.38081620090455687, -0.4636583021241183, '50.3%'),
#   Text(0.3943349279204341, 0.45221672306758626, '48.7%'),
#   Text(-0.44448337250035397, 0.4030316756418924, '0.7%'),
#   Text(-0.4559434462466556, 0.39001996593087773, '0.3%'),
#   Text(-0.4593871986402739, 0.38595777194589764, '0.0%')])

# %%
top_customer=df.groupby('customer')['total_sales'].sum().nlargest(3)
top_customer
# Out:
# customer
# samim    413224
# jeaj      59976
# daed      27830
# Name: total_sales, dtype: int64

# %%
best_customer=df.groupby('customer')['total_sales'].sum().idxmax()
best_customer
# Out:
# 'samim'

# %%
catagories_revenue=df.groupby('catagories')['total_sales'].sum()
catagories_revenue
# Out:
# catagories
# accesories       100
# acess           3330
# electric        1332
# glosary       246942
# samud         255098
# Name: total_sales, dtype: int64

# %%
df['order_date']=pd.to_datetime(df['order_date'])
df['month']=df['order_date'].dt.month
print(df.head())
# Out:
#    order_id customer  product  catagories  quantity  price order_date  \
# 0       101    samim   laptop  accesories         1    100 2023-01-01
# 1       102     adib  dekstop     glosary         2    555 2023-01-02
# 2       103     ajij    light    electric         3    444 2023-01-03
# 3       104    jamil       tv       acess         6    555 2023-01-04
# 4       105     daed     werw       samud         5   5566 2023-01-05
#
#    total_sales  month
# 0          100      1
# 1         1110      1
# 2         1332      1
# 3         3330      1
# 4        27830      1

# %%
df['month_name']=df['order_date'].dt.month_name()
print(df.head())
# Out:
#    order_id customer  product  catagories  quantity  price order_date  \
# 0       101    samim   laptop  accesories         1    100 2023-01-01
# 1       102     adib  dekstop     glosary         2    555 2023-01-02
# 2       103     ajij    light    electric         3    444 2023-01-03
# 3       104    jamil       tv       acess         6    555 2023-01-04
# 4       105     daed     werw       samud         5   5566 2023-01-05
#
#    total_sales  month month_name
# 0          100      1    January
# 1         1110      1    January
# 2         1332      1    January
# 3         3330      1    January
# 4        27830      1    January

# %%
daily_sales=df.groupby(df['order_date'].dt.date)['total_sales'].sum()
daily_sales
# Out:
# order_date
# 2023-01-01       100
# 2023-01-02      1110
# 2023-01-03      1332
# 2023-01-04      3330
# 2023-01-05     27830
# 2023-01-06     59976
# 2023-01-07    185856
# 2023-01-08    227268
# Name: total_sales, dtype: int64

# %%
daily_sales.plot(kind='bar',color='blue')
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %%
df=df.groupby('month_name')['total_sales'].sum()
df
# Out:
# month_name
# January    506802
# Name: total_sales, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(df,labels=df.index,autopct='%1.1f%%',startangle=140)
plt.title('Monthly Sales Distribution')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index,df.values,marker='o',linestyle='-')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(df.index,df.values,color='blue')
plt.title('Monthly Sales Distribution')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()
