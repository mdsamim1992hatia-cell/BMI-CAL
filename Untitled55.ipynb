# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
climate_data={
    'day':['1/2/2025','1/3/2025','2/2/2012'],
    'temperature':[32,55,22],
    'windspeed':[11,2,3],
    'event':['Rain','Sunny','Snow'],
}
df=pd.DataFrame(climate_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/2/2025           32         11   Rain
# 1  1/3/2025           55          2  Sunny
# 2  2/2/2012           22          3   Snow

# %%
climate_data=[
    ('1/2/2025',22,55,'sunny'),
    ('1/5/2021',66,33,'cloudy'),
    ('5/12/2025',55,22,'rainy'),
]
df=pd.DataFrame(climate_data,columns=['day','temperature','windspeed','event'])
df
# Out:
#          day  temperature  windspeed   event
# 0   1/2/2025           22         55   sunny
# 1   1/5/2021           66         33  cloudy
# 2  5/12/2025           55         22   rainy

# %%
climate_data=(
    {'day':'1/2/2025','temperature':22,'windspeed':55,'event':'sunny'},
    {'day':'1/5/2021','temperature':66,'windspeed':33,'event':'cloudy'},
    {'day':'5/12/2025','temperature':55,'windspeed':22,'event':'rainy'},
    {'day':'5/12/2025','temperature':55,'windspeed':22,'event':'rainy'},
)
df=pd.DataFrame(climate_data)
df
# Out:
#          day  temperature  windspeed   event
# 0   1/2/2025           22         55   sunny
# 1   1/5/2021           66         33  cloudy
# 2  5/12/2025           55         22   rainy
# 3  5/12/2025           55         22   rainy
