# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled76.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.DataFrame({
    'city':['new york','dhaka','paris'],
    'temperature':[21,14,35],
    'humidity':[68,65,75]
})
df1
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1     dhaka           14        65
# 2     paris           35        75

# %%
df2=pd.DataFrame({
    'city':['new york','dhaka','paris'],
    'temperature':[21,14,35],
    'humidity':[68,65,75]
})
df2
# Out:
#         city  temperature  humidity
# 0  new yourk           21        68
# 1      dhaka           14        65
# 2      paris           35        75

# %%
pd.merge(df1,df2,how='inner',on='city')
# Out:
#     city  temperature_x  humidity_x  temperature_y  humidity_y
# 0  dhaka             14          65             14          65
# 1  paris             35          75             35          75

# %%
df1=pd.DataFrame({
    'key':['k','l','m'],
    'c1':[2,0,1],
    'c2':[3,0,5]})
df1
# Out:
#   key  c1  c2
# 0   k   2   3
# 1   l   0   0
# 2   m   1   5

# %%
df2=pd.DataFrame({
    'key':['k','l','m'],
    'd1':[5,6,9],
    'd2':[1,3,5]
})
df2
# Out:
#   key  d1  d2
# 0   k   5   1
# 1   l   6   3
# 2   m   9   5

# %%
pd.merge(df1,df2,how='inner',on='key')[['key','c1','d1']]
# Out:
#   key  c1  d1
# 0   k   2   5
# 1   l   0   6
# 2   m   1   9
