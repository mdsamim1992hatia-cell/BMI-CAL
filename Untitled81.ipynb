# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data={
    'a':[10,20,30,np.nan,np.nan],
    'b':[np.nan,np.nan,np.nan,np.nan,np.nan],
    'c':[10,20,30,40,np.nan],
    'd':[50,50,np.nan,np.nan,np.nan],
}
df=pd.DataFrame(data)
df
# Out:
#       a   b     c     d
# 0  10.0 NaN  10.0  50.0
# 1  20.0 NaN  20.0  50.0
# 2  30.0 NaN  30.0   NaN
# 3   NaN NaN  40.0   NaN
# 4   NaN NaN   NaN   NaN

# %%
df.isnull()
# Out:
#        a     b      c      d
# 0  False  True  False  False
# 1  False  True  False  False
# 2  False  True  False   True
# 3   True  True  False   True
# 4   True  True   True   True

# %%
df.isnull().sum()
# Out:
# a    2
# b    5
# c    1
# d    3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(11)

# %%
df['a'].isnull().sum()
# Out:
# np.int64(2)

# %%
df['b'].isnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: b, dtype: bool

# %%
df.notnull()
# Out:
#        a      b      c      d
# 0   True  False   True   True
# 1   True  False   True   True
# 2   True  False   True  False
# 3  False  False   True  False
# 4  False  False  False  False

# %%
df.notna().sum()
# Out:
# a    3
# b    0
# c    4
# d    2
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(9)

# %%
df['c'].sum()
# Out:
# np.float64(100.0)

# %%
df['c'].mean()
# Out:
# np.float64(25.0)

# %%
df.loc[2].sum()
# Out:
# np.float64(60.0)

# %%
df.isnull().sum()
# Out:
# a    2
# b    5
# c    1
# d    3
# dtype: int64

# %%
df['d'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: d, dtype: bool

# %%
df.loc[2].mean()
# Out:
# np.float64(30.0)

# %%
df.loc[2].mean().sum()
# Out:
# np.float64(30.0)

# %%
df=pd.DataFrame(data)
df
# Out:
#       a   b     c     d
# 0  10.0 NaN  10.0  50.0
# 1  20.0 NaN  20.0  50.0
# 2  30.0 NaN  30.0   NaN
# 3   NaN NaN  40.0   NaN
# 4   NaN NaN   NaN   NaN

# %%
df_fill=df.fillna(0)
df_fill
# Out:
#       a    b     c     d
# 0  10.0  0.0  10.0  50.0
# 1  20.0  0.0  20.0  50.0
# 2  30.0  0.0  30.0   0.0
# 3   0.0  0.0  40.0   0.0
# 4   0.0  0.0   0.0   0.0

# %%
df_bfill=df.fillna(method='bfill')
df_bfill
# Out:
# /tmp/ipython-input-4020059411.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill=df.fillna(method='bfill')
#       a   b     c     d
# 0  10.0 NaN  10.0  50.0
# 1  20.0 NaN  20.0  50.0
# 2  30.0 NaN  30.0   NaN
# 3   NaN NaN  40.0   NaN
# 4   NaN NaN   NaN   NaN

# %%
df_zero=df.fillna(0)
df_zero
# Out:
#       a    b     c     d
# 0  10.0  0.0  10.0  50.0
# 1  20.0  0.0  20.0  50.0
# 2  30.0  0.0  30.0   0.0
# 3   0.0  0.0  40.0   0.0
# 4   0.0  0.0   0.0   0.0

# %%
df.iloc[2]
# Out:
# a    30.0
# b     NaN
# c    30.0
# d     NaN
# Name: 2, dtype: float64
