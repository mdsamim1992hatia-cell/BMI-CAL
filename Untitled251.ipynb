# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled251.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.DataFrame({
    'key':['a','b','c','d','e','a','v'],
    'a1':range(1,8),
    'b1':range(8,15)
})
df1
# Out:
#   key  a1  b1
# 0   a   1   8
# 1   b   2   9
# 2   c   3  10
# 3   d   4  11
# 4   e   5  12
# 5   a   6  13
# 6   v   7  14

# %%
df2=pd.DataFrame({
    'key':['a','b','c'],
    'a2':range(3),
    'b2':range(3,6)
})
df2
# Out:
#   key  a2  b2
# 0   a   0   3
# 1   b   1   4
# 2   c   2   5

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  a1  b1  a2  b2
# 0   a   1   8   0   3
# 1   b   2   9   1   4
# 2   c   3  10   2   5
# 3   a   6  13   0   3

# %%
pd.merge(df1,df2,on='key',how='outer')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   a   6  0.0
# 2   b   2  1.0
# 3   c   3  2.0
# 4   d   4  NaN
# 5   e   5  NaN
# 6   v   7  NaN

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  a1  b1   a2   b2
# 0   a   1   8  0.0  3.0
# 1   b   2   9  1.0  4.0
# 2   c   3  10  2.0  5.0
# 3   d   4  11  NaN  NaN
# 4   e   5  12  NaN  NaN
# 5   a   6  13  0.0  3.0
# 6   v   7  14  NaN  NaN

# %%
pd.merge(df1,df2,on='key',how='left')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   b   2  1.0
# 2   c   3  2.0
# 3   d   4  NaN
# 4   e   5  NaN
# 5   a   6  0.0
# 6   v   7  NaN

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  a1  b1  a2  b2
# 0   a   1   8   0   3
# 1   a   6  13   0   3
# 2   b   2   9   1   4
# 3   c   3  10   2   5

# %%
pd.merge(df1,df2,on='key',how='right')[['key','a1','a2']]
# Out:
#   key  a1  a2
# 0   a   1   0
# 1   a   6   0
# 2   b   2   1
# 3   c   3   2

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key  a1  b1   a2   b2
# 0   a   1   8  0.0  3.0
# 1   a   6  13  0.0  3.0
# 2   b   2   9  1.0  4.0
# 3   c   3  10  2.0  5.0
# 4   d   4  11  NaN  NaN
# 5   e   5  12  NaN  NaN
# 6   v   7  14  NaN  NaN

# %%
pd.merge(df1,df2,on='key',how='outer')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   a   6  0.0
# 2   b   2  1.0
# 3   c   3  2.0
# 4   d   4  NaN
# 5   e   5  NaN
# 6   v   7  NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.DataFrame({
    'key':['a','b','c','d','e','a','v'],
    'a1':range(1,8),
    'b1':range(8,15)
})
df1
# Out:
#   key  a1  b1
# 0   a   1   8
# 1   b   2   9
# 2   c   3  10
# 3   d   4  11
# 4   e   5  12
# 5   a   6  13
# 6   v   7  14

# %%
df2=pd.DataFrame({
    'key':['a','b','c'],
    'a2':range(3),
    'b2':range(3,6)
})
df2
# Out:
#   key  a2  b2
# 0   a   0   3
# 1   b   1   4
# 2   c   2   5

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  a1  b1  a2  b2
# 0   a   1   8   0   3
# 1   b   2   9   1   4
# 2   c   3  10   2   5
# 3   a   6  13   0   3

# %%
pd.merge(df1,df2,on='key',how='outer')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   a   6  0.0
# 2   b   2  1.0
# 3   c   3  2.0
# 4   d   4  NaN
# 5   e   5  NaN
# 6   v   7  NaN

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  a1  b1   a2   b2
# 0   a   1   8  0.0  3.0
# 1   b   2   9  1.0  4.0
# 2   c   3  10  2.0  5.0
# 3   d   4  11  NaN  NaN
# 4   e   5  12  NaN  NaN
# 5   a   6  13  0.0  3.0
# 6   v   7  14  NaN  NaN

# %%
pd.merge(df1,df2,on='key',how='left')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   b   2  1.0
# 2   c   3  2.0
# 3   d   4  NaN
# 4   e   5  NaN
# 5   a   6  0.0
# 6   v   7  NaN

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  a1  b1  a2  b2
# 0   a   1   8   0   3
# 1   a   6  13   0   3
# 2   b   2   9   1   4
# 3   c   3  10   2   5

# %%
pd.merge(df1,df2,on='key',how='right')[['key','a1','a2']]
# Out:
#   key  a1  a2
# 0   a   1   0
# 1   a   6   0
# 2   b   2   1
# 3   c   3   2

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key  a1  b1   a2   b2
# 0   a   1   8  0.0  3.0
# 1   a   6  13  0.0  3.0
# 2   b   2   9  1.0  4.0
# 3   c   3  10  2.0  5.0
# 4   d   4  11  NaN  NaN
# 5   e   5  12  NaN  NaN
# 6   v   7  14  NaN  NaN

# %%
pd.merge(df1,df2,on='key',how='outer')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   a   6  0.0
# 2   b   2  1.0
# 3   c   3  2.0
# 4   d   4  NaN
# 5   e   5  NaN
# 6   v   7  NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.DataFrame({
    'key':['a','b','c','d','e','a','v'],
    'a1':range(1,8),
    'b1':range(8,15)
})
df1
# Out:
#   key  a1  b1
# 0   a   1   8
# 1   b   2   9
# 2   c   3  10
# 3   d   4  11
# 4   e   5  12
# 5   a   6  13
# 6   v   7  14

# %%
df2=pd.DataFrame({
    'key':['a','b','c'],
    'a2':range(3),
    'b2':range(3,6)
})
df2
# Out:
#   key  a2  b2
# 0   a   0   3
# 1   b   1   4
# 2   c   2   5

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  a1  b1  a2  b2
# 0   a   1   8   0   3
# 1   b   2   9   1   4
# 2   c   3  10   2   5
# 3   a   6  13   0   3

# %%
pd.merge(df1,df2,on='key',how='outer')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   a   6  0.0
# 2   b   2  1.0
# 3   c   3  2.0
# 4   d   4  NaN
# 5   e   5  NaN
# 6   v   7  NaN

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  a1  b1   a2   b2
# 0   a   1   8  0.0  3.0
# 1   b   2   9  1.0  4.0
# 2   c   3  10  2.0  5.0
# 3   d   4  11  NaN  NaN
# 4   e   5  12  NaN  NaN
# 5   a   6  13  0.0  3.0
# 6   v   7  14  NaN  NaN

# %%
pd.merge(df1,df2,on='key',how='left')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   b   2  1.0
# 2   c   3  2.0
# 3   d   4  NaN
# 4   e   5  NaN
# 5   a   6  0.0
# 6   v   7  NaN

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  a1  b1  a2  b2
# 0   a   1   8   0   3
# 1   a   6  13   0   3
# 2   b   2   9   1   4
# 3   c   3  10   2   5

# %%
pd.merge(df1,df2,on='key',how='right')[['key','a1','a2']]
# Out:
#   key  a1  a2
# 0   a   1   0
# 1   a   6   0
# 2   b   2   1
# 3   c   3   2

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key  a1  b1   a2   b2
# 0   a   1   8  0.0  3.0
# 1   a   6  13  0.0  3.0
# 2   b   2   9  1.0  4.0
# 3   c   3  10  2.0  5.0
# 4   d   4  11  NaN  NaN
# 5   e   5  12  NaN  NaN
# 6   v   7  14  NaN  NaN

# %%
pd.merge(df1,df2,on='key',how='outer')[['key','a1','a2']]
# Out:
#   key  a1   a2
# 0   a   1  0.0
# 1   a   6  0.0
# 2   b   2  1.0
# 3   c   3  2.0
# 4   d   4  NaN
# 5   e   5  NaN
# 6   v   7  NaN

# %%
df3=pd.DataFrame({
    'key':['x','y','z','a','d'],
    'a3':range(5),
    'b3':range(5,10)
})
df3
# Out:
#   key  a3  b3
# 0   x   0   5
# 1   y   1   6
# 2   z   2   7
# 3   a   3   8
# 4   d   4   9

# %%
df4=pd.DataFrame({
    'key':['x','y','z'],
    'a4':range(3),
    'b4':range(3,6)
})
df4
# Out:
#   key  a4  b4
# 0   x   0   3
# 1   y   1   4
# 2   z   2   5

# %%
pd.merge(df3,df4,on='key',how='inner')
# Out:
#   key  a3  b3  a4  b4
# 0   x   0   5   0   3
# 1   y   1   6   1   4
# 2   z   2   7   2   5

# %%
pd.merge(df3,df4,on='key',how='outer')[['key','a3','a4']]
# Out:
#   key  a3   a4
# 0   a   3  NaN
# 1   d   4  NaN
# 2   x   0  0.0
# 3   y   1  1.0
# 4   z   2  2.0

# %%
pd.merge(df3,df4,on='key',how='left')
# Out:
#   key  a3  b3   a4   b4
# 0   x   0   5  0.0  3.0
# 1   y   1   6  1.0  4.0
# 2   z   2   7  2.0  5.0
# 3   a   3   8  NaN  NaN
# 4   d   4   9  NaN  NaN

# %%
pd.merge(df3,df4,on='key',how='left')[['key','a3','a4']]
# Out:
#   key  a3   a4
# 0   x   0  0.0
# 1   y   1  1.0
# 2   z   2  2.0
# 3   a   3  NaN
# 4   d   4  NaN

# %%
pd.merge(df3,df4,on='key',how='right')
# Out:
#   key  a3  b3  a4  b4
# 0   x   0   5   0   3
# 1   y   1   6   1   4
# 2   z   2   7   2   5

# %%
pd.merge(df3,df4,on='key',how='right')[['key','a3','a4']]
# Out:
#   key  a3  a4
# 0   x   0   0
# 1   y   1   1
# 2   z   2   2

# %%
pd.merge(df3,df4,on='key',how='outer')
# Out:
#   key  a3  b3   a4   b4
# 0   a   3   8  NaN  NaN
# 1   d   4   9  NaN  NaN
# 2   x   0   5  0.0  3.0
# 3   y   1   6  1.0  4.0
# 4   z   2   7  2.0  5.0

# %%
result=pd.merge(df3,df4,on='key',how='outer')[['key','a3','a4']]
result
# Out:
#   key  a3   a4
# 0   a   3  NaN
# 1   d   4  NaN
# 2   x   0  0.0
# 3   y   1  1.0
# 4   z   2  2.0
