# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled118.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dic={
    'a':[1,2,None,4,np.nan],
    'b':[np.nan,np.nan,np.nan,np.nan,5],
    'c':[1,np.nan,3,4,5],
    'd':[1,2,np.nan,4,5]
}
df=pd.DataFrame(data_dic)
df
# Out:
#      a    b    c    d
# 0  1.0  NaN  1.0  1.0
# 1  2.0  NaN  NaN  2.0
# 2  NaN  NaN  3.0  NaN
# 3  4.0  NaN  4.0  4.0
# 4  NaN  5.0  5.0  5.0

# %%
df['a'].fillna(value=2)
# Out:
# 0    1.0
# 1    2.0
# 2    2.0
# 3    4.0
# 4    2.0
# Name: a, dtype: float64

# %%
df['b'].fillna(value=df['b'].mean())
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: b, dtype: float64

# %%
df['c'].fillna(value=df['c'].mean())
# Out:
# 0    1.00
# 1    3.25
# 2    3.00
# 3    4.00
# 4    5.00
# Name: c, dtype: float64

# %%
df.fillna(method='ffill')
# Out:
# /tmp/ipython-input-1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#      a    b    c    d
# 0  1.0  NaN  1.0  1.0
# 1  2.0  NaN  1.0  2.0
# 2  2.0  NaN  3.0  2.0
# 3  4.0  NaN  4.0  4.0
# 4  4.0  5.0  5.0  5.0

# %%
df.fillna(method='bfill')
# Out:
# /tmp/ipython-input-2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#      a    b    c    d
# 0  1.0  5.0  1.0  1.0
# 1  2.0  5.0  3.0  2.0
# 2  4.0  5.0  3.0  4.0
# 3  4.0  5.0  4.0  4.0
# 4  NaN  5.0  5.0  5.0

# %%
df.fillna(method='ffill',axis=0)
# Out:
# /tmp/ipython-input-2614524743.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',axis=0)
#      a    b    c    d
# 0  1.0  NaN  1.0  1.0
# 1  2.0  NaN  1.0  2.0
# 2  2.0  NaN  3.0  2.0
# 3  4.0  NaN  4.0  4.0
# 4  4.0  5.0  5.0  5.0

# %%
df=pd.DataFrame(data_dic)
df
# Out:
#      a    b    c    d
# 0  1.0  NaN  1.0  1.0
# 1  2.0  NaN  NaN  2.0
# 2  NaN  NaN  3.0  NaN
# 3  4.0  NaN  4.0  4.0
# 4  NaN  5.0  5.0  5.0

# %%
df['a'].unique()
# Out:
# array([ 1.,  2., nan,  4.])

# %%
print(df['a'].unique())
# Out:
# [ 1.  2. nan  4.]

# %%
print(df['a'].unique())
print(df['b'].unique())
print(df['c'].unique())
print(df['d'].unique())
# Out:
# [ 1.  2. nan  4.]
# [nan  5.]
# [ 1. nan  3.  4.  5.]
# [ 1.  2. nan  4.  5.]

# %%
print(df['a'].nunique())
print(df['b'].nunique())
print(df['c'].nunique())
print(df['d'].nunique())
# Out:
# 3
# 1
# 4
# 4

# %%
df['a'].value_counts()
# Out:
# a
# 1.0    1
# 2.0    1
# 4.0    1
# Name: count, dtype: int64

# %%
df['d'].value_counts()
# Out:
# d
# 1.0    1
# 2.0    1
# 4.0    1
# 5.0    1
# Name: count, dtype: int64

# %%
df['c'].count()
# Out:
# np.int64(4)

# %%
df.sort_values(by='d',ascending=False)
# Out:
#      a    b    c    d
# 4  NaN  5.0  5.0  5.0
# 3  4.0  NaN  4.0  4.0
# 1  2.0  NaN  NaN  2.0
# 0  1.0  NaN  1.0  1.0
# 2  NaN  NaN  3.0  NaN

# %%
def square(value):
    return value*value

# %%
square(2)
# Out:
# 4

# %%
df['d'].apply(square)
# Out:
# 0     1.0
# 1     4.0
# 2     NaN
# 3    16.0
# 4    25.0
# Name: d, dtype: float64

# %%
df['c'].apply(square)
# Out:
# 0     1.0
# 1     NaN
# 2     9.0
# 3    16.0
# 4    25.0
# Name: c, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
newdf=df.drop('a',axis=1)
newdf
# Out:
#      b    c    d
# 0  NaN  1.0  1.0
# 1  NaN  NaN  2.0
# 2  NaN  3.0  NaN
# 3  NaN  4.0  4.0
# 4  5.0  5.0  5.0

# %%
df=pd.DataFrame(data_dic)
df
# Out:
#      a    b    c    d
# 0  1.0  NaN  1.0  1.0
# 1  2.0  NaN  NaN  2.0
# 2  NaN  NaN  3.0  NaN
# 3  4.0  NaN  4.0  4.0
# 4  NaN  5.0  5.0  5.0
