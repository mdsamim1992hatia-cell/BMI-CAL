# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled79.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dic={
    'A':[1,2,np.nan,3,4],
    'B':[5,np.nan,np.nan,np.nan,6],
    'C':[7,8,9,10,11],
    'D':[12,13,np.nan,15,16],
}
df=pd.DataFrame(data_dic)
df
# Out:
#      A    B   C     D
# 0  1.0  5.0   7  12.0
# 1  2.0  NaN   8  13.0
# 2  NaN  NaN   9   NaN
# 3  3.0  NaN  10  15.0
# 4  4.0  6.0  11  16.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       2 non-null      float64
#  2   C       5 non-null      int64
#  3   D       4 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#               A         B          C          D
# count  4.000000  2.000000   5.000000   4.000000
# mean   2.500000  5.500000   9.000000  14.000000
# std    1.290994  0.707107   1.581139   1.825742
# min    1.000000  5.000000   7.000000  12.000000
# 25%    1.750000  5.250000   8.000000  12.750000
# 50%    2.500000  5.500000   9.000000  14.000000
# 75%    3.250000  5.750000  10.000000  15.250000
# max    4.000000  6.000000  11.000000  16.000000

# %%
df.isnull()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False   True  False  False
# 2   True   True  False   True
# 3  False   True  False  False
# 4  False  False  False  False

# %%
df.isnull().sum()
# Out:
# A    1
# B    3
# C    0
# D    1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(5)

# %%
df['A'].isnull().sum()
# Out:
# np.int64(1)

# %%
df.notnull().sum()
# Out:
# A    4
# B    2
# C    5
# D    4
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(15)

# %%
df['A'].sum()
# Out:
# np.float64(10.0)

# %%
df['B'].mean()
# Out:
# np.float64(5.5)

# %%
df['B'].mean().sum().round(2)
# Out:
# np.float64(5.5)

# %%
df.loc[2].sum()
# Out:
# np.float64(9.0)

# %%
import pandas as pd
import numpy as np

# %%
data={
    'a':[21,22,23,np.nan,np.nan],
    'b':[np.nan,25,26,27,28],
    'c':[np.nan,np.nan,29,30,31],
    'd':[32,33,34,35,36],
}
df=pd.DataFrame(data)
df
# Out:
#       a     b     c   d
# 0  21.0   NaN   NaN  32
# 1  22.0  25.0   NaN  33
# 2  23.0  26.0  29.0  34
# 3   NaN  27.0  30.0  35
# 4   NaN  28.0  31.0  36

# %%
df['b'].isnull().sum()
# Out:
# np.int64(1)

# %%
df.notnull().sum().sum()
# Out:
# np.int64(15)

# %%
df.loc[2].mean()
# Out:
# np.float64(28.0)

# %%
df.isnull().sum()
# Out:
# a    2
# b    1
# c    2
# d    0
# dtype: int64

# %%
df['b'].mean()
# Out:
# np.float64(26.5)
