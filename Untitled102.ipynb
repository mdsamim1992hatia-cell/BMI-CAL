# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data_dic={
    'a':[10,20,None,40,np.nan],
    'b':[None,None,None,None,None],
    'c':[100,200,300,400,500],
    'd':[1000,2000,3000,4000,None]

}
df=pd.DataFrame(data_dic)
df
# Out:
#       a     b    c       d
# 0  10.0  None  100  1000.0
# 1  20.0  None  200  2000.0
# 2   NaN  None  300  3000.0
# 3  40.0  None  400  4000.0
# 4   NaN  None  500     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      float64
#  1   b       0 non-null      object
#  2   c       5 non-null      int64
#  3   d       4 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#                a           c            d
# count   3.000000    5.000000     4.000000
# mean   23.333333  300.000000  2500.000000
# std    15.275252  158.113883  1290.994449
# min    10.000000  100.000000  1000.000000
# 25%    15.000000  200.000000  1750.000000
# 50%    20.000000  300.000000  2500.000000
# 75%    30.000000  400.000000  3250.000000
# max    40.000000  500.000000  4000.000000

# %%
df.head()
# Out:
#       a     b    c       d
# 0  10.0  None  100  1000.0
# 1  20.0  None  200  2000.0
# 2   NaN  None  300  3000.0
# 3  40.0  None  400  4000.0
# 4   NaN  None  500     NaN

# %%
df.tail()
# Out:
#       a     b    c       d
# 0  10.0  None  100  1000.0
# 1  20.0  None  200  2000.0
# 2   NaN  None  300  3000.0
# 3  40.0  None  400  4000.0
# 4   NaN  None  500     NaN

# %%
df.notnull()
# Out:
#        a      b     c      d
# 0   True  False  True   True
# 1   True  False  True   True
# 2  False  False  True   True
# 3   True  False  True   True
# 4  False  False  True  False

# %%
df.notnull().sum()
# Out:
# a    3
# b    0
# c    5
# d    4
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(12)

# %%
df.isna()
# Out:
#        a     b      c      d
# 0  False  True  False  False
# 1  False  True  False  False
# 2   True  True  False  False
# 3  False  True  False  False
# 4   True  True  False   True

# %%
df.isna().sum()
# Out:
# a    2
# b    5
# c    0
# d    1
# dtype: int64

# %%
df.loc[[1]]
# Out:
#       a     b    c       d
# 1  20.0  None  200  2000.0

# %%
df.iloc[[2]]
# Out:
#     a     b    c       d
# 2 NaN  None  300  3000.0

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [a, b, c, d]
# Index: []

# %%
df=pd.DataFrame(data_dic)
df
# Out:
#       a     b    c       d
# 0  10.0  None  100  1000.0
# 1  20.0  None  200  2000.0
# 2   NaN  None  300  3000.0
# 3  40.0  None  400  4000.0
# 4   NaN  None  500     NaN

# %%
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [a, b, c, d]
# Index: []

# %%
df.dropna(axis=1)
# Out:
#      c
# 0  100
# 1  200
# 2  300
# 3  400
# 4  500

# %%
df.dropna(axis=1,thresh=4)
# Out:
#      c       d
# 0  100  1000.0
# 1  200  2000.0
# 2  300  3000.0
# 3  400  4000.0
# 4  500     NaN

# %%
df.dropna(axis=0,thresh=3)
# Out:
#       a     b    c       d
# 0  10.0  None  100  1000.0
# 1  20.0  None  200  2000.0
# 3  40.0  None  400  4000.0

# %%
df.fillna(value=10)
# Out:
# /tmp/ipython-input-3688939399.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(value=10)
#       a   b    c       d
# 0  10.0  10  100  1000.0
# 1  20.0  10  200  2000.0
# 2  10.0  10  300  3000.0
# 3  40.0  10  400  4000.0
# 4  10.0  10  500    10.0

# %%
df['a'].fillna(value=df['a'].mean())
# Out:
# 0    10.000000
# 1    20.000000
# 2    23.333333
# 3    40.000000
# 4    23.333333
# Name: a, dtype: float64

# %%
df.fillna(method='ffill')
# Out:
# /tmp/ipython-input-1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#       a     b    c       d
# 0  10.0  None  100  1000.0
# 1  20.0  None  200  2000.0
# 2  20.0  None  300  3000.0
# 3  40.0  None  400  4000.0
# 4  40.0  None  500  4000.0

# %%
df.fillna(method='bfill')
# Out:
# /tmp/ipython-input-2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#       a     b    c       d
# 0  10.0  None  100  1000.0
# 1  20.0  None  200  2000.0
# 2  40.0  None  300  3000.0
# 3  40.0  None  400  4000.0
# 4   NaN  None  500     NaN
