# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
a=20

# %%
b=50
c=40
sum=a+b+c
print(sum)
# Out:
# 110

# %%
sub=a-b-c
print(sub)
# Out:
# -70

# %%
multiplication=a*b*c
print(multiplication)
# Out:
# 40000

# %%
division=a/b/c
print(division)
# Out:
# 0.01

# %%
complex_num=10+10j
print(complex_num)
# Out:
# (10+10j)

# %%
student_num=7447
print(student_num)
# Out:
# 7447

# %%
lao_tree=4454
print(lao_tree)
# Out:
# 4454

# %%
age=410
print(age)
# Out:
# 410

# %%
marks=55.5
print(marks)
# Out:
# 55.5

# %%
name="md samimul islam"
print(name)
# Out:
# md samimul islam

# %%
cities=["dhaka","khulna","rajsahi","noakhali"]
print(cities)
# Out:
# ['dhaka', 'khulna', 'rajsahi', 'noakhali']

# %%
print(cities[0])
print(cities[1])
print(cities[2])
print(cities[3])
# Out:
# dhaka
# khulna
# rajsahi
# noakhali

# %%
fruits=["apple","banana","mango","orange"]
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[3])
# Out:
# apple
# banana
# mango
# orange

# %%
number=range(1,10)
print(number)
# Out:
# range(1, 10)

# %%
print(*number)
# Out:
# 1 2 3 4 5 6 7 8 9

# %%
latter=("a","b","c","d","e")
print(latter)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
print(*latter)
# Out:
# a b c d e

# %%
print(latter[0])
print(latter[1])
print(latter[2])
print(latter[3])
print(latter[4])
# Out:
# a
# b
# c
# d
# e

# %%
isbangaladesi=True
print(isbangaladesi)
# Out:
# True

# %%
havemone=None
print(havemone)
# Out:
# None
