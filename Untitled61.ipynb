# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled61.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    "a":[54,54,np.nan,69,np.nan],
    "b":[np.nan,np.nan,np.nan,np.nan,np.nan],
    "c":[12,np.nan,45,np.nan,np.nan],
    "d":[12,12,12,12,12]

}
df=pd.DataFrame(data)
df
# Out:
#       a   b     c   d
# 0  54.0 NaN  12.0  12
# 1  54.0 NaN   NaN  12
# 2   NaN NaN  45.0  12
# 3  69.0 NaN   NaN  12
# 4   NaN NaN   NaN  12

# %%
df['new']='a'
df
# Out:
#       a   b     c   d new
# 0  54.0 NaN  12.0  12   a
# 1  54.0 NaN   NaN  12   a
# 2   NaN NaN  45.0  12   a
# 3  69.0 NaN   NaN  12   a
# 4   NaN NaN   NaN  12   a

# %%
df['new_3']='b'
df
# Out:
#       a   b     c   d new new_3
# 0  54.0 NaN  12.0  12   a     b
# 1  54.0 NaN   NaN  12   a     b
# 2   NaN NaN  45.0  12   a     b
# 3  69.0 NaN   NaN  12   a     b
# 4   NaN NaN   NaN  12   a     b

# %%
df_ffill=df.fillna(method='ffill')
df_ffill
# Out:
# /tmp/ipython-input-2958970242.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill=df.fillna(method='ffill')
#       a   b     c   d new new_3
# 0  54.0 NaN  12.0  12   a     b
# 1  54.0 NaN  12.0  12   a     b
# 2  54.0 NaN  45.0  12   a     b
# 3  69.0 NaN  45.0  12   a     b
# 4  69.0 NaN  45.0  12   a     b

# %%
df_bfill=df.fillna(method='bfill')
df_bfill
# Out:
# /tmp/ipython-input-4020059411.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill=df.fillna(method='bfill')
#       a   b     c   d new new_3
# 0  54.0 NaN  12.0  12   a     b
# 1  54.0 NaN  45.0  12   a     b
# 2  69.0 NaN  45.0  12   a     b
# 3  69.0 NaN   NaN  12   a     b
# 4   NaN NaN   NaN  12   a     b

# %%
df_zero=df.fillna(0)
df_zero
# Out:
#       a    b     c   d new new_3
# 0  54.0  0.0  12.0  12   a     b
# 1  54.0  0.0   0.0  12   a     b
# 2   0.0  0.0  45.0  12   a     b
# 3  69.0  0.0   0.0  12   a     b
# 4   0.0  0.0   0.0  12   a     b

# %%
df_ffill=df.fillna(method='ffill',axis=1)
df_ffill
# Out:
# /tmp/ipython-input-1187291773.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill=df.fillna(method='ffill',axis=1)
#       a     b     c   d new new_3
# 0  54.0  54.0  12.0  12   a     b
# 1  54.0  54.0  54.0  12   a     b
# 2   NaN   NaN  45.0  12   a     b
# 3  69.0  69.0  69.0  12   a     b
# 4   NaN   NaN   NaN  12   a     b

# %%
df_bfill=df.fillna(method='bfill',axis=1)
df_bfill
# Out:
# /tmp/ipython-input-3441360825.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill=df.fillna(method='bfill',axis=1)
#       a     b     c   d new new_3
# 0  54.0  12.0  12.0  12   a     b
# 1  54.0    12    12  12   a     b
# 2  45.0  45.0  45.0  12   a     b
# 3  69.0    12    12  12   a     b
# 4    12    12    12  12   a     b

# %%
df_zero=df.fillna(0,axis=1)
df_zero
# Out:
#       a  b     c   d new new_3
# 0  54.0  0  12.0  12   a     b
# 1  54.0  0     0  12   a     b
# 2     0  0  45.0  12   a     b
# 3  69.0  0     0  12   a     b
# 4     0  0     0  12   a     b
