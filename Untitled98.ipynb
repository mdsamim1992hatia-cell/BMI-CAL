# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %%
a=10
b=20
c=30
sum=a+b+c
print(sum)
# Out:
# 60

# %%
sub=a-b-c
sub
# Out:
# -40

# %%
multi=a*b*c
multi
# Out:
# 6000

# %%
complex_num=10+10j
complex_num
# Out:
# (10+10j)

# %%
cities=['dhaka','khulna','rajsahi',]
cities
# Out:
# ['dhaka', 'khulna', 'rajsahi']

# %%
cities[1]
# Out:
# 'khulna'

# %%
number=[1,2,3,5,55,55,55,5]
number
# Out:
# [1, 2, 3, 5, 55, 55, 55, 5]

# %%
number[3]
# Out:
# 5

# %%
isbangladeshi=True
isbangladeshi
# Out:
# True

# %%
taka_ase=None
taka_ase
