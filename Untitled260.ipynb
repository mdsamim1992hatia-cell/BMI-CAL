# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled260.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'order':range(1,10001),
    'price':np.random.randint(10,100,10000),
    'product':np.random.choice(['APPLE','BANANA','CALLM',None,None],10000),
    'customer':np.random.choice(['can','alex',None,None],10000),
    'quantity':np.random.randint(1,10,10000),

}
df=pd.DataFrame(data)
print("====raw data====")
print(df)
# Out:
# ====raw data====
#       order  price product customer  quantity
# 0         1     11    None     None         6
# 1         2     79   CALLM      can         7
# 2         3     45    None     None         5
# 3         4     61   APPLE      can         4
# 4         5     10    None     alex         7
# ...     ...    ...     ...      ...       ...
# 9995   9996     66    None     None         7
# 9996   9997     83   CALLM     None         5
# 9997   9998     30   CALLM      can         4
# 9998   9999     48   CALLM      can         9
# 9999  10000     62   CALLM      can         5
#
# [10000 rows x 5 columns]

# %%
df.shape
# Out:
# (10000, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order     10000 non-null  int64
#  1   price     10000 non-null  int64
#  2   product   6022 non-null   object
#  3   customer  5007 non-null   object
#  4   quantity  10000 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 390.8+ KB

# %%
df.describe()
# Out:
#              order        price      quantity
# count  10000.00000  10000.00000  10000.000000
# mean    5000.50000     54.89920      4.990700
# std     2886.89568     26.04363      2.563878
# min        1.00000     10.00000      1.000000
# 25%     2500.75000     32.00000      3.000000
# 50%     5000.50000     55.00000      5.000000
# 75%     7500.25000     78.00000      7.000000
# max    10000.00000     99.00000      9.000000

# %%
df.dtypes
# Out:
# order        int64
# price        int64
# product     object
# customer    object
# quantity     int64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df['customer']
# Out:
# 0       None
# 1        can
# 2       None
# 3        can
# 4       alex
#         ...
# 9995    None
# 9996    None
# 9997     can
# 9998     can
# 9999     can
# Name: customer, Length: 10000, dtype: object

# %%
df[['price','quantity']]
# Out:
#       price  quantity
# 0        11         6
# 1        79         7
# 2        45         5
# 3        61         4
# 4        10         7
# ...     ...       ...
# 9995     66         7
# 9996     83         5
# 9997     30         4
# 9998     48         9
# 9999     62         5
#
# [10000 rows x 2 columns]

# %%
df.iloc[2]
# Out:
# order          3
# price         45
# product     None
# customer    None
# quantity       5
# Name: 2, dtype: object

# %%
df.iloc[1111:1115]
# Out:
#       order  price product customer  quantity
# 1111   1112     11  BANANA     alex         8
# 1112   1113     22   APPLE      can         8
# 1113   1114     97   APPLE     None         8
# 1114   1115     24    None      can         2

# %%
df.iloc[0:11]
# Out:
#     order  price product customer  quantity
# 0       1     11    None     None         6
# 1       2     79   CALLM      can         7
# 2       3     45    None     None         5
# 3       4     61   APPLE      can         4
# 4       5     10    None     alex         7
# 5       6     40    None     None         6
# 6       7     88    None     alex         3
# 7       8     74    None     alex         8
# 8       9     95   CALLM      can         8
# 9      10     96  BANANA     None         8
# 10     11     45   APPLE      can         4

# %%
df.sort_values(by='price',ascending=False)
# Out:
#       order  price product customer  quantity
# 2523   2524     99  BANANA      can         8
# 2616   2617     99    None     alex         4
# 2492   2493     99   CALLM     None         8
# 2751   2752     99    None     alex         8
# 2779   2780     99  BANANA     None         8
# ...     ...    ...     ...      ...       ...
# 4494   4495     10   APPLE      can         6
# 1465   1466     10    None     alex         6
# 255     256     10  BANANA     alex         5
# 9950   9951     10    None     alex         3
# 4         5     10    None     alex         7
#
# [10000 rows x 5 columns]

# %%
df.isna()
# Out:
#       order  price  product  customer  quantity
# 0     False  False     True      True     False
# 1     False  False    False     False     False
# 2     False  False     True      True     False
# 3     False  False    False     False     False
# 4     False  False     True     False     False
# ...     ...    ...      ...       ...       ...
# 9995  False  False     True      True     False
# 9996  False  False    False      True     False
# 9997  False  False    False     False     False
# 9998  False  False    False     False     False
# 9999  False  False    False     False     False
#
# [10000 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# order          0
# price          0
# product     3978
# customer    4993
# quantity       0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# order       10000
# price       10000
# product      6022
# customer     5007
# quantity    10000
# dtype: int64

# %%
df['product']=df['product'].fillna('None')
df
# Out:
#       order  price product customer  quantity
# 0         1     11    None     None         6
# 1         2     79   CALLM      can         7
# 2         3     45    None     None         5
# 3         4     61   APPLE      can         4
# 4         5     10    None     alex         7
# ...     ...    ...     ...      ...       ...
# 9995   9996     66    None     None         7
# 9996   9997     83   CALLM     None         5
# 9997   9998     30   CALLM      can         4
# 9998   9999     48   CALLM      can         9
# 9999  10000     62   CALLM      can         5
#
# [10000 rows x 5 columns]

# %%
df['customer']=df['customer'].fillna('None')
df
# Out:
#       order  price product customer  quantity
# 0         1     11    None     None         6
# 1         2     79   CALLM      can         7
# 2         3     45    None     None         5
# 3         4     61   APPLE      can         4
# 4         5     10    None     alex         7
# ...     ...    ...     ...      ...       ...
# 9995   9996     66    None     None         7
# 9996   9997     83   CALLM     None         5
# 9997   9998     30   CALLM      can         4
# 9998   9999     48   CALLM      can         9
# 9999  10000     62   CALLM      can         5
#
# [10000 rows x 5 columns]

# %%
df['price']=df['price'].fillna(df['price'].mean())
df
# Out:
#       order  price product customer  quantity
# 0         1     11    None     None         6
# 1         2     79   CALLM      can         7
# 2         3     45    None     None         5
# 3         4     61   APPLE      can         4
# 4         5     10    None     alex         7
# ...     ...    ...     ...      ...       ...
# 9995   9996     66    None     None         7
# 9996   9997     83   CALLM     None         5
# 9997   9998     30   CALLM      can         4
# 9998   9999     48   CALLM      can         9
# 9999  10000     62   CALLM      can         5
#
# [10000 rows x 5 columns]

# %%
df['total_sales']=df['price']*df['quantity']
df
# Out:
#       order  price product customer  quantity  total_sales
# 0         1     11    None     None         6           66
# 1         2     79   CALLM      can         7          553
# 2         3     45    None     None         5          225
# 3         4     61   APPLE      can         4          244
# 4         5     10    None     alex         7           70
# ...     ...    ...     ...      ...       ...          ...
# 9995   9996     66    None     None         7          462
# 9996   9997     83   CALLM     None         5          415
# 9997   9998     30   CALLM      can         4          120
# 9998   9999     48   CALLM      can         9          432
# 9999  10000     62   CALLM      can         5          310
#
# [10000 rows x 6 columns]

# %%
total_revenue=df['total_sales'].sum()
print(total_revenue)
# Out:
# 2753576

# %%
customer_sales=df.groupby('customer')['total_sales'].sum()
print(customer_sales)
# Out:
# customer
# None    1370954
# alex     681909
# can      700713
# Name: total_sales, dtype: int64

# %%
top_customer=customer_sales.idxmax()
print(top_customer)
# Out:
# None

# %%
lower_customer=customer_sales.idxmin()
print(lower_customer)
# Out:
# alex

# %%
product_sales=df.groupby('product')['total_sales'].sum().sort_values(ascending=False)
print(product_sales)
# Out:
# product
# None      1099279
# APPLE      566978
# CALLM      550738
# BANANA     536581
# Name: total_sales, dtype: int64

# %%
avarge_order=df['total_sales'].mean()
print(avarge_order)
# Out:
# 275.3576

# %%
customer_avg=df.groupby('customer')['total_sales'].mean()
print(customer_avg)
# Out:
# customer
# None    274.575205
# alex    274.410060
# can     277.840206
# Name: total_sales, dtype: float64

# %%
top_orders=df.nlargest(5,'total_sales')
print(top_orders)
# Out:
#      order  price product customer  quantity  total_sales
# 26      27     99   CALLM     None         9          891
# 334    335     99    None      can         9          891
# 479    480     99   CALLM      can         9          891
# 800    801     99   APPLE     alex         9          891
# 853    854     99  BANANA      can         9          891

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['total_sales'],bins=20,kde=True)
plt.title('Distribution of Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='customer',y='total_sales',data=df)
plt.xlabel('Customer')
plt.ylabel('Total Sales')
plt.title('Total Sales by Customer')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='product',y='total_sales',data=df)
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.title('Total Sales by Product')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='total_sales',data=df)
plt.xlabel('Price')
plt.ylabel('Total Sales')
plt.title('Total Sales vs Price')
plt.show()

# %%
df1={
    'key':['A','B','C','D'],
    'a1':[1,2,3,4],
    'b1':[5,6,7,8]
}
df1=pd.DataFrame(df1)
df1
# Out:
#   key  a1  b1
# 0   A   1   5
# 1   B   2   6
# 2   C   3   7
# 3   D   4   8

# %%
df2={
    'key':['x','B','A','D'],
    'a2':[7,8,9,4],
    'b2':[10,11,12,5]
}
df2=pd.DataFrame(df2)
df2
# Out:
#   key  a2  b2
# 0   x   7  10
# 1   B   8  11
# 2   A   9  12
# 3   D   4   5

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  a1  b1  a2  b2
# 0   A   1   5   9  12
# 1   B   2   6   8  11
# 2   D   4   8   4   5

# %%
pd.merge(df1,df2,on='key',how='inner')[['key','a1','a2']]
# Out:
#   key  a1  a2
# 0   A   1   9
# 1   B   2   8
# 2   D   4   4

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  a1  b1   a2    b2
# 0   A   1   5  9.0  12.0
# 1   B   2   6  8.0  11.0
# 2   C   3   7  NaN   NaN
# 3   D   4   8  4.0   5.0

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key   a1   b1  a2  b2
# 0   x  NaN  NaN   7  10
# 1   B  2.0  6.0   8  11
# 2   A  1.0  5.0   9  12
# 3   D  4.0  8.0   4   5

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key   a1   b1   a2    b2
# 0   A  1.0  5.0  9.0  12.0
# 1   B  2.0  6.0  8.0  11.0
# 2   C  3.0  7.0  NaN   NaN
# 3   D  4.0  8.0  4.0   5.0
# 4   x  NaN  NaN  7.0  10.0
