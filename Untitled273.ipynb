# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled273.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'order':[1,None,None,4,5,6,7,8,9,10],
    'customer':['A','B','C',None,'E',None,'G','H',None,'J'],
    'product':['apple','banana','orange','apple','banana','orange','apple',None,None,None],
    'quantity':[10,20,30,40,50,60,454,45,44,5469],
    'price':[100,200,300,400,500,600,554.48,None,None,None]
}
df=pd.DataFrame(data)
print("ORIGINAL DATAFRAME")
print(df)
# Out:
# ORIGINAL DATAFRAME
#    order customer product  quantity   price
# 0    1.0        A   apple        10  100.00
# 1    NaN        B  banana        20  200.00
# 2    NaN        C  orange        30  300.00
# 3    4.0     None   apple        40  400.00
# 4    5.0        E  banana        50  500.00
# 5    6.0     None  orange        60  600.00
# 6    7.0        G   apple       454  554.48
# 7    8.0        H    None        45     NaN
# 8    9.0     None    None        44     NaN
# 9   10.0        J    None      5469     NaN

# %%
df.head()
# Out:
#    order customer product  quantity  price
# 0    1.0        A   apple        10  100.0
# 1    NaN        B  banana        20  200.0
# 2    NaN        C  orange        30  300.0
# 3    4.0     None   apple        40  400.0
# 4    5.0        E  banana        50  500.0

# %%
df.tail()
# Out:
#    order customer product  quantity   price
# 5    6.0     None  orange        60  600.00
# 6    7.0        G   apple       454  554.48
# 7    8.0        H    None        45     NaN
# 8    9.0     None    None        44     NaN
# 9   10.0        J    None      5469     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order     8 non-null      float64
#  1   customer  7 non-null      object
#  2   product   7 non-null      object
#  3   quantity  10 non-null     int64
#  4   price     7 non-null      float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#            order     quantity       price
# count   8.000000    10.000000    7.000000
# mean    6.250000   622.200000  379.211429
# std     2.915476  1708.079155  187.456180
# min     1.000000    10.000000  100.000000
# 25%     4.750000    32.500000  250.000000
# 50%     6.500000    44.500000  400.000000
# 75%     8.250000    57.500000  527.240000
# max    10.000000  5469.000000  600.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.dtypes
# Out:
# order       float64
# customer     object
# product      object
# quantity      int64
# price       float64
# dtype: object

# %%
df['customer']
# Out:
# 0       A
# 1       B
# 2       C
# 3    None
# 4       E
# 5    None
# 6       G
# 7       H
# 8    None
# 9       J
# Name: customer, dtype: object

# %%
df[['price','quantity']]
# Out:
#     price  quantity
# 0  100.00        10
# 1  200.00        20
# 2  300.00        30
# 3  400.00        40
# 4  500.00        50
# 5  600.00        60
# 6  554.48       454
# 7     NaN        45
# 8     NaN        44
# 9     NaN      5469

# %%
df.isna()
# Out:
#    order  customer  product  quantity  price
# 0  False     False    False     False  False
# 1   True     False    False     False  False
# 2   True     False    False     False  False
# 3  False      True    False     False  False
# 4  False     False    False     False  False
# 5  False      True    False     False  False
# 6  False     False    False     False  False
# 7  False     False     True     False   True
# 8  False      True     True     False   True
# 9  False     False     True     False   True

# %%
df.isna().sum()
# Out:
# order       2
# customer    3
# product     3
# quantity    0
# price       3
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(11)

# %%
df.notna().sum()
# Out:
# order        8
# customer     7
# product      7
# quantity    10
# price        7
# dtype: int64

# %%
df.notna().sum().sum()
# Out:
# np.int64(39)

# %%
df['order']=df['order'].fillna(df['order'].mean())
df['price']=df['price'].fillna(df['price'].mean())
df['quantity']=df['quantity'].fillna(df['quantity'].mean())
df['product']=df['product'].fillna(df['product'].mode()[0])
df['customer']=df['customer'].fillna(df['customer'].mode()[0])
print("=======clean data=======")
print(df)
# Out:
# =======clean data=======
#    order customer product  quantity       price
# 0   1.00        A   apple        10  100.000000
# 1   6.25        B  banana        20  200.000000
# 2   6.25        C  orange        30  300.000000
# 3   4.00        A   apple        40  400.000000
# 4   5.00        E  banana        50  500.000000
# 5   6.00        A  orange        60  600.000000
# 6   7.00        G   apple       454  554.480000
# 7   8.00        H   apple        45  379.211429
# 8   9.00        A   apple        44  379.211429
# 9  10.00        J   apple      5469  379.211429

# %%
df['total_sales']=df['price']*df['quantity']
print(df)
# Out:
#    order customer product  quantity       price   total_sales
# 0   1.00        A   apple        10  100.000000  1.000000e+03
# 1   6.25        B  banana        20  200.000000  4.000000e+03
# 2   6.25        C  orange        30  300.000000  9.000000e+03
# 3   4.00        A   apple        40  400.000000  1.600000e+04
# 4   5.00        E  banana        50  500.000000  2.500000e+04
# 5   6.00        A  orange        60  600.000000  3.600000e+04
# 6   7.00        G   apple       454  554.480000  2.517339e+05
# 7   8.00        H   apple        45  379.211429  1.706451e+04
# 8   9.00        A   apple        44  379.211429  1.668530e+04
# 9  10.00        J   apple      5469  379.211429  2.073907e+06

# %%
df.loc[df['total_sales']>900]
# Out:
#    order customer product  quantity       price   total_sales
# 0   1.00        A   apple        10  100.000000  1.000000e+03
# 1   6.25        B  banana        20  200.000000  4.000000e+03
# 2   6.25        C  orange        30  300.000000  9.000000e+03
# 3   4.00        A   apple        40  400.000000  1.600000e+04
# 4   5.00        E  banana        50  500.000000  2.500000e+04
# 5   6.00        A  orange        60  600.000000  3.600000e+04
# 6   7.00        G   apple       454  554.480000  2.517339e+05
# 7   8.00        H   apple        45  379.211429  1.706451e+04
# 8   9.00        A   apple        44  379.211429  1.668530e+04
# 9  10.00        J   apple      5469  379.211429  2.073907e+06

# %%
df.loc[2]
# Out:
# order            6.25
# customer            C
# product        orange
# quantity           30
# price           300.0
# total_sales    9000.0
# Name: 2, dtype: object

# %%
df.loc[2:6]
# Out:
#    order customer product  quantity   price  total_sales
# 2   6.25        C  orange        30  300.00      9000.00
# 3   4.00        A   apple        40  400.00     16000.00
# 4   5.00        E  banana        50  500.00     25000.00
# 5   6.00        A  orange        60  600.00     36000.00
# 6   7.00        G   apple       454  554.48    251733.92

# %%
df.iloc[2]
# Out:
# order            6.25
# customer            C
# product        orange
# quantity           30
# price           300.0
# total_sales    9000.0
# Name: 2, dtype: object

# %%
df.iloc[2:6]
# Out:
#    order customer product  quantity  price  total_sales
# 2   6.25        C  orange        30  300.0       9000.0
# 3   4.00        A   apple        40  400.0      16000.0
# 4   5.00        E  banana        50  500.0      25000.0
# 5   6.00        A  orange        60  600.0      36000.0

# %%
df.sort_index()
# Out:
#    order customer product  quantity       price   total_sales
# 0   1.00        A   apple        10  100.000000  1.000000e+03
# 1   6.25        B  banana        20  200.000000  4.000000e+03
# 2   6.25        C  orange        30  300.000000  9.000000e+03
# 3   4.00        A   apple        40  400.000000  1.600000e+04
# 4   5.00        E  banana        50  500.000000  2.500000e+04
# 5   6.00        A  orange        60  600.000000  3.600000e+04
# 6   7.00        G   apple       454  554.480000  2.517339e+05
# 7   8.00        H   apple        45  379.211429  1.706451e+04
# 8   9.00        A   apple        44  379.211429  1.668530e+04
# 9  10.00        J   apple      5469  379.211429  2.073907e+06

# %%
df.sort_values(by='price')
# Out:
#    order customer product  quantity       price   total_sales
# 0   1.00        A   apple        10  100.000000  1.000000e+03
# 1   6.25        B  banana        20  200.000000  4.000000e+03
# 2   6.25        C  orange        30  300.000000  9.000000e+03
# 7   8.00        H   apple        45  379.211429  1.706451e+04
# 9  10.00        J   apple      5469  379.211429  2.073907e+06
# 8   9.00        A   apple        44  379.211429  1.668530e+04
# 3   4.00        A   apple        40  400.000000  1.600000e+04
# 4   5.00        E  banana        50  500.000000  2.500000e+04
# 6   7.00        G   apple       454  554.480000  2.517339e+05
# 5   6.00        A  orange        60  600.000000  3.600000e+04

# %%
df.sort_values(by='price',ascending=False)
# Out:
#    order customer product  quantity       price   total_sales
# 5   6.00        A  orange        60  600.000000  3.600000e+04
# 6   7.00        G   apple       454  554.480000  2.517339e+05
# 4   5.00        E  banana        50  500.000000  2.500000e+04
# 3   4.00        A   apple        40  400.000000  1.600000e+04
# 8   9.00        A   apple        44  379.211429  1.668530e+04
# 7   8.00        H   apple        45  379.211429  1.706451e+04
# 9  10.00        J   apple      5469  379.211429  2.073907e+06
# 2   6.25        C  orange        30  300.000000  9.000000e+03
# 1   6.25        B  banana        20  200.000000  4.000000e+03
# 0   1.00        A   apple        10  100.000000  1.000000e+03

# %%
total_revenue=df['total_sales'].sum()
print("Total Revenue:",total_revenue)
# Out:
# Total Revenue: 2450391.04

# %%
top_product=df['product'].value_counts().idxmax()
print("Top Product:",top_product)
# Out:
# Top Product: apple

# %%
top_customer=df['customer'].value_counts().idxmax()
print("Top Customer:",top_customer)
# Out:
# Top Customer: A

# %%
top_order=df['order'].value_counts().idxmax()
print("Top Order:",top_order)
# Out:
# Top Order: 6.25

# %%
df.groupby('product')['total_sales'].sum()
# Out:
# product
# apple     2376391.04
# banana      29000.00
# orange      45000.00
# Name: total_sales, dtype: float64

# %%
df.groupby('customer')['total_sales'].sum()
# Out:
# customer
# A    6.968530e+04
# B    4.000000e+03
# C    9.000000e+03
# E    2.500000e+04
# G    2.517339e+05
# H    1.706451e+04
# J    2.073907e+06
# Name: total_sales, dtype: float64

# %%
df.groupby(['customer','product'])['total_sales'].sum()
# Out:
# customer  product
# A         apple      3.368530e+04
#           orange     3.600000e+04
# B         banana     4.000000e+03
# C         orange     9.000000e+03
# E         banana     2.500000e+04
# G         apple      2.517339e+05
# H         apple      1.706451e+04
# J         apple      2.073907e+06
# Name: total_sales, dtype: float64

# %%
df.groupby('product').agg({
    'total_sales':'sum',
    'quantity':'sum'
})
# Out:
#          total_sales  quantity
# product
# apple     2376391.04      6062
# banana      29000.00        70
# orange      45000.00        90

# %%
df.groupby('customer').agg({
    'total_sales':'sum',
    'quantity':'sum'
})
# Out:
#            total_sales  quantity
# customer
# A         6.968530e+04       154
# B         4.000000e+03        20
# C         9.000000e+03        30
# E         2.500000e+04        50
# G         2.517339e+05       454
# H         1.706451e+04        45
# J         2.073907e+06      5469

# %%
df.groupby(['customer','product']).agg({
    'total_sales':'sum',
    'quantity':'sum'
})
# Out:
#                    total_sales  quantity
# customer product
# A        apple    3.368530e+04        94
#          orange   3.600000e+04        60
# B        banana   4.000000e+03        20
# C        orange   9.000000e+03        30
# E        banana   2.500000e+04        50
# G        apple    2.517339e+05       454
# H        apple    1.706451e+04        45
# J        apple    2.073907e+06      5469

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='product',y='total_sales',data=df)
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='customer',y='total_sales',data=df)
plt.title('Total Sales by Customer')
plt.xlabel('Customer')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='order',y='total_sales',data=df)
plt.xlabel('Order')
plt.ylabel('Total Sales')
plt.title('Total Sales by Order')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['total_sales'],bins=20,kde=True)
plt.xlabel('Total Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Total Sales')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='price',y='quantity',data=df)
plt.xlabel('Price')
plt.ylabel('Quantity')
plt.title('Price vs Quantity')
plt.show()
