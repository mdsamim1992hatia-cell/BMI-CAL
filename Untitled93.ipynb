# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled93.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.DataFrame({
    'customer':['A','B','C','D','E','F'],
    'product':['X','Y','Z','X','Y','Z'],
    'quantity':[1,2,1,3,2,1],
    'seles':[1000,2000,20100,1411,21211,55454]
})
df
# Out:
#   customer product  quantity  seles
# 0        A       X         1   1000
# 1        B       Y         2   2000
# 2        C       Z         1  20100
# 3        D       X         3   1411
# 4        E       Y         2  21211
# 5        F       Z         1  55454

# %%
df['new']='bb'
df
# Out:
#   customer product  quantity  seles new
# 0        A       X         1   1000  bb
# 1        B       Y         2   2000  bb
# 2        C       Z         1  20100  bb
# 3        D       X         3   1411  bb
# 4        E       Y         2  21211  bb
# 5        F       Z         1  55454  bb

# %%
df.groupby('product').sum()
# Out:
#         customer  quantity  seles   new
# product
# X             AD         4   2411  bbbb
# Y             BE         4  23211  bbbb
# Z             CF         2  75554  bbbb

# %%
df.groupby('customer')['seles'].sum()
# Out:
# customer
# A     1000
# B     2000
# C    20100
# D     1411
# E    21211
# F    55454
# Name: seles, dtype: int64

# %%
df.groupby('customer')['seles'].mean()
# Out:
# customer
# A     1000.0
# B     2000.0
# C    20100.0
# D     1411.0
# E    21211.0
# F    55454.0
# Name: seles, dtype: float64

# %%
df.groupby('customer')['seles'].agg(['sum','mean'])
# Out:
#             sum     mean
# customer
# A          1000   1000.0
# B          2000   2000.0
# C         20100  20100.0
# D          1411   1411.0
# E         21211  21211.0
# F         55454  55454.0

# %%
df.groupby(['customer','product'])['seles'].sum()
# Out:
# customer  product
# A         X           1000
# B         Y           2000
# C         Z          20100
# D         X           1411
# E         Y          21211
# F         Z          55454
# Name: seles, dtype: int64
