# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
climate_data=[
    ('1/2/2025',22,55,'sunny'),
    ('2/12/2023',2,22,'clody'),
    ('5/2/2023',2525,'rainny')
]
df=pd.DataFrame(climate_data,columns=['date','temperature','rainfall','condition'])
df
# Out:
#         date  temperature rainfall condition
# 0   1/2/2025           22       55     sunny
# 1  2/12/2023            2       22     clody
# 2   5/2/2023         2525   rainny      None

# %%
climate_data=[
    {'day':'1/2/2025','temperature':22,'rainfall':55,'condition':'sunny'},
    {'day':'2/12/2023','temperature':2,'rainfall':22,'condition':'clody'},
    {'day':'5/2/2023','temperature':2525,'rainfall':25,'condition':'rainny'}


]
df=pd.DataFrame(climate_data)
df
# Out:
#          day  temperature  rainfall condition
# 0   1/2/2025           22        55     sunny
# 1  2/12/2023            2        22     clody
# 2   5/2/2023         2525        25    rainny

# %%
climate_data={
    'day':['1/2/2025','2/12/2023','1,/,2,/2021'],
    'temperature':[22,2,2525],
    'rainfall':[55,22,25],
    'condition':['sunny','clody','rainny']

}
df=pd.DataFrame(climate_data)
df
# Out:
#            day  temperature  rainfall condition
# 0     1/2/2025           22        55     sunny
# 1    2/12/2023            2        22     clody
# 2  1,/,2,/2021         2525        25    rainny

# %%
import pandas as pd
import numpy as np

# %%
climate_data=[
    ('1/2/2025',2,5,'clody'),
    ('2/2/2021',22,3,'sunny'),
    ('3/3/2023',55,6,'rainy')

]
df=pd.DataFrame(climate_data,columns=['day','temperature','rainfall','condition'])
df
# Out:
#         day  temperature  rainfall condition
# 0  1/2/2025            2         5     clody
# 1  2/2/2021           22         3     sunny
# 2  3/3/2023           55         6     rainy

# %%
climate_data={
    'day':['1/2/2025','2/2/2021','3/3/2023'],
    'temperature':[2,22,55],
    'rainfall':[5,3,2],
    'condition':['clody','sunny','rainy']
}
df=pd.DataFrame(climate_data)
df
# Out:
#         day  temperature  rainfall condition
# 0  1/2/2025            2         5     clody
# 1  2/2/2021           22         3     sunny
# 2  3/3/2023           55         2     rainy

# %%
climate_data=[
    {'day':'1/2/2025','temperature':22,'rainfall':55,'condition':'sunny'},
    {'day':'2/12/2023','temperature':11,'rainfall':22,'condition':'clody'},
    {'day':'5/2/2023','temperature':44,'rainfall':25,'condition':'rainny'}


]
df=pd.DataFrame(climate_data)
df
# Out:
#          day  temperature  rainfall condition
# 0   1/2/2025           22        55     sunny
# 1  2/12/2023           11        22     clody
# 2   5/2/2023           44        25    rainny
