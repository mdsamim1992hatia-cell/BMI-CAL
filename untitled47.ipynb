# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/untitled47.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=20
sum=a+b
sub=a-b
mul=a*b
div=a/b

# %%
print(sum)
print(sub)
print(mul)
print(div)
# Out:
# 30
# -10
# 200
# 0.5

# %%
complex_num=10+10j
print(complex_num)
# Out:
# (10+10j)

# %%
age=50
print(age)
# Out:
# 50

# %%
marks=55.5
print(marks)
# Out:
# 55.5

# %%
name="md samim"
print(name)
# Out:
# md samim

# %%
citties=["daka","rongour","noakhali"]
print(citties)
# Out:
# ['daka', 'rongour', 'noakhali']

# %%
print(type(age))
print(type(marks))
print(type(name))
print(type(citties))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>

# %%
print(type(complex_num))
# Out:
# <class 'complex'>

# %%
print(citties)
# Out:
# ['daka', 'rongour', 'noakhali']

# %%
print(citties[0])
print(citties[1])
print(citties[2])
# Out:
# daka
# rongour
# noakhali

# %%
number=range(0,10)

# %%
print(number)
# Out:
# range(0, 10)

# %%
data={
    "name":"samim",
    "age":25,
    "country":"bangladesh"

}

# %%
print(data)
# Out:
# {'name': 'samim', 'age': 25, 'country': 'bangladesh'}
