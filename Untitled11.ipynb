# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=20

# %%
c=30
sum=a+b+c
print(sum)
# Out:
# 60

# %%
sub=a-b-c
print(sub)
# Out:
# -40

# %%
div=a/b/c
print(div)
# Out:
# 0.016666666666666666

# %%
mul=a*b*c

# %%
print(mul)
# Out:
# 6000

# %%
complex_num=10+10j
print(complex_num)
# Out:
# (10+10j)

# %%
age=20
print(age)
# Out:
# 20

# %%
marks=50.5
print(marks)
# Out:
# 50.5

# %%
name="md samimul islam"
print(name)
# Out:
# md samimul islam

# %%
cities=["dhaka","khulna","rajsahi","noakhali","borishal"]
print(cities)
# Out:
# ['dhaka', 'khulna', 'rajsahi', 'noakhali', 'borishal']

# %%
print(cities[0])
print(cities[1])
print(cities[2])
print(cities[3])
print(cities[4])
# Out:
# dhaka
# khulna
# rajsahi
# noakhali
# borishal

# %%
latter=["a,","b","c","d","e"]
print(latter)
# Out:
# ['a,', 'b', 'c', 'd', 'e']

# %%
print(latter[0])
print(latter[1])
print(latter[2])
print(latter[3])
# Out:
# a,
# b
# c
# d

# %%
number=range(2,10)
print(number)
# Out:
# range(2, 10)

# %%
number=range(2,20,2)
print(*number)
# Out:
# 2 4 6 8 10 12 14 16 18

# %%
fruits=("apple","banana","papya","mango")
print(fruits)
print(fruits[0])
print(fruits[1])
print(fruits[2])
# Out:
# ('apple', 'banana', 'papya', 'mango')
# apple
# banana
# papya

# %%
isbangladeshi=True
print(isbangladeshi)
# Out:
# True

# %%
havemony=None
print(havemony)
# Out:
# None
