# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled232.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'order':range(1,11),
    'country':['usa','india','ban','canada','india',None,'canada','italy',None,'italy'],
    'catagory':['tech','food','tech','food','food','food','tech','food','tech','food'],
    'sales':[np.nan,44,555,55,55,8585,55,np.nan,55,565],
    'customers':['alex','nen','bib','lion','deaw',None,None,None,'ALEX','BIB']
}
df=pd.DataFrame(data)
print("----raw dat---")
print(df)
# Out:
# ----raw dat---
#    order country catagory   sales customers
# 0      1     usa     tech     NaN      alex
# 1      2   india     food    44.0       nen
# 2      3     ban     tech   555.0       bib
# 3      4  canada     food    55.0      lion
# 4      5   india     food    55.0      deaw
# 5      6    None     food  8585.0      None
# 6      7  canada     tech    55.0      None
# 7      8   italy     food     NaN      None
# 8      9    None     tech    55.0      ALEX
# 9     10   italy     food   565.0       BIB

# %%
df.head()
# Out:
#    order country catagory  sales customers
# 0      1     usa     tech    NaN      alex
# 1      2   india     food   44.0       nen
# 2      3     ban     tech  555.0       bib
# 3      4  canada     food   55.0      lion
# 4      5   india     food   55.0      deaw

# %%
df.tail()
# Out:
#    order country catagory   sales customers
# 5      6    None     food  8585.0      None
# 6      7  canada     tech    55.0      None
# 7      8   italy     food     NaN      None
# 8      9    None     tech    55.0      ALEX
# 9     10   italy     food   565.0       BIB

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['order', 'country', 'catagory', 'sales', 'customers'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order      10 non-null     int64
#  1   country    8 non-null      object
#  2   catagory   10 non-null     object
#  3   sales      8 non-null      float64
#  4   customers  7 non-null      object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#           order        sales
# count  10.00000     8.000000
# mean    5.50000  1246.125000
# std     3.02765  2974.195951
# min     1.00000    44.000000
# 25%     3.25000    55.000000
# 50%     5.50000    55.000000
# 75%     7.75000   557.500000
# max    10.00000  8585.000000

# %%
df.dtypes
# Out:
# order          int64
# country       object
# catagory      object
# sales        float64
# customers     object
# dtype: object

# %%
df['customers'].fillna('unknown',inplace=True)
df['sales'].fillna(df['sales'].mean(),inplace=True)
df['catagory'].fillna('unknown',inplace=True)
df['country'].fillna('unknown',inplace=True)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      ALEX
# 9     10    italy     food   565.000       BIB
# /tmp/ipython-input-1384946317.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df['country']=df['country'].fillna('unknown')
print(df)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df['customers']=df['customers'].fillna('unknown')
print(df)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df['sales']=df['sales'].fillna(df['sales'].mean())
print(df)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df.groupby('country')['sales'].sum().sort_values(ascending=False)
# Out:
# country
# unknown    8640.000
# italy      1811.125
# usa        1246.125
# ban         555.000
# canada      110.000
# india        99.000
# Name: sales, dtype: float64

# %%
df.groupby('catagory')['sales'].sum().sort_values(ascending=False)
# Out:
# catagory
# food    10550.125
# tech     1911.125
# Name: sales, dtype: float64

# %%
df.groupby('customers')['sales'].sum().sort_values(ascending=False)
# Out:
# customers
# unknown    9886.125
# alex       1301.125
# bib        1120.000
# deaw         55.000
# lion         55.000
# nen          44.000
# Name: sales, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='country',y='sales',data=df)
plt.xlabel('country')
plt.ylabel('sales')
plt.title('total sales by country')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='catagory',y='sales',data=df)
plt.xlabel('catagory')
plt.ylabel('sales')
plt.title('total sales by catagory')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='customers',y='sales',data=df)
plt.xlabel('customers')
plt.ylabel('sales')
plt.title('total sales by customers')
plt.show()

# %%
df.head()
# Out:
#    order country catagory     sales customers
# 0      1     usa     tech  1246.125      alex
# 1      2   india     food    44.000       nen
# 2      3     ban     tech   555.000       bib
# 3      4  canada     food    55.000      lion
# 4      5   india     food    55.000      deaw

# %%
df.tail()
# Out:
#    order  country catagory     sales customers
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['order', 'country', 'catagory', 'sales', 'customers'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order      10 non-null     int64
#  1   country    10 non-null     object
#  2   catagory   10 non-null     object
#  3   sales      10 non-null     float64
#  4   customers  10 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#           order        sales
# count  10.00000    10.000000
# mean    5.50000  1246.125000
# std     3.02765  2622.994279
# min     1.00000    44.000000
# 25%     3.25000    55.000000
# 50%     5.50000   305.000000
# 75%     7.75000  1075.843750
# max    10.00000  8585.000000

# %%
df.dtypes
# Out:
# order          int64
# country       object
# catagory      object
# sales        float64
# customers     object
# dtype: object

# %%
df['customers']=df['customers'].fillna('unknown')
print(df)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df['sales']=df['sales'].fillna(df['sales'].mean())
print(df)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df.groupby('country')['sales'].sum().sort_values(ascending=False)
# Out:
# country
# unknown    8640.000
# italy      1811.125
# usa        1246.125
# ban         555.000
# canada      110.000
# india        99.000
# Name: sales, dtype: float64

# %%
df.groupby('catagory')['sales'].sum().sort_values(ascending=False)
# Out:
# catagory
# food    10550.125
# tech     1911.125
# Name: sales, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.columns
# Out:
# Index(['order', 'country', 'catagory', 'sales', 'customers'], dtype='object')

# %%
df.head()
# Out:
#    order country catagory     sales customers
# 0      1     usa     tech  1246.125      alex
# 1      2   india     food    44.000       nen
# 2      3     ban     tech   555.000       bib
# 3      4  canada     food    55.000      lion
# 4      5   india     food    55.000      deaw

# %%
df.tail()
# Out:
#    order  country catagory     sales customers
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df.shape
# Out:
# (10, 5)

# %%
df.describe()
# Out:
#           order        sales
# count  10.00000    10.000000
# mean    5.50000  1246.125000
# std     3.02765  2622.994279
# min     1.00000    44.000000
# 25%     3.25000    55.000000
# 50%     5.50000   305.000000
# 75%     7.75000  1075.843750
# max    10.00000  8585.000000

# %%
df.dtypes
# Out:
# order          int64
# country       object
# catagory      object
# sales        float64
# customers     object
# dtype: object

# %%
df['customers']=df['customers'].fillna('unknown')
print(df)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df['catagory']=df['catagory'].fillna('unknown')
print(df)
# Out:
#    order  country catagory     sales customers
# 0      1      usa     tech  1246.125      alex
# 1      2    india     food    44.000       nen
# 2      3      ban     tech   555.000       bib
# 3      4   canada     food    55.000      lion
# 4      5    india     food    55.000      deaw
# 5      6  unknown     food  8585.000   unknown
# 6      7   canada     tech    55.000   unknown
# 7      8    italy     food  1246.125   unknown
# 8      9  unknown     tech    55.000      alex
# 9     10    italy     food   565.000       bib

# %%
df.groupby('country')['sales'].sum().sort_values(ascending=False)
# Out:
# country
# unknown    8640.000
# italy      1811.125
# usa        1246.125
# ban         555.000
# canada      110.000
# india        99.000
# Name: sales, dtype: float64

# %%
df.groupby('catagory')['sales'].sum().sort_values(ascending=False)
# Out:
# catagory
# food    10550.125
# tech     1911.125
# Name: sales, dtype: float64

# %%
df.groupby('customers')['sales'].sum().sort_values(ascending=False)
# Out:
# customers
# unknown    9886.125
# alex       1301.125
# bib        1120.000
# deaw         55.000
# lion         55.000
# nen          44.000
# Name: sales, dtype: float64

# %%
plt.figure
sns.barplot(x='country',y='sales',data=df)
plt.xlabel('country')
plt.ylabel('sales')
plt.title('total sales by country')
plt.show()

# %%
plt.figure
sns.barplot(x='catagory',y='sales',data=df)
plt.xlabel('catagory')
plt.ylabel('sales')
plt.title('total sales by catagory')
plt.show()

# %%
plt.figure
sns.barplot(x='customers',y='sales',data=df)
plt.xlabel('customers')
plt.ylabel('sales')
plt.title('total sales by customers')
plt.show()

# %%
plt.figure
sns.barplot(x='order',y='sales',data=df)
plt.xlabel('order')
plt.ylabel('sales')
plt.title('total sales by order')
plt.show()

# %%
data={
    'order_id':range(101,111),
    'country':['usa','india','ban','canada','india',None,'canada','italy',None,'italy'],
    'catagory':['tech','food','tech','food','food','food','tech','food','tech','food'],
    'sales':[None,None,555,55,55,8585,55,3636,220,221],
    'profit':[None,None,555,5545,6565,68685,665,3636,220,221],
    'order_date':pd.date_range(start='2022-01-01',periods=10,freq='D')
}
df=pd.DataFrame(data)
print("----raw dat---")
print(df)
# Out:
# ----raw dat---
#    order_id country catagory   sales   profit order_date
# 0       101     usa     tech     NaN      NaN 2022-01-01
# 1       102   india     food     NaN      NaN 2022-01-02
# 2       103     ban     tech   555.0    555.0 2022-01-03
# 3       104  canada     food    55.0   5545.0 2022-01-04
# 4       105   india     food    55.0   6565.0 2022-01-05
# 5       106    None     food  8585.0  68685.0 2022-01-06
# 6       107  canada     tech    55.0    665.0 2022-01-07
# 7       108   italy     food  3636.0   3636.0 2022-01-08
# 8       109    None     tech   220.0    220.0 2022-01-09
# 9       110   italy     food   221.0    221.0 2022-01-10

# %%
df['country'].fillna('unknown',inplace=True)
print(df)
# Out:
#    order_id  country catagory   sales   profit order_date
# 0       101      usa     tech     NaN      NaN 2022-01-01
# 1       102    india     food     NaN      NaN 2022-01-02
# 2       103      ban     tech   555.0    555.0 2022-01-03
# 3       104   canada     food    55.0   5545.0 2022-01-04
# 4       105    india     food    55.0   6565.0 2022-01-05
# 5       106  unknown     food  8585.0  68685.0 2022-01-06
# 6       107   canada     tech    55.0    665.0 2022-01-07
# 7       108    italy     food  3636.0   3636.0 2022-01-08
# 8       109  unknown     tech   220.0    220.0 2022-01-09
# 9       110    italy     food   221.0    221.0 2022-01-10
# /tmp/ipython-input-1140149345.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df['sales'].fillna(df['sales'].mean(),inplace=True)
print(df)
# Out:
#    order_id  country catagory    sales   profit order_date
# 0       101      usa     tech  1672.75      NaN 2022-01-01
# 1       102    india     food  1672.75      NaN 2022-01-02
# 2       103      ban     tech   555.00    555.0 2022-01-03
# 3       104   canada     food    55.00   5545.0 2022-01-04
# 4       105    india     food    55.00   6565.0 2022-01-05
# 5       106  unknown     food  8585.00  68685.0 2022-01-06
# 6       107   canada     tech    55.00    665.0 2022-01-07
# 7       108    italy     food  3636.00   3636.0 2022-01-08
# 8       109  unknown     tech   220.00    220.0 2022-01-09
# 9       110    italy     food   221.00    221.0 2022-01-10
# /tmp/ipython-input-4239423840.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['country'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#    order_id  country catagory    sales   profit order_date
# 0       101      usa     tech  1672.75      NaN 2022-01-01
# 1       102    india     food  1672.75      NaN 2022-01-02
# 2       103      ban     tech   555.00    555.0 2022-01-03
# 3       104   canada     food    55.00   5545.0 2022-01-04
# 4       105    india     food    55.00   6565.0 2022-01-05
# 5       106  unknown     food  8585.00  68685.0 2022-01-06
# 6       107   canada     tech    55.00    665.0 2022-01-07
# 7       108    italy     food  3636.00   3636.0 2022-01-08
# 8       109  unknown     tech   220.00    220.0 2022-01-09
# 9       110    italy     food   221.00    221.0 2022-01-10
# /tmp/ipython-input-3429143772.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['country'].fillna(method='ffill',inplace=True)

# %%
df=df.dropna()
print(df)
# Out:
#    order_id  country catagory   sales   profit order_date
# 2       103      ban     tech   555.0    555.0 2022-01-03
# 3       104   canada     food    55.0   5545.0 2022-01-04
# 4       105    india     food    55.0   6565.0 2022-01-05
# 5       106  unknown     food  8585.0  68685.0 2022-01-06
# 6       107   canada     tech    55.0    665.0 2022-01-07
# 7       108    italy     food  3636.0   3636.0 2022-01-08
# 8       109  unknown     tech   220.0    220.0 2022-01-09
# 9       110    italy     food   221.0    221.0 2022-01-10

# %%
df['total_sales']=df['sales']*df['profit']
print(df)
# Out:
#    order_id  country catagory   sales   profit order_date  total_sales
# 2       103      ban     tech   555.0    555.0 2022-01-03     308025.0
# 3       104   canada     food    55.0   5545.0 2022-01-04     304975.0
# 4       105    india     food    55.0   6565.0 2022-01-05     361075.0
# 5       106  unknown     food  8585.0  68685.0 2022-01-06  589660725.0
# 6       107   canada     tech    55.0    665.0 2022-01-07      36575.0
# 7       108    italy     food  3636.0   3636.0 2022-01-08   13220496.0
# 8       109  unknown     tech   220.0    220.0 2022-01-09      48400.0
# 9       110    italy     food   221.0    221.0 2022-01-10      48841.0

# %%
df['sales']=df['sales'].astype(int)
print(df)
# Out:
#    order_id  country catagory  sales   profit order_date  total_sales
# 2       103      ban     tech    555    555.0 2022-01-03     308025.0
# 3       104   canada     food     55   5545.0 2022-01-04     304975.0
# 4       105    india     food     55   6565.0 2022-01-05     361075.0
# 5       106  unknown     food   8585  68685.0 2022-01-06  589660725.0
# 6       107   canada     tech     55    665.0 2022-01-07      36575.0
# 7       108    italy     food   3636   3636.0 2022-01-08   13220496.0
# 8       109  unknown     tech    220    220.0 2022-01-09      48400.0
# 9       110    italy     food    221    221.0 2022-01-10      48841.0

# %%
df[df['catagory']=='food']
# Out:
#    order_id  country catagory  sales   profit order_date  total_sales
# 3       104   canada     food     55   5545.0 2022-01-04     304975.0
# 4       105    india     food     55   6565.0 2022-01-05     361075.0
# 5       106  unknown     food   8585  68685.0 2022-01-06  589660725.0
# 7       108    italy     food   3636   3636.0 2022-01-08   13220496.0
# 9       110    italy     food    221    221.0 2022-01-10      48841.0

# %%
df[['country','sales']]
# Out:
#    country  sales
# 2      ban    555
# 3   canada     55
# 4    india     55
# 5  unknown   8585
# 6   canada     55
# 7    italy   3636
# 8  unknown    220
# 9    italy    221

# %%
df.isna()
# Out:
#    order_id  country  catagory  sales  profit  order_date  total_sales
# 2     False    False     False  False   False       False        False
# 3     False    False     False  False   False       False        False
# 4     False    False     False  False   False       False        False
# 5     False    False     False  False   False       False        False
# 6     False    False     False  False   False       False        False
# 7     False    False     False  False   False       False        False
# 8     False    False     False  False   False       False        False
# 9     False    False     False  False   False       False        False

# %%
df.groupby('sales')['profit'].sum().sort_values(ascending=False)
# Out:
# sales
# 8585    68685.0
# 55      12775.0
# 3636     3636.0
# 555       555.0
# 221       221.0
# 220       220.0
# Name: profit, dtype: float64

# %%
df.groupby('catagory')['total_sales'].sum().sort_values(ascending=False)
# Out:
# catagory
# food    603596112.0
# tech       393000.0
# Name: total_sales, dtype: float64

# %%
df.groupby('country')['total_sales'].sum().sort_values(ascending=False)
# Out:
# country
# unknown    589709125.0
# italy       13269337.0
# india         361075.0
# canada        341550.0
# ban           308025.0
# Name: total_sales, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='country',y='total_sales',data=df)
plt.xlabel('country')
plt.ylabel('total_sales')
plt.title('total sales by country')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='catagory',y='total_sales',data=df)
plt.xlabel('catagory')
plt.ylabel('total_sales')
plt.title('total sales by catagory')
plt.show()

# %%
plt.figure  (figsize=(10,6))
sns.barplot(x='order_date',y='total_sales',data=df)
plt.xlabel('order_date')
plt.ylabel('total_sales')
plt.title('total sales by order_date')
# Out:
# Text(0.5, 1.0, 'total sales by order_date')

# %%
data={
    'order':range(1,11),
    'country':['usa','india','ban','canada','india',None,'canada','italy',None,'italy'],
    'catagory':['tech','food','tech','food','food','food','tech',np.nan,np.nan,np.nan],
    'sales':[np.nan,44,555,55,55,8585,55,np.nan,220,np.nan],
    'profit':[np.nan,np.nan,525,5545,6565,68685,665,3636,220,22],

}
df=pd.DataFrame(data)
print("----raw dat---")
print(df)
# Out:
# ----raw dat---
#    order country catagory   sales   profit
# 0      1     usa     tech     NaN      NaN
# 1      2   india     food    44.0      NaN
# 2      3     ban     tech   555.0    525.0
# 3      4  canada     food    55.0   5545.0
# 4      5   india     food    55.0   6565.0
# 5      6    None     food  8585.0  68685.0
# 6      7  canada     tech    55.0    665.0
# 7      8   italy      NaN     NaN   3636.0
# 8      9    None      NaN   220.0    220.0
# 9     10   italy      NaN     NaN     22.0

# %%
df['catagory']=df['catagory'].fillna('unknown')
df['country']=df['country'].fillna('unknown')
df['sales']=df['sales'].fillna(df['sales'].mean())
df['profit']=df['profit'].fillna(df['profit'].mean())

print("=== clen data===")
print(df)
# Out:
# === clen data===
#    order  country catagory   sales     profit
# 0      1      usa     tech  1367.0  10732.875
# 1      2    india     food    44.0  10732.875
# 2      3      ban     tech   555.0    525.000
# 3      4   canada     food    55.0   5545.000
# 4      5    india     food    55.0   6565.000
# 5      6  unknown     food  8585.0  68685.000
# 6      7   canada     tech    55.0    665.000
# 7      8    italy  unknown  1367.0   3636.000
# 8      9  unknown  unknown   220.0    220.000
# 9     10    italy  unknown  1367.0     22.000

# %%
df['total_sales']=df['sales']*df['profit']
print(df)
# Out:
#    order  country catagory   sales     profit   total_sales
# 0      1      usa     tech  1367.0  10732.875  1.467184e+07
# 1      2    india     food    44.0  10732.875  4.722465e+05
# 2      3      ban     tech   555.0    525.000  2.913750e+05
# 3      4   canada     food    55.0   5545.000  3.049750e+05
# 4      5    india     food    55.0   6565.000  3.610750e+05
# 5      6  unknown     food  8585.0  68685.000  5.896607e+08
# 6      7   canada     tech    55.0    665.000  3.657500e+04
# 7      8    italy  unknown  1367.0   3636.000  4.970412e+06
# 8      9  unknown  unknown   220.0    220.000  4.840000e+04
# 9     10    italy  unknown  1367.0     22.000  3.007400e+04

# %%
df.groupby('catagory')['total_sales'].sum().sort_values(ascending=False)
# Out:
# catagory
# food       5.907990e+08
# tech       1.499979e+07
# unknown    5.048886e+06
# Name: total_sales, dtype: float64

# %%
df.groupby('country')['total_sales'].sum().sort_values(ascending=False)
# Out:
# country
# unknown    5.897091e+08
# usa        1.467184e+07
# italy      5.000486e+06
# india      8.333215e+05
# canada     3.415500e+05
# ban        2.913750e+05
# Name: total_sales, dtype: float64

# %%
df.groupby('order')['total_sales'].sum().sort_values(ascending=False)
# Out:
# order
# 6     5.896607e+08
# 1     1.467184e+07
# 8     4.970412e+06
# 2     4.722465e+05
# 5     3.610750e+05
# 4     3.049750e+05
# 3     2.913750e+05
# 9     4.840000e+04
# 7     3.657500e+04
# 10    3.007400e+04
# Name: total_sales, dtype: float64

# %%
df.groupby('catagory')['total_sales'].sum().sort_values(ascending=False)
# Out:
# catagory
# food       5.907990e+08
# tech       1.499979e+07
# unknown    5.048886e+06
# Name: total_sales, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='country',y='total_sales',data=df)
plt.xlabel('country')
plt.ylabel('total_sales')
plt.title('total sales by country')
plt.show()

# %%
plt.figure
sns.barplot(x='catagory',y='total_sales',data=df)
plt.xlabel('catagory')
plt.ylabel('total_sales')
plt.title('total sales by catagory')
plt.show()

# %%
plt.figure
sns.barplot(x='order',y='total_sales',data=df)
plt.xlabel('order')
plt.ylabel('total_sales')
plt.title('total sales by order')
plt.show()

# %%
plt.figure
sns.barplot(x='catagory',y='total_sales',data=df)
plt.xlabel('catagory')
plt.ylabel('total_sales')
plt.title('total sales by catagory')
# Out:
# Text(0.5, 1.0, 'total sales by catagory')

# %%
np.random.seed(42)

# %%
data={
    'order':range(1001,1051),
    'customers':np.random.choice(['alex','bib','deaw','nen',None],size=50),
    'product':np.random.choice(['laptop','mobile',None],size=50),
    'sales':np.random.randint(100,500,size=50),
    'profit':np.random.randint(100,500,size=50),
}
df=pd.DataFrame(data)
print("----raw dat---")
print(df)
# Out:
# ----raw dat---
#     order customers product  sales  profit
# 0    1001       nen    None    388     135
# 1    1002      None    None    478     112
# 2    1003      deaw  laptop    360     259
# 3    1004      None    None    330     426
# 4    1005      None    None    140     286
# 5    1006       bib  mobile    127     342
# 6    1007      deaw  laptop    234     185
# 7    1008      deaw  mobile    300     383
# 8    1009      deaw  mobile    427     165
# 9    1010      None  mobile    367     269
# 10   1011       nen  mobile    132     144
# 11   1012      deaw  mobile    147     161
# 12   1013      None  mobile    161     233
# 13   1014       bib  mobile    315     383
# 14   1015       nen  laptop    392     127
# 15   1016       bib    None    198     207
# 16   1017       nen  mobile    271     143
# 17   1018      None  mobile    459     439
# 18   1019      alex  mobile    313     385
# 19   1020       nen  mobile    134     430
# ...

# %%
df.head()
# Out:
#    order customers product  sales  profit
# 0   1001       nen    None    388     135
# 1   1002      None    None    478     112
# 2   1003      deaw  laptop    360     259
# 3   1004      None    None    330     426
# 4   1005      None    None    140     286

# %%
df.tail()
# Out:
#     order customers product  sales  profit
# 45   1046      alex    None    330     195
# 46   1047       bib    None    336     332
# 47   1048      None    None    242     279
# 48   1049       bib  laptop    270     212
# 49   1050       nen    None    128     417

# %%
df.columns
# Out:
# Index(['order', 'customers', 'product', 'sales', 'profit'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order      50 non-null     int64
#  1   customers  40 non-null     object
#  2   product    35 non-null     object
#  3   sales      50 non-null     int64
#  4   profit     50 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#             order       sales      profit
# count    50.00000   50.000000   50.000000
# mean   1025.50000  297.900000  302.720000
# std      14.57738  119.376484  104.934779
# min    1001.00000  104.000000  112.000000
# 25%    1013.25000  195.750000  221.750000
# 50%    1025.50000  316.000000  293.000000
# 75%    1037.75000  378.250000  384.500000
# max    1050.00000  497.000000  484.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.shape
# Out:
# (50, 5)

# %%
df.dtypes
# Out:
# order         int64
# customers    object
# product      object
# sales         int64
# profit        int64
# dtype: object

# %%
df['product']=df['product'].fillna('unknown')
print(df)
# Out:
#     order customers  product  sales  profit
# 0    1001       nen  unknown    388     135
# 1    1002      None  unknown    478     112
# 2    1003      deaw   laptop    360     259
# 3    1004      None  unknown    330     426
# 4    1005      None  unknown    140     286
# 5    1006       bib   mobile    127     342
# 6    1007      deaw   laptop    234     185
# 7    1008      deaw   mobile    300     383
# 8    1009      deaw   mobile    427     165
# 9    1010      None   mobile    367     269
# 10   1011       nen   mobile    132     144
# 11   1012      deaw   mobile    147     161
# 12   1013      None   mobile    161     233
# 13   1014       bib   mobile    315     383
# 14   1015       nen   laptop    392     127
# 15   1016       bib  unknown    198     207
# 16   1017       nen   mobile    271     143
# 17   1018      None   mobile    459     439
# 18   1019      alex   mobile    313     385
# 19   1020       nen   mobile    134     430
# ...

# %%
df['sales']=df['sales'].fillna(df['sales'].mean())
print(df)
# Out:
#     order customers  product  sales  profit
# 0    1001       nen  unknown    388     135
# 1    1002      None  unknown    478     112
# 2    1003      deaw   laptop    360     259
# 3    1004      None  unknown    330     426
# 4    1005      None  unknown    140     286
# 5    1006       bib   mobile    127     342
# 6    1007      deaw   laptop    234     185
# 7    1008      deaw   mobile    300     383
# 8    1009      deaw   mobile    427     165
# 9    1010      None   mobile    367     269
# 10   1011       nen   mobile    132     144
# 11   1012      deaw   mobile    147     161
# 12   1013      None   mobile    161     233
# 13   1014       bib   mobile    315     383
# 14   1015       nen   laptop    392     127
# 15   1016       bib  unknown    198     207
# 16   1017       nen   mobile    271     143
# 17   1018      None   mobile    459     439
# 18   1019      alex   mobile    313     385
# 19   1020       nen   mobile    134     430
# ...

# %%
df.isna().sum()
# Out:
# order         0
# customers    10
# product       0
# sales         0
# profit        0
# dtype: int64

# %%
df['customers']=df['customers'].fillna('unknown')
print(df)
# Out:
#     order customers  product  sales  profit
# 0    1001       nen  unknown    388     135
# 1    1002   unknown  unknown    478     112
# 2    1003      deaw   laptop    360     259
# 3    1004   unknown  unknown    330     426
# 4    1005   unknown  unknown    140     286
# 5    1006       bib   mobile    127     342
# 6    1007      deaw   laptop    234     185
# 7    1008      deaw   mobile    300     383
# 8    1009      deaw   mobile    427     165
# 9    1010   unknown   mobile    367     269
# 10   1011       nen   mobile    132     144
# 11   1012      deaw   mobile    147     161
# 12   1013   unknown   mobile    161     233
# 13   1014       bib   mobile    315     383
# 14   1015       nen   laptop    392     127
# 15   1016       bib  unknown    198     207
# 16   1017       nen   mobile    271     143
# 17   1018   unknown   mobile    459     439
# 18   1019      alex   mobile    313     385
# 19   1020       nen   mobile    134     430
# ...

# %%
df.isna().sum()
# Out:
# order        0
# customers    0
# product      0
# sales        0
# profit       0
# dtype: int64

# %%
df['total_sales']=df['sales']*df['profit']
print(df)
# Out:
#     order customers  product  sales  profit  total_sales
# 0    1001       nen  unknown    388     135        52380
# 1    1002   unknown  unknown    478     112        53536
# 2    1003      deaw   laptop    360     259        93240
# 3    1004   unknown  unknown    330     426       140580
# 4    1005   unknown  unknown    140     286        40040
# 5    1006       bib   mobile    127     342        43434
# 6    1007      deaw   laptop    234     185        43290
# 7    1008      deaw   mobile    300     383       114900
# 8    1009      deaw   mobile    427     165        70455
# 9    1010   unknown   mobile    367     269        98723
# 10   1011       nen   mobile    132     144        19008
# 11   1012      deaw   mobile    147     161        23667
# 12   1013   unknown   mobile    161     233        37513
# 13   1014       bib   mobile    315     383       120645
# 14   1015       nen   laptop    392     127        49784
# ...

# %%
daily_sales=df.groupby('order')['total_sales'].sum()
print(daily_sales)
# Out:
# order
# 1001     52380
# 1002     53536
# 1003     93240
# 1004    140580
# 1005     40040
# 1006     43434
# 1007     43290
# 1008    114900
# 1009     70455
# 1010     98723
# 1011     19008
# 1012     23667
# 1013     37513
# 1014    120645
# 1015     49784
# 1016     40986
# 1017     38753
# 1018    201501
# 1019    120505
# 1020     57620
# 1021     74002
# 1022     89400
# 1023     75900
# 1024    102884
# 1025     33696
# 1026    153428
# 1027    168504
# 1028    189854
# 1029    100760
# 1030     82130
# 1031    163344
# 1032    109548
# 1033     52212
# 1034    132165
# 1035     33276
# 1036    199743
# 1037     73392
# 1038     52488
# 1039    183106
# 1040    109890
# 1041     92140
# 1042     37901
# 1043     80730
# 1044    230351
# 1045     83139
# 1046     64350
# 1047    111552
# 1048     67518
# 1049     57240
# 1050     53376
# Name: total_sales, dtype: int64

# %%
customers_sales=df.groupby('customers')['total_sales'].sum().sort_values(ascending=False)
print(customers_sales)
# Out:
# customers
# bib        1061093
# unknown     981042
# deaw        937496
# nen         864341
# alex        674607
# Name: total_sales, dtype: int64

# %%
cuantity_sales=df.groupby('product')['total_sales'].sum().sort_values(ascending=False)
print(cuantity_sales)
# Out:
# product
# mobile     1629185
# laptop     1559480
# unknown    1329914
# Name: total_sales, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='customers',y='total_sales',data=df)
plt.xlabel('customers')
plt.ylabel('total_sales')
plt.title('total sales by customers')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='product',y='total_sales',data=df)
plt.xlabel('product')
plt.ylabel('total_sales')
plt.title('total sales by product')
plt.show()

# %%
plt.figure
sns.barplot(x='order',y='total_sales',data=df)
plt.xlabel('order')
plt.ylabel('total_sales')
plt.title('total sales by order')
plt.show()

# %%
plt.figure
sns.barplot(x='customers',y='total_sales',data=df)
plt.xlabel('customers')
plt.ylabel('total_sales')
plt.title('total sales by customers')
plt.show()

# %%
data1={
    'order':range(1,51),
    'customer':np.random.choice(['alex',None,'deaw','nen'],size=50),
    'product':np.random.choice(['laptop','mobile',None],size=50),
    'sales':np.random.randint(100,500,size=50),
    'profit':np.random.randint(100,500,size=50),

}
df=pd.DataFrame(data1)
print("----raw dat---")
print(df)
# Out:
# ----raw dat---
#     order customer product  sales  profit
# 0       1     alex  mobile    445     358
# 1       2     deaw  mobile    118     243
# 2       3     alex    None    138     111
# 3       4     deaw  mobile    225     429
# 4       5     alex    None    272     323
# 5       6     None  mobile    240     371
# 6       7     alex  laptop    341     457
# 7       8     alex    None    319     255
# 8       9     None    None    225     472
# 9      10      nen  laptop    157     107
# 10     11      nen    None    247     221
# 11     12     alex    None    416     447
# 12     13     None  mobile    482     263
# 13     14     alex    None    460     189
# 14     15     deaw  laptop    100     235
# 15     16     deaw  mobile    486     285
# 16     17     alex  mobile    447     415
# 17     18      nen  laptop    289     277
# 18     19      nen  laptop    290     127
# 19     20     alex  mobile    468     319
# 20     21     alex    None    411     456
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.columns
# Out:
# Index(['order', 'customer', 'product', 'sales', 'profit'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order     50 non-null     int64
#  1   customer  45 non-null     object
#  2   product   34 non-null     object
#  3   sales     50 non-null     int64
#  4   profit    50 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#           order       sales     profit
# count  50.00000   50.000000   50.00000
# mean   25.50000  306.420000  300.64000
# std    14.57738  115.501584  114.22244
# min     1.00000  103.000000  111.00000
# 25%    13.25000  199.250000  195.75000
# 50%    25.50000  320.000000  293.00000
# 75%    37.75000  387.000000  382.00000
# max    50.00000  499.000000  496.00000

# %%
df.head()
# Out:
#    order customer product  sales  profit
# 0      1     alex  mobile    445     358
# 1      2     deaw  mobile    118     243
# 2      3     alex    None    138     111
# 3      4     deaw  mobile    225     429
# 4      5     alex    None    272     323

# %%
df.tail()
# Out:
#     order customer product  sales  profit
# 45     46      nen  laptop    242     104
# 46     47     alex  mobile    100     218
# 47     48     deaw    None    472     388
# 48     49     alex    None    153     473
# 49     50     alex  mobile    473     164

# %%
df.isna().sum()
# Out:
# order        0
# customer     5
# product     16
# sales        0
# profit       0
# dtype: int64

# %%
df['customer']=df['customer'].fillna('unknown')
print(df)
# Out:
#     order customer product  sales  profit
# 0       1     alex  mobile    445     358
# 1       2     deaw  mobile    118     243
# 2       3     alex    None    138     111
# 3       4     deaw  mobile    225     429
# 4       5     alex    None    272     323
# 5       6  unknown  mobile    240     371
# 6       7     alex  laptop    341     457
# 7       8     alex    None    319     255
# 8       9  unknown    None    225     472
# 9      10      nen  laptop    157     107
# 10     11      nen    None    247     221
# 11     12     alex    None    416     447
# 12     13  unknown  mobile    482     263
# 13     14     alex    None    460     189
# 14     15     deaw  laptop    100     235
# 15     16     deaw  mobile    486     285
# 16     17     alex  mobile    447     415
# 17     18      nen  laptop    289     277
# 18     19      nen  laptop    290     127
# 19     20     alex  mobile    468     319
# 20     21     alex    None    411     456
# ...

# %%
df['product']=df['product'].fillna('unknown')
print(df)
# Out:
#     order customer  product  sales  profit
# 0       1     alex   mobile    445     358
# 1       2     deaw   mobile    118     243
# 2       3     alex  unknown    138     111
# 3       4     deaw   mobile    225     429
# 4       5     alex  unknown    272     323
# 5       6  unknown   mobile    240     371
# 6       7     alex   laptop    341     457
# 7       8     alex  unknown    319     255
# 8       9  unknown  unknown    225     472
# 9      10      nen   laptop    157     107
# 10     11      nen  unknown    247     221
# 11     12     alex  unknown    416     447
# 12     13  unknown   mobile    482     263
# 13     14     alex  unknown    460     189
# 14     15     deaw   laptop    100     235
# 15     16     deaw   mobile    486     285
# 16     17     alex   mobile    447     415
# 17     18      nen   laptop    289     277
# 18     19      nen   laptop    290     127
# 19     20     alex   mobile    468     319
# 20     21     alex  unknown    411     456
# ...

# %%
df.isna().sum()
# Out:
# order       0
# customer    0
# product     0
# sales       0
# profit      0
# dtype: int64

# %%
daily_sales=df.groupby('order')['sales'].sum()
print(daily_sales)
# Out:
# order
# 1     445
# 2     118
# 3     138
# 4     225
# 5     272
# 6     240
# 7     341
# 8     319
# 9     225
# 10    157
# 11    247
# 12    416
# 13    482
# 14    460
# 15    100
# 16    486
# 17    447
# 18    289
# 19    290
# 20    468
# 21    411
# 22    216
# 23    233
# 24    157
# 25    143
# 26    272
# 27    259
# 28    272
# 29    416
# 30    402
# 31    248
# 32    179
# 33    473
# 34    312
# 35    302
# 36    351
# 37    328
# 38    263
# 39    326
# 40    246
# 41    119
# 42    146
# 43    332
# 44    404
# 45    113
# 46    242
# 47    100
# 48    472
# 49    153
# 50    473
# Name: sales, dtype: int64

# %%
product_sales=df.groupby('product')['sales'].sum().sort_values(ascending=False)
print(product_sales)
# Out:
# product
# mobile     5950
# unknown    4773
# laptop     3805
# Name: sales, dtype: int64

# %%
customers_sales=df.groupby('customer')['sales'].sum().sort_values(ascending=False)
print(customers_sales)
# Out:
# customer
# alex       6129
# nen        3701
# deaw       3313
# unknown    1385
# Name: sales, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='customer',y='sales',data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='product',y='sales',data=df)
plt.xlabel('product')
plt.ylabel('sales')
plt.title('total sales by product')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='order',y='sales',data=df)
plt.xlabel('order')
plt.ylabel('sales')
plt.title('total sales by order')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='customer',y='sales',data=df)
plt.xlabel('customer')
plt.ylabel('sales')
plt.title('total sales by customer')
plt.show()

# %%
df=pd.DataFrame(data1)
df
# Out:
#     order customer product  sales  profit
# 0       1     alex  mobile    445     358
# 1       2     deaw  mobile    118     243
# 2       3     alex    None    138     111
# 3       4     deaw  mobile    225     429
# 4       5     alex    None    272     323
# 5       6     None  mobile    240     371
# 6       7     alex  laptop    341     457
# 7       8     alex    None    319     255
# 8       9     None    None    225     472
# 9      10      nen  laptop    157     107
# 10     11      nen    None    247     221
# 11     12     alex    None    416     447
# 12     13     None  mobile    482     263
# 13     14     alex    None    460     189
# 14     15     deaw  laptop    100     235
# 15     16     deaw  mobile    486     285
# 16     17     alex  mobile    447     415
# 17     18      nen  laptop    289     277
# 18     19      nen  laptop    290     127
# 19     20     alex  mobile    468     319
# 20     21     alex    None    411     456
# ...

# %%
df['sales']
# Out:
# 0     445
# 1     118
# 2     138
# 3     225
# 4     272
# 5     240
# 6     341
# 7     319
# 8     225
# 9     157
# 10    247
# 11    416
# 12    482
# 13    460
# 14    100
# 15    486
# 16    447
# 17    289
# 18    290
# 19    468
# 20    411
# 21    216
# 22    233
# 23    157
# 24    143
# 25    272
# 26    259
# 27    272
# 28    416
# 29    402
# 30    248
# 31    179
# 32    473
# 33    312
# 34    302
# 35    351
# 36    328
# 37    263
# 38    326
# 39    246
# 40    119
# 41    146
# 42    332
# 43    404
# 44    113
# 45    242
# 46    100
# 47    472
# 48    153
# 49    473
# Name: sales, dtype: int64

# %%
df[['customer','sales']]
# Out:
#    customer  sales
# 0      alex    445
# 1      deaw    118
# 2      alex    138
# 3      deaw    225
# 4      alex    272
# 5      None    240
# 6      alex    341
# 7      alex    319
# 8      None    225
# 9       nen    157
# 10      nen    247
# 11     alex    416
# 12     None    482
# 13     alex    460
# 14     deaw    100
# 15     deaw    486
# 16     alex    447
# 17      nen    289
# 18      nen    290
# 19     alex    468
# 20     alex    411
# 21     deaw    216
# 22      nen    233
# 23     alex    157
# 24     deaw    143
# 25      nen    272
# 26     None    259
# 27     deaw    272
# 28      nen    416
# 29      nen    402
# 30     deaw    248
# 31     None    179
# 32     deaw    473
# 33      nen    312
# 34     alex    302
# 35     alex    351
# 36     deaw    328
# 37      nen    263
# 38     alex    326
# 39      nen    246
# 40     deaw    119
# 41     alex    146
# 42      nen    332
# 43     alex    404
# 44     deaw    113
# 45      nen    242
# ...

# %%
df.loc[:,['sales','product']]
# Out:
#     sales product
# 0     445  mobile
# 1     118  mobile
# 2     138    None
# 3     225  mobile
# 4     272    None
# 5     240  mobile
# 6     341  laptop
# 7     319    None
# 8     225    None
# 9     157  laptop
# 10    247    None
# 11    416    None
# 12    482  mobile
# 13    460    None
# 14    100  laptop
# 15    486  mobile
# 16    447  mobile
# 17    289  laptop
# 18    290  laptop
# 19    468  mobile
# 20    411    None
# 21    216  mobile
# 22    233  laptop
# 23    157  mobile
# 24    143  laptop
# 25    272  mobile
# 26    259    None
# 27    272  mobile
# 28    416  mobile
# 29    402  laptop
# 30    248  laptop
# 31    179  laptop
# 32    473  mobile
# 33    312    None
# 34    302  laptop
# 35    351  laptop
# 36    328  mobile
# 37    263  laptop
# 38    326    None
# 39    246    None
# 40    119  laptop
# 41    146  laptop
# 42    332  mobile
# 43    404    None
# 44    113    None
# 45    242  laptop
# 46    100  mobile
# 47    472    None
# 48    153    None
# ...

# %%
df.iloc[:,[3,4]]
# Out:
#     sales  profit
# 0     445     358
# 1     118     243
# 2     138     111
# 3     225     429
# 4     272     323
# 5     240     371
# 6     341     457
# 7     319     255
# 8     225     472
# 9     157     107
# 10    247     221
# 11    416     447
# 12    482     263
# 13    460     189
# 14    100     235
# 15    486     285
# 16    447     415
# 17    289     277
# 18    290     127
# 19    468     319
# 20    411     456
# 21    216     140
# 22    233     327
# 23    157     291
# 24    143     244
# 25    272     300
# 26    259     311
# 27    272     319
# 28    416     339
# 29    402     496
# 30    248     145
# 31    179     134
# 32    473     352
# 33    312     489
# 34    302     181
# 35    351     470
# 36    328     355
# 37    263     296
# 38    326     402
# 39    246     109
# 40    119     411
# 41    146     385
# 42    332     341
# 43    404     350
# 44    113     464
# 45    242     104
# 46    100     218
# 47    472     388
# 48    153     473
# ...

# %%
df.iloc[:,2:5]
# Out:
#    product  sales  profit
# 0   mobile    445     358
# 1   mobile    118     243
# 2     None    138     111
# 3   mobile    225     429
# 4     None    272     323
# 5   mobile    240     371
# 6   laptop    341     457
# 7     None    319     255
# 8     None    225     472
# 9   laptop    157     107
# 10    None    247     221
# 11    None    416     447
# 12  mobile    482     263
# 13    None    460     189
# 14  laptop    100     235
# 15  mobile    486     285
# 16  mobile    447     415
# 17  laptop    289     277
# 18  laptop    290     127
# 19  mobile    468     319
# 20    None    411     456
# 21  mobile    216     140
# 22  laptop    233     327
# 23  mobile    157     291
# 24  laptop    143     244
# 25  mobile    272     300
# 26    None    259     311
# 27  mobile    272     319
# 28  mobile    416     339
# 29  laptop    402     496
# 30  laptop    248     145
# 31  laptop    179     134
# 32  mobile    473     352
# 33    None    312     489
# ...

# %%
df.drop('sales',axis=1)
# Out:
#     order customer product  profit
# 0       1     alex  mobile     358
# 1       2     deaw  mobile     243
# 2       3     alex    None     111
# 3       4     deaw  mobile     429
# 4       5     alex    None     323
# 5       6     None  mobile     371
# 6       7     alex  laptop     457
# 7       8     alex    None     255
# 8       9     None    None     472
# 9      10      nen  laptop     107
# 10     11      nen    None     221
# 11     12     alex    None     447
# 12     13     None  mobile     263
# 13     14     alex    None     189
# 14     15     deaw  laptop     235
# 15     16     deaw  mobile     285
# 16     17     alex  mobile     415
# 17     18      nen  laptop     277
# 18     19      nen  laptop     127
# 19     20     alex  mobile     319
# 20     21     alex    None     456
# 21     22     deaw  mobile     140
# 22     23      nen  laptop     327
# 23     24     alex  mobile     291
# 24     25     deaw  laptop     244
# 25     26      nen  mobile     300
# ...

# %%
df.drop('order',axis=1)
# Out:
#    customer product  sales  profit
# 0      alex  mobile    445     358
# 1      deaw  mobile    118     243
# 2      alex    None    138     111
# 3      deaw  mobile    225     429
# 4      alex    None    272     323
# 5      None  mobile    240     371
# 6      alex  laptop    341     457
# 7      alex    None    319     255
# 8      None    None    225     472
# 9       nen  laptop    157     107
# 10      nen    None    247     221
# 11     alex    None    416     447
# 12     None  mobile    482     263
# 13     alex    None    460     189
# 14     deaw  laptop    100     235
# 15     deaw  mobile    486     285
# 16     alex  mobile    447     415
# 17      nen  laptop    289     277
# 18      nen  laptop    290     127
# 19     alex  mobile    468     319
# 20     alex    None    411     456
# 21     deaw  mobile    216     140
# 22      nen  laptop    233     327
# 23     alex  mobile    157     291
# 24     deaw  laptop    143     244
# 25      nen  mobile    272     300
# ...

# %%
df.select_dtypes(include='object')
# Out:
#    customer product
# 0      alex  mobile
# 1      deaw  mobile
# 2      alex    None
# 3      deaw  mobile
# 4      alex    None
# 5      None  mobile
# 6      alex  laptop
# 7      alex    None
# 8      None    None
# 9       nen  laptop
# 10      nen    None
# 11     alex    None
# 12     None  mobile
# 13     alex    None
# 14     deaw  laptop
# 15     deaw  mobile
# 16     alex  mobile
# 17      nen  laptop
# 18      nen  laptop
# 19     alex  mobile
# 20     alex    None
# 21     deaw  mobile
# 22      nen  laptop
# 23     alex  mobile
# 24     deaw  laptop
# 25      nen  mobile
# 26     None    None
# 27     deaw  mobile
# 28      nen  mobile
# 29      nen  laptop
# 30     deaw  laptop
# 31     None  laptop
# 32     deaw  mobile
# 33      nen    None
# 34     alex  laptop
# 35     alex  laptop
# 36     deaw  mobile
# 37      nen  laptop
# 38     alex    None
# 39      nen    None
# 40     deaw  laptop
# 41     alex  laptop
# 42      nen  mobile
# 43     alex    None
# ...

# %%
df['customer']
# Out:
# 0     alex
# 1     deaw
# 2     alex
# 3     deaw
# 4     alex
# 5     None
# 6     alex
# 7     alex
# 8     None
# 9      nen
# 10     nen
# 11    alex
# 12    None
# 13    alex
# 14    deaw
# 15    deaw
# 16    alex
# 17     nen
# 18     nen
# 19    alex
# 20    alex
# 21    deaw
# 22     nen
# 23    alex
# 24    deaw
# 25     nen
# 26    None
# 27    deaw
# 28     nen
# 29     nen
# 30    deaw
# 31    None
# 32    deaw
# 33     nen
# 34    alex
# 35    alex
# 36    deaw
# 37     nen
# 38    alex
# 39     nen
# 40    deaw
# 41    alex
# 42     nen
# 43    alex
# 44    deaw
# 45     nen
# 46    alex
# 47    deaw
# 48    alex
# 49    alex
# Name: customer, dtype: object
