# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dic={
    'a':[1,2,np.nan,4,5],
    'b':[np.nan,np.nan,np.nan,np.nan,5],
    'c':[1,2,3,4,5],
    'd':[5,np.nan,np.nan,np.nan,5]
}
df=pd.DataFrame(data_dic)
df
# Out:
#      a    b  c    d
# 0  1.0  NaN  1  5.0
# 1  2.0  NaN  2  NaN
# 2  NaN  NaN  3  NaN
# 3  4.0  NaN  4  NaN
# 4  5.0  5.0  5  5.0

# %%
df['new']='x'
df
# Out:
#      a    b  c    d new
# 0  1.0  NaN  1  5.0   x
# 1  2.0  NaN  2  NaN   x
# 2  NaN  NaN  3  NaN   x
# 3  4.0  NaN  4  NaN   x
# 4  5.0  5.0  5  5.0   x

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       4 non-null      float64
#  1   b       1 non-null      float64
#  2   c       5 non-null      int64
#  3   d       2 non-null      float64
#  4   new     5 non-null      object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 332.0+ bytes

# %%
df.isnull()
# Out:
#        a      b      c      d    new
# 0  False   True  False  False  False
# 1  False   True  False   True  False
# 2   True   True  False   True  False
# 3  False   True  False   True  False
# 4  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# a      1
# b      4
# c      0
# d      3
# new    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(8)

# %%
df['a'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: a, dtype: bool

# %%
df[df['a'].isnull()]
# Out:
#     a   b  c   d new
# 2 NaN NaN  3 NaN   x

# %%
df.notnull().sum().sum()
# Out:
# np.int64(17)

# %%
df['b'].sum()
# Out:
# np.float64(5.0)

# %%
df_fill=df.fillna(0)
df_fill
# Out:
#      a    b  c    d new
# 0  1.0  0.0  1  5.0   x
# 1  2.0  0.0  2  0.0   x
# 2  0.0  0.0  3  0.0   x
# 3  4.0  0.0  4  0.0   x
# 4  5.0  5.0  5  5.0   x

# %%
df_fill=df.fillna(method='ffill')
df_fill
# Out:
# /tmp/ipython-input-356525906.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fill=df.fillna(method='ffill')
#      a    b  c    d new
# 0  1.0  NaN  1  5.0   x
# 1  2.0  NaN  2  5.0   x
# 2  2.0  NaN  3  5.0   x
# 3  4.0  NaN  4  5.0   x
# 4  5.0  5.0  5  5.0   x

# %%
df_bfill=df.fillna(method='bfill')
df_bfill
# Out:
# /tmp/ipython-input-4020059411.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill=df.fillna(method='bfill')
#      a    b  c    d new
# 0  1.0  5.0  1  5.0   x
# 1  2.0  5.0  2  5.0   x
# 2  4.0  5.0  3  5.0   x
# 3  4.0  5.0  4  5.0   x
# 4  5.0  5.0  5  5.0   x

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
