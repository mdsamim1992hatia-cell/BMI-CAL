# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data_dic={
    'col_1':[1,2,3,4,5],
    'col_2':[111,222,333,111,555],
    'col_3':['alpha','beta','gamma',np.nan,np.nan]

}
df=pd.DataFrame(data_dic)
df
# Out:
#    col_1  col_2  col_3
# 0      1    111  alpha
# 1      2    222   beta
# 2      3    333  gamma
# 3      4    111    NaN
# 4      5    555    NaN

# %%
df['col_2'].unique()
# Out:
# array([111, 222, 333, 555])

# %%
print(df['col_1'].unique())
print(df['col_2'].unique())
print(df['col_3'].unique())
# Out:
# [1 2 3 4 5]
# [111 222 333 555]
# ['alpha' 'beta' 'gamma' nan]

# %%
print(df['col_1'].nunique())
print(df['col_2'].nunique())
print(df['col_3'].nunique())
# Out:
# 5
# 4
# 3

# %%
df['col_1'].value_counts()
# Out:
# col_1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64

# %%
df['col_2'].value_counts()
# Out:
# col_2
# 111    2
# 222    1
# 333    1
# 555    1
# Name: count, dtype: int64

# %%
df['col_3'].value_counts()
# Out:
# col_3
# alpha    1
# beta     1
# gamma    1
# Name: count, dtype: int64

# %%
df['col_1'].count()
# Out:
# np.int64(5)

# %%
df['col_2'].count()
# Out:
# np.int64(5)

# %%
df['col_3'].count()
# Out:
# np.int64(3)

# %%
df.sort_values(by='col_2',ascending=False)
# Out:
#    col_1  col_2  col_3
# 4      5    555    NaN
# 2      3    333  gamma
# 1      2    222   beta
# 0      1    111  alpha
# 3      4    111    NaN

# %%
df.sort_values(by='col_2',ascending=True)
# Out:
#    col_1  col_2  col_3
# 0      1    111  alpha
# 3      4    111    NaN
# 1      2    222   beta
# 2      3    333  gamma
# 4      5    555    NaN

# %%
df.sort_values(by=['col_2','col_1'],ascending=False)
# Out:
#    col_1  col_2  col_3
# 4      5    555    NaN
# 2      3    333  gamma
# 1      2    222   beta
# 3      4    111    NaN
# 0      1    111  alpha

# %%
df['col_2'].apply(np.square)
# Out:
# 0     12321
# 1     49284
# 2    110889
# 3     12321
# 4    308025
# Name: col_2, dtype: int64

# %%
df['col_1'].apply(np.square)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: col_1, dtype: int64

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
newdf=df.drop('col_3',axis=1)
newdf
# Out:
#    col_1  col_2
# 0      1    111
# 1      2    222
# 2      3    333
# 3      4    111
# 4      5    555

# %%
newdf=df.copy()
newdf
# Out:
#    col_1  col_2  col_3
# 0      1    111  alpha
# 1      2    222   beta
# 2      3    333  gamma
# 3      4    111    NaN
# 4      5    555    NaN

# %%
aa=df
aa
# Out:
#    col_1  col_2  col_3
# 0      1    111  alpha
# 1      2    222   beta
# 2      3    333  gamma
# 3      4    111    NaN
# 4      5    555    NaN

# %%
df.dropna(thresh=4,axis=1)
# Out:
#    col_2
# 0    111
# 1    222
# 2    333
# 3    111
# 4    555
