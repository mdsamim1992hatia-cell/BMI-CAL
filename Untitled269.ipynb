# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled269.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'order':range(1,100001),
    'customer':np.random.choice(['Alex','Been','Cawe','Drrt','Egg',None,None,None],100000),
    'product':np.random.choice(['APPLE','WWEVB','COMMLA','Deede',None,None,None],100000),
    'quantity':np.random.randint(1,100,100000),
    'price':np.random.randint(1,1000,100000),
}
df=pd.DataFrame(data)
df
# Out:
#         order customer product  quantity  price
# 0           1     None  COMMLA        13    422
# 1           2     Drrt   WWEVB         9    214
# 2           3     Cawe   APPLE        22    437
# 3           4     Alex    None        89    678
# 4           5     Cawe   Deede        33    737
# ...       ...      ...     ...       ...    ...
# 99995   99996     Alex   WWEVB        25    912
# 99996   99997     Been   WWEVB        70    632
# 99997   99998     None    None        37    187
# 99998   99999     Been    None        79    472
# 99999  100000     Drrt   APPLE        33    543
#
# [100000 rows x 5 columns]

# %%
df.head()
# Out:
#    order customer product  quantity  price
# 0      1     None  COMMLA        13    422
# 1      2     Drrt   WWEVB         9    214
# 2      3     Cawe   APPLE        22    437
# 3      4     Alex    None        89    678
# 4      5     Cawe   Deede        33    737

# %%
df.tail()
# Out:
#         order customer product  quantity  price
# 99995   99996     Alex   WWEVB        25    912
# 99996   99997     Been   WWEVB        70    632
# 99997   99998     None    None        37    187
# 99998   99999     Been    None        79    472
# 99999  100000     Drrt   APPLE        33    543

# %%
df.shape
# Out:
# (100000, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100000, step=1)

# %%
df.describe()
# Out:
#                order       quantity          price
# count  100000.000000  100000.000000  100000.000000
# mean    50000.500000      50.073990     500.426400
# std     28867.657797      28.564369     288.712956
# min         1.000000       1.000000       1.000000
# 25%     25000.750000      25.000000     250.000000
# 50%     50000.500000      50.000000     502.000000
# 75%     75000.250000      75.000000     752.000000
# max    100000.000000      99.000000     999.000000

# %%
df.dtypes
# Out:
# order        int64
# customer    object
# product     object
# quantity     int64
# price        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['order', 'customer', 'product', 'quantity', 'price'], dtype='object')

# %%
df['customer']
# Out:
# 0        None
# 1        Drrt
# 2        Cawe
# 3        Alex
# 4        Cawe
#          ...
# 99995    Alex
# 99996    Been
# 99997    None
# 99998    Been
# 99999    Drrt
# Name: customer, Length: 100000, dtype: object

# %%
df[['product','customer']]
# Out:
#       product customer
# 0      COMMLA     None
# 1       WWEVB     Drrt
# 2       APPLE     Cawe
# 3        None     Alex
# 4       Deede     Cawe
# ...       ...      ...
# 99995   WWEVB     Alex
# 99996   WWEVB     Been
# 99997    None     None
# 99998    None     Been
# 99999   APPLE     Drrt
#
# [100000 rows x 2 columns]

# %%
df.loc[1:6,['customer','product']]
# Out:
#   customer product
# 1     Drrt   WWEVB
# 2     Cawe   APPLE
# 3     Alex    None
# 4     Cawe   Deede
# 5     Been    None
# 6     Drrt  COMMLA

# %%
df.loc[5]
# Out:
# order          6
# customer    Been
# product     None
# quantity      27
# price        460
# Name: 5, dtype: object

# %%
df.iloc[2]
# Out:
# order           3
# customer     Cawe
# product     APPLE
# quantity       22
# price         437
# Name: 2, dtype: object

# %%
df.iloc[:6]
# Out:
#    order customer product  quantity  price
# 0      1     None  COMMLA        13    422
# 1      2     Drrt   WWEVB         9    214
# 2      3     Cawe   APPLE        22    437
# 3      4     Alex    None        89    678
# 4      5     Cawe   Deede        33    737
# 5      6     Been    None        27    460

# %%
df.sort_values(by='price',ascending=False)
# Out:
#        order customer product  quantity  price
# 35318  35319     None  COMMLA        33    999
# 79980  79981      Egg   WWEVB        96    999
# 61314  61315     None    None        76    999
# 25015  25016     Drrt    None         3    999
# 6384    6385     Cawe   Deede        38    999
# ...      ...      ...     ...       ...    ...
# 73940  73941     None  COMMLA        73      1
# 26539  26540     Been   APPLE        96      1
# 66998  66999     Cawe  COMMLA        63      1
# 38024  38025     None    None        48      1
# 79741  79742     Drrt    None        78      1
#
# [100000 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# order           0
# customer    37315
# product     42887
# quantity        0
# price           0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(80202)

# %%
df.notna().sum()
# Out:
# order       100000
# customer     62685
# product      57113
# quantity    100000
# price       100000
# dtype: int64

# %%
total_revenue=df['price'].sum()
total_revenue
# Out:
# np.int64(50042640)

# %%
df['product']=df['product'].fillna('unknown')
df
# Out:
#         order customer  product  quantity  price
# 0           1     None   COMMLA        13    422
# 1           2     Drrt    WWEVB         9    214
# 2           3     Cawe    APPLE        22    437
# 3           4     Alex  unknown        89    678
# 4           5     Cawe    Deede        33    737
# ...       ...      ...      ...       ...    ...
# 99995   99996     Alex    WWEVB        25    912
# 99996   99997     Been    WWEVB        70    632
# 99997   99998     None  unknown        37    187
# 99998   99999     Been  unknown        79    472
# 99999  100000     Drrt    APPLE        33    543
#
# [100000 rows x 5 columns]

# %%
df['customer']=df['customer'].fillna('unknown')
df
# Out:
#         order customer  product  quantity  price
# 0           1  unknown   COMMLA        13    422
# 1           2     Drrt    WWEVB         9    214
# 2           3     Cawe    APPLE        22    437
# 3           4     Alex  unknown        89    678
# 4           5     Cawe    Deede        33    737
# ...       ...      ...      ...       ...    ...
# 99995   99996     Alex    WWEVB        25    912
# 99996   99997     Been    WWEVB        70    632
# 99997   99998  unknown  unknown        37    187
# 99998   99999     Been  unknown        79    472
# 99999  100000     Drrt    APPLE        33    543
#
# [100000 rows x 5 columns]

# %%
df['total_sales']=df['quantity']*df['price']
df
# Out:
#         order customer  product  quantity  price  total_sales
# 0           1  unknown   COMMLA        13    422         5486
# 1           2     Drrt    WWEVB         9    214         1926
# 2           3     Cawe    APPLE        22    437         9614
# 3           4     Alex  unknown        89    678        60342
# 4           5     Cawe    Deede        33    737        24321
# ...       ...      ...      ...       ...    ...          ...
# 99995   99996     Alex    WWEVB        25    912        22800
# 99996   99997     Been    WWEVB        70    632        44240
# 99997   99998  unknown  unknown        37    187         6919
# 99998   99999     Been  unknown        79    472        37288
# 99999  100000     Drrt    APPLE        33    543        17919
#
# [100000 rows x 6 columns]

# %%
total_revenue=df['total_sales'].sum()
total_revenue
# Out:
# np.int64(2503960046)

# %%
customer_sales=df.groupby('customer')['total_sales'].sum()
customer_sales
# Out:
# customer
# Alex       314949585
# Been       312748061
# Cawe       312477230
# Drrt       313893941
# Egg        315892136
# unknown    933999093
# Name: total_sales, dtype: int64

# %%
product_sales=df.groupby('product')['total_sales'].sum()
product_sales
# Out:
# product
# APPLE       351233987
# COMMLA      361182003
# Deede       353965409
# WWEVB       357888574
# unknown    1079690073
# Name: total_sales, dtype: int64

# %%
top_customer=customer_sales.idxmax()
top_customer
# Out:
# 'unknown'

# %%
top_product=product_sales.idxmax()
top_product
# Out:
# 'unknown'

# %%
avg_sales=df['total_sales'].mean()
avg_sales
# Out:
# np.float64(25039.60046)

# %%
customer_avg=df.groupby('customer')['total_sales'].mean()
customer_avg
# Out:
# customer
# Alex       25043.701097
# Been       25035.867835
# Cawe       24729.125514
# Drrt       25265.127254
# Egg        25156.656526
# unknown    25030.124427
# Name: total_sales, dtype: float64

# %%
df.groupby(['customer','product'])['total_sales'].sum()
# Out:
# customer  product
# Alex      APPLE       43092979
#           COMMLA      46522454
#           Deede       45966082
#           WWEVB       44721648
#           unknown    134646422
# Been      APPLE       43665876
#           COMMLA      45326415
#           Deede       43975846
#           WWEVB       43774561
#           unknown    136005363
# Cawe      APPLE       45354877
#           COMMLA      44318854
#           Deede       43062946
#           WWEVB       44024377
#           unknown    135716176
# Drrt      APPLE       44840853
#           COMMLA      46183716
#           Deede       45568095
#           WWEVB       43697734
#           unknown    133603543
# Egg       APPLE       42977385
#           COMMLA      45802573
#           Deede       44323660
#           WWEVB       46316591
#           unknown    136471927
# unknown   APPLE      131302017
#           COMMLA     133027991
#           Deede      131068780
#           WWEVB      135353663
# ...

# %%
df.groupby('product').agg({
    'total_sales':'sum',
    'quantity':'sum'
})
# Out:
#          total_sales  quantity
# product
# APPLE      351233987    704759
# COMMLA     361182003    726346
# Deede      353965409    706579
# WWEVB      357888574    719495
# unknown   1079690073   2150220

# %%
df.groupby('customer').agg({
    'total_sales':'sum',
    'quantity':'sum'
})
# Out:
#           total_sales  quantity
# customer
# Alex        314949585    630374
# Been        312748061    624099
# Cawe        312477230    629105
# Drrt        313893941    623540
# Egg         315892136    627700
# unknown     933999093   1872581

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='customer')
plt.title('Customer Distribution')
plt.xlabel('Customer')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='product',order=df['product'].value_counts().index)
plt.xlabel('Product')
plt.ylabel('Count')
plt.title('Product Distribution')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='total_sales',bins=20,kde=True)
plt.xlabel('Total Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Total Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='customer',y='total_sales')
plt.xlabel('Customer')
plt.ylabel('Total Sales')
plt.title('Total Sales by Customer')
# Out:
# Text(0.5, 1.0, 'Total Sales by Customer')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='product',y='total_sales')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.title('Total Sales by Product')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='quantity',y='total_sales',hue='customer')
plt.xlabel('Quantity')
plt.ylabel('Total Sales')
plt.title('Quantity vs Total Sales')
plt.show()

# %%
df1=pd.DataFrame({
    'key':['A','B','C','D'],
    'a1':[1,2,3,4],
    'a2':[5,6,7,8]
})
df1
# Out:
#   key  a1  a2
# 0   A   1   5
# 1   B   2   6
# 2   C   3   7
# 3   D   4   8

# %%
df2=pd.DataFrame({
    'key':['A','B','C','D'],
    'b1':[3,4,5,6],
    'b2':[7,8,9,10]
})
df2
# Out:
#   key  b1  b2
# 0   A   3   7
# 1   B   4   8
# 2   C   5   9
# 3   D   6  10

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  a1  a2  b1  b2
# 0   A   1   5   3   7
# 1   B   2   6   4   8
# 2   C   3   7   5   9
# 3   D   4   8   6  10

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  a1  a2  b1  b2
# 0   A   1   5   3   7
# 1   B   2   6   4   8
# 2   C   3   7   5   9
# 3   D   4   8   6  10

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  a1  a2  b1  b2
# 0   A   1   5   3   7
# 1   B   2   6   4   8
# 2   C   3   7   5   9
# 3   D   4   8   6  10

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key  a1  a2  b1  b2
# 0   A   1   5   3   7
# 1   B   2   6   4   8
# 2   C   3   7   5   9
# 3   D   4   8   6  10
