# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
climate_data={
    'day':['1/1/2023','1/2/2024','1/3/2025'],
    'tempareture':[21,54,32],
    'windspeed':[3,6,9],
    'event':['cloudy','rainy','sunny'],
}
df=pd.DataFrame(climate_data)
df
# Out:
#         day  tempareture  windspeed   event
# 0  1/1/2023           21          3  cloudy
# 1  1/2/2024           54          6   rainy
# 2  1/3/2025           32          9   sunny

# %%
climate_data=[
    ('1/1/2023',27,26,'cloudy'),
    ('1/2/2024',28,27,'rainy'),
    ('1/5/2023',55,23,'sunny'),
]
df=pd.DataFrame(climate_data,index=['x','y','z'], columns=['day','tempareture','windspeed','event'])
df
# Out:
#         day  tempareture  windspeed   event
# x  1/1/2023           27         26  cloudy
# y  1/2/2024           28         27   rainy
# z  1/5/2023           55         23   sunny

# %%
climate_data=[
    {'day':'1/1/2023','tempareture':27,'windspeed':26,'event':'cloudy'},
    {'day':'1/2/2024','tempareture':28,'windspeed':2,'event':'rainy'},
    {'day':'1/3/2025','tempareture':55,'windspeed':23,'event':'sunny'},
]

df=pd.DataFrame(climate_data)
df
# Out:
#         day  tempareture  windspeed   event
# 0  1/1/2023           27         26  cloudy
# 1  1/2/2024           28          2   rainy
# 2  1/3/2025           55         23   sunny
