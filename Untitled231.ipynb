# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'order':range(1,11),
    'store':['dhaka','khulna','rajsahi','dhaka','khulna','noakhali','rongpur','akali','dhaka','khulna'],
    'customer':['alex','noamm','reag','alex','noamm','reag','alex','noamm','reag','alex'],
    'quantity':[55,55,5252,2525,2525,232,np.nan,np.nan,np.nan,np.nan],
    'price':[222,55,55,55,5252,2525,252,None,None,None],
    'data':pd.date_range('20220101',periods=10)

}
df=pd.DataFrame(data)
print("===raw data===")
print(df)
# Out:
# ===raw data===
#    order     store customer  quantity   price       data
# 0      1     dhaka     alex      55.0   222.0 2022-01-01
# 1      2    khulna    noamm      55.0    55.0 2022-01-02
# 2      3   rajsahi     reag    5252.0    55.0 2022-01-03
# 3      4     dhaka     alex    2525.0    55.0 2022-01-04
# 4      5    khulna    noamm    2525.0  5252.0 2022-01-05
# 5      6  noakhali     reag     232.0  2525.0 2022-01-06
# 6      7   rongpur     alex       NaN   252.0 2022-01-07
# 7      8     akali    noamm       NaN     NaN 2022-01-08
# 8      9     dhaka     reag       NaN     NaN 2022-01-09
# 9     10    khulna     alex       NaN     NaN 2022-01-10

# %%
df.isna().sum()
# Out:
# order       0
# store       0
# customer    0
# quantity    4
# price       3
# dtype: int64

# %%
df['price']=df['price'].fillna(0)
df
# Out:
#    order     store customer  quantity   price
# 0      1     dhaka     alex      55.0   222.0
# 1      2    khulna    noamm      55.0    55.0
# 2      3   rajsahi     reag    5252.0    55.0
# 3      4     dhaka     alex    2525.0    55.0
# 4      5    khulna    noamm    2525.0  5252.0
# 5      6  noakhali     reag     232.0  2525.0
# 6      7   rongpur     alex       NaN   252.0
# 7      8     akali    noamm       NaN     0.0
# 8      9     dhaka     reag       NaN     0.0
# 9     10    khulna     alex       NaN     0.0

# %%
df['quantity']=df['quantity'].fillna(df['quantity'].mean())
df
# Out:
#    order     store customer  quantity   price
# 0      1     dhaka     alex      55.0   222.0
# 1      2    khulna    noamm      55.0    55.0
# 2      3   rajsahi     reag    5252.0    55.0
# 3      4     dhaka     alex    2525.0    55.0
# 4      5    khulna    noamm    2525.0  5252.0
# 5      6  noakhali     reag     232.0  2525.0
# 6      7   rongpur     alex    1774.0   252.0
# 7      8     akali    noamm    1774.0     0.0
# 8      9     dhaka     reag    1774.0     0.0
# 9     10    khulna     alex    1774.0     0.0

# %%
df['data']=pd.to_datetime(df['data'])
df
# Out:
#    order     store customer  quantity   price       data
# 0      1     dhaka     alex      55.0   222.0 2022-01-01
# 1      2    khulna    noamm      55.0    55.0 2022-01-02
# 2      3   rajsahi     reag    5252.0    55.0 2022-01-03
# 3      4     dhaka     alex    2525.0    55.0 2022-01-04
# 4      5    khulna    noamm    2525.0  5252.0 2022-01-05
# 5      6  noakhali     reag     232.0  2525.0 2022-01-06
# 6      7   rongpur     alex       NaN   252.0 2022-01-07
# 7      8     akali    noamm       NaN     NaN 2022-01-08
# 8      9     dhaka     reag       NaN     NaN 2022-01-09
# 9     10    khulna     alex       NaN     NaN 2022-01-10

# %%
store_total_sales=df.groupby('store')['quantity'].sum()
print(store_total_sales)
# Out:
# store
# akali          0.0
# dhaka       2580.0
# khulna      2580.0
# noakhali     232.0
# rajsahi     5252.0
# rongpur        0.0
# Name: quantity, dtype: float64

# %%
df['total_sales']=df['quantity']*df['price']
print(df)
# Out:
#    order     store customer  quantity   price       data  total_sales
# 0      1     dhaka     alex      55.0   222.0 2022-01-01      12210.0
# 1      2    khulna    noamm      55.0    55.0 2022-01-02       3025.0
# 2      3   rajsahi     reag    5252.0    55.0 2022-01-03     288860.0
# 3      4     dhaka     alex    2525.0    55.0 2022-01-04     138875.0
# 4      5    khulna    noamm    2525.0  5252.0 2022-01-05   13261300.0
# 5      6  noakhali     reag     232.0  2525.0 2022-01-06     585800.0
# 6      7   rongpur     alex       NaN   252.0 2022-01-07          NaN
# 7      8     akali    noamm       NaN     NaN 2022-01-08          NaN
# 8      9     dhaka     reag       NaN     NaN 2022-01-09          NaN
# 9     10    khulna     alex       NaN     NaN 2022-01-10          NaN

# %%
store_avg_sales=df.groupby('store')['total_sales'].mean()
print(store_avg_sales)
# Out:
# store
# akali             NaN
# dhaka         75542.5
# khulna      6632162.5
# noakhali     585800.0
# rajsahi      288860.0
# rongpur           NaN
# Name: total_sales, dtype: float64

# %%
daily_sales=df.groupby('data')['total_sales'].sum()
print(daily_sales)
# Out:
# data
# 2022-01-01       12210.0
# 2022-01-02        3025.0
# 2022-01-03      288860.0
# 2022-01-04      138875.0
# 2022-01-05    13261300.0
# 2022-01-06      585800.0
# 2022-01-07           0.0
# 2022-01-08           0.0
# 2022-01-09           0.0
# 2022-01-10           0.0
# Name: total_sales, dtype: float64

# %%
top_3_stores=store_total_sales.nlargest(3)
print(top_3_stores)
# Out:
# store
# rajsahi    5252.0
# dhaka      2580.0
# khulna     2580.0
# Name: quantity, dtype: float64

# %%
top_3_order=df.nlargest(3,'total_sales')
print(top_3_order)
# Out:
#    order     store customer  quantity   price       data  total_sales
# 4      5    khulna    noamm    2525.0  5252.0 2022-01-05   13261300.0
# 5      6  noakhali     reag     232.0  2525.0 2022-01-06     585800.0
# 2      3   rajsahi     reag    5252.0    55.0 2022-01-03     288860.0

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=store_total_sales.index,y=store_total_sales.values)
plt.xlabel('Store')
plt.ylabel('Total Sales')
plt.title('Total Sales by Store')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=daily_sales.index,y=daily_sales.values)
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.title('Daily Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=store_avg_sales.index,y=store_avg_sales.values)
plt.xlabel
plt.ylabel
plt.title
plt.show()
#
