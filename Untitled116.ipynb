# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled116.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dic={
    'col_1':[1,2,3,4,5],
    'col-2':[111,222,333,111,555],
    'col_3':['alapha','brabo','cherry',np.nan,np.nan]
}
df=pd.DataFrame(data_dic)
df
# Out:
#    col_1  col-2   col_3
# 0      1    111  alapha
# 1      2    222   brabo
# 2      3    333  cherry
# 3      4    111     NaN
# 4      5    555     NaN

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df['col-2'].unique()
# Out:
# array([111, 222, 333, 555])

# %%
print(df['col-2'].nunique())
print(df['col_3'].nunique())
print(df['col_1'].nunique())
# Out:
# 4
# 3
# 5

# %%
print(df['col-2'].nunique())
print(df['col_3'].nunique())
print(df['col_1'].nunique())
# Out:
# 4
# 3
# 5

# %%
df['col-2'].value_counts()
# Out:
# col-2
# 111    2
# 222    1
# 333    1
# 555    1
# Name: count, dtype: int64

# %%
df['col_1'].value_counts()
# Out:
# col_1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64

# %%
df['col_3'].value_counts()
# Out:
# col_3
# alapha    1
# brabo     1
# cherry    1
# Name: count, dtype: int64

# %%
df['col-2'].count()
# Out:
# np.int64(5)

# %%
df.sort_values(by=['col_1'],ascending=False)
# Out:
#    col_1  col-2   col_3
# 4      5    555     NaN
# 3      4    111     NaN
# 2      3    333  cherry
# 1      2    222   brabo
# 0      1    111  alapha

# %%
df.sort_values(by=['col_1'],ascending=True)
# Out:
#    col_1  col-2   col_3
# 0      1    111  alapha
# 1      2    222   brabo
# 2      3    333  cherry
# 3      4    111     NaN
# 4      5    555     NaN

# %%
df.sort_values(by=['col_3'],ascending=False)
# Out:
#    col_1  col-2   col_3
# 2      3    333  cherry
# 1      2    222   brabo
# 0      1    111  alapha
# 3      4    111     NaN
# 4      5    555     NaN

# %%
df.sort_values(by=['col_3'],ascending=True)
# Out:
#    col_1  col-2   col_3
# 0      1    111  alapha
# 1      2    222   brabo
# 2      3    333  cherry
# 3      4    111     NaN
# 4      5    555     NaN

# %%
def square(value):
    return value*value

# %%
square(5)
# Out:
# 25

# %%
df['col_1'].apply(square)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: col_1, dtype: int64

# %%
df['col-2'].apply(square)
# Out:
# 0     12321
# 1     49284
# 2    110889
# 3     12321
# 4    308025
# Name: col-2, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['col_1', 'col-2', 'col_3'], dtype='object')

# %%
newdf=df
aa=df.copy()
aa
# Out:
#    col_1  col-2   col_3
# 0      1    111  alapha
# 1      2    222   brabo
# 2      3    333  cherry
# 3      4    111     NaN
# 4      5    555     NaN

# %%
del aa['col_3']
aa
# Out:
#    col_1  col-2
# 0      1    111
# 1      2    222
# 2      3    333
# 3      4    111
# 4      5    555
