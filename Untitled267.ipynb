# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled267.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'order':range(1,100001),
    'product':np.random.choice(['A','B','C'],100000),
    'quantity':np.random.randint(1,5,100000),
    'customer':np.random.choice(['customer1','customer2','customer3'],100000),
    'price':np.random.randint(10,100,100000),
}
df=pd.DataFrame(data)
print(df)
# Out:
#         order product  quantity   customer  price
# 0           1       A         2  customer3     75
# 1           2       C         3  customer1     68
# 2           3       B         1  customer2     85
# 3           4       C         2  customer1     53
# 4           5       C         1  customer1     95
# ...       ...     ...       ...        ...    ...
# 99995   99996       B         2  customer3     45
# 99996   99997       C         3  customer1     50
# 99997   99998       C         1  customer1     30
# 99998   99999       A         2  customer1     72
# 99999  100000       A         1  customer2     30
#
# [100000 rows x 5 columns]

# %%
df.groupby('customer')['price'].sum()
# Out:
# customer
# customer1    1816019
# customer2    1807640
# customer3    1828676
# Name: price, dtype: int64

# %%
df.groupby(['product','customer'])['quantity'].sum()
# Out:
# product  customer
# A        customer1    27534
#          customer2    27942
#          customer3    27542
# B        customer1    27594
#          customer2    27665
#          customer3    27745
# C        customer1    27967
#          customer2    27586
#          customer3    27976
# Name: quantity, dtype: int64

# %%
df.groupby(['order','product'])['price'].sum()
# Out:
# order   product
# 1       A          75
# 2       C          68
# 3       B          85
# 4       C          53
# 5       C          95
#                    ..
# 99996   B          45
# 99997   C          50
# 99998   C          30
# 99999   A          72
# 100000  A          30
# Name: price, Length: 100000, dtype: int64

# %%
df['total_sales']=df['price']*df['quantity']
df
# Out:
#         order product  quantity   customer  price  total_sales
# 0           1       A         2  customer3     75          150
# 1           2       C         3  customer1     68          204
# 2           3       B         1  customer2     85           85
# 3           4       C         2  customer1     53          106
# 4           5       C         1  customer1     95           95
# ...       ...     ...       ...        ...    ...          ...
# 99995   99996       B         2  customer3     45           90
# 99996   99997       C         3  customer1     50          150
# 99997   99998       C         1  customer1     30           30
# 99998   99999       A         2  customer1     72          144
# 99999  100000       A         1  customer2     30           30
#
# [100000 rows x 6 columns]

# %%
df.groupby(['product','customer'])['total_sales'].sum()
# Out:
# product  customer
# A        customer1    1502444
#          customer2    1523696
#          customer3    1510717
# B        customer1    1507523
#          customer2    1504725
#          customer3    1517006
# C        customer1    1522746
#          customer2    1488367
#          customer3    1534453
# Name: total_sales, dtype: int64

# %%
df.groupby(['price','quantity'])['total_sales'].sum()
# Out:
# price  quantity
# 10     1             3150
#        2             5680
#        3             8370
#        4            11480
# 11     1             3190
#                     ...
# 98     4           111328
# 99     1            28215
#        2            57222
#        3            85536
#        4           114840
# Name: total_sales, Length: 360, dtype: int64

# %%
df.groupby('product').agg({
    'quantity':'sum',
    'price':'mean',
    'total_sales':'sum'
})
# Out:
#          quantity      price  total_sales
# product
# A           83018  54.636787      4536857
# B           83004  54.525961      4529254
# C           83529  54.407914      4545566

# %%
df.groupby('customer').agg({
    'order':'count',
    'total_sales':'sum'
})
# Out:
#            order  total_sales
# customer
# customer1  33283      4532713
# customer2  33288      4516788
# customer3  33429      4562176

# %%
df.groupby('product').agg({
    'quantity':'sum',
    'price':'mean',
    'total_sales':'sum'
})
# Out:
#          quantity      price  total_sales
# product
# A           83018  54.636787      4536857
# B           83004  54.525961      4529254
# C           83529  54.407914      4545566

# %%
df.groupby('customer').agg({
    'order':'count',
    'total_sales':'sum'
})
# Out:
#            order  total_sales
# customer
# customer1  33283      4532713
# customer2  33288      4516788
# customer3  33429      4562176

# %%
df.groupby('product').agg({
    'quantity':'sum',
    'price':'mean',
    'total_sales':'sum'
} )
# Out:
#          quantity      price  total_sales
# product
# A           83018  54.636787      4536857
# B           83004  54.525961      4529254
# C           83529  54.407914      4545566

# %%
df.groupby('product')['price'].agg(['count','mean','max','min','sum'])
# Out:
#          count       mean  max  min      sum
# product
# A        33311  54.636787   99   10  1820006
# B        33204  54.525961   99   10  1810480
# C        33485  54.407914   99   10  1821849

# %%
df.groupby('customer')['total_sales'].agg(['count','mean','max','min','sum'])
# Out:
#            count        mean  max  min      sum
# customer
# customer1  33283  136.187032  396   10  4532713
# customer2  33288  135.688176  396   10  4516788
# customer3  33429  136.473601  396   10  4562176

# %%
total_revenue=df['total_sales'].sum()
print(total_revenue)
# Out:
# 13611677

# %%
total_revenue=df['total_sales'].sum()
print(total_revenue)
# Out:
# 13611677

# %%
customer_sales=df.groupby('customer')['total_sales'].sum()
print(customer_sales)
# Out:
# customer
# customer1    4532713
# customer2    4516788
# customer3    4562176
# Name: total_sales, dtype: int64

# %%
total_revenue=df['total_sales'].sum()
print(total_revenue)
# Out:
# 13611677

# %%
customer_sales=df.groupby('customer')['total_sales'].sum()
print(customer_sales)
# Out:
# customer
# customer1    4532713
# customer2    4516788
# customer3    4562176
# Name: total_sales, dtype: int64

# %%
top_customer=customer_sales.idxmax()
print(top_customer)
# Out:
# customer3

# %%
lowes_customer=customer_sales.idxmin()
print(lowes_customer)
# Out:
# customer2

# %%
product_sales=df.groupby('product')['total_sales'].sum()
print(product_sales )
# Out:
# product
# A    4536857
# B    4529254
# C    4545566
# Name: total_sales, dtype: int64

# %%
top_product=product_sales.idxmax()
print(top_product)
# Out:
# C

# %%
avg_order_value=df['total_sales'].mean()
print(avg_order_value)
# Out:
# 136.11677

# %%
customer_avg=df.groupby('customer')['total_sales'].mean()
print(customer_avg)
# Out:
# customer
# customer1    136.187032
# customer2    135.688176
# customer3    136.473601
# Name: total_sales, dtype: float64

# %%
top_order=df.groupby('order')['total_sales'].sum().idxmax()
print(top_order)
# Out:
# 141

# %%
df.groupby(['product','price'])['total_sales'].sum()
# Out:
# product  price
# A        10       10010
#          11        9724
#          12        9984
#          13       11609
#          14       14770
#                   ...
# C        95       82080
#          96       83808
#          97       93605
#          98       93002
#          99       94446
# Name: total_sales, Length: 270, dtype: int64

# %%
df.groupby(['customer','product'])['total_sales'].sum()
# Out:
# customer   product
# customer1  A          1502444
#            B          1507523
#            C          1522746
# customer2  A          1523696
#            B          1504725
#            C          1488367
# customer3  A          1510717
#            B          1517006
#            C          1534453
# Name: total_sales, dtype: int64

# %%
df.groupby('product').agg({
    'quantity':'sum',
    'price':'mean',
    'total_sales':'sum'
})
# Out:
#          quantity      price  total_sales
# product
# A           83018  54.636787      4536857
# B           83004  54.525961      4529254
# C           83529  54.407914      4545566

# %%
df.groupby('customer').agg({
    'order':'count',
    'total_sales':'sum'
})
# Out:
#            order  total_sales
# customer
# customer1  33283      4532713
# customer2  33288      4516788
# customer3  33429      4562176

# %%
df.groupby('product').agg({
    'quantity':'sum',
    'price':'mean',
    'total_sales':'sum'
})
# Out:
#          quantity      price  total_sales
# product
# A           83018  54.636787      4536857
# B           83004  54.525961      4529254
# C           83529  54.407914      4545566

# %%
top_revenue=df.groupby('customer')['total_sales'].sum().idxmax()
print(top_revenue)
# Out:
# customer3

# %%
total_revenue=df['total_sales'].sum()
print(total_revenue)
# Out:
# 13611677

# %%
customer_sales=df.groupby('customer')['total_sales'].sum()
print(customer_sales)
# Out:
# customer
# customer1    4532713
# customer2    4516788
# customer3    4562176
# Name: total_sales, dtype: int64

# %%
top_customer=customer_sales.idxmax()
print(top_customer)
# Out:
# customer3

# %%
product_sales=df.groupby('product')['total_sales'].sum()
print(product_sales)
# Out:
# product
# A    4536857
# B    4529254
# C    4545566
# Name: total_sales, dtype: int64

# %%
top_product=product_sales.idxmax()
print(top_product)

# %%
avg_order_value=df['total_sales'].mean()
print(avg_order_value)
# Out:
# 136.11677

# %%
customer_avg=df.groupby('customer')['total_sales'].mean()
print(customer_avg)
# Out:
# customer
# customer1    136.187032
# customer2    135.688176
# customer3    136.473601
# Name: total_sales, dtype: float64

# %%
_
