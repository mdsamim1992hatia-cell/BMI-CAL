# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled115.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dic={
    'a':[1,2,None,4,np.nan],
    'b':[np.nan,np.nan,np.nan,np.nan,np.nan],
    'c':[16,np.nan,18,19,20],
    'd':[21,22,23,24,25]
}
df=pd.DataFrame(data_dic)
df
# Out:
#      a   b     c   d
# 0  1.0 NaN  16.0  21
# 1  2.0 NaN   NaN  22
# 2  NaN NaN  18.0  23
# 3  4.0 NaN  19.0  24
# 4  NaN NaN  20.0  25

# %%
df['c'].fillna(value=df['c'].mean())
# Out:
# 0    16.00
# 1    18.25
# 2    18.00
# 3    19.00
# 4    20.00
# Name: c, dtype: float64

# %%
df.fillna(method='ffill')
# Out:
# /tmp/ipython-input-253117906.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#      a   b     c   d
# 0  1.0 NaN  16.0  21
# 1  2.0 NaN  16.0  22
# 2  2.0 NaN  18.0  23
# 3  4.0 NaN  19.0  24
# 4  4.0 NaN  20.0  25

# %%
df.fillna(method='bfill')
# Out:
# /tmp/ipython-input-2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#      a   b     c   d
# 0  1.0 NaN  16.0  21
# 1  2.0 NaN  18.0  22
# 2  4.0 NaN  18.0  23
# 3  4.0 NaN  19.0  24
# 4  NaN NaN  20.0  25

# %%
from  sklearn.impute import SimpleImputer
df2=df.copy()
imputer=SimpleImputer(missing_values=np.nan,strategy='constant')
df
# Out:
#      a   b     c   d
# 0  1.0 NaN  16.0  21
# 1  2.0 NaN   NaN  22
# 2  NaN NaN  18.0  23
# 3  4.0 NaN  19.0  24
# 4  NaN NaN  20.0  25

# %%
df2['a']=imputer.fit_transform(df2[['a']])
df2
# Out:
#           a   b     c   d
# 0  1.000000 NaN  16.0  21
# 1  2.000000 NaN   NaN  22
# 2  2.333333 NaN  18.0  23
# 3  4.000000 NaN  19.0  24
# 4  2.333333 NaN  20.0  25

# %%
from sklearn.impute import SimpleImputer
df2=df.copy()
imputer=SimpleImputer(missing_values=np.nan,strategy='mood')
df
# Out:
#      a   b     c   d
# 0  1.0 NaN  16.0  21
# 1  2.0 NaN   NaN  22
# 2  NaN NaN  18.0  23
# 3  4.0 NaN  19.0  24
# 4  NaN NaN  20.0  25
