# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled169.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# %%
conn=sqlite3.connect('test.db')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data1=np.random.randn(700,4)
data1
# Out:
# array([[ 0.64503344,  0.15216671,  1.10642111,  0.92688177],
#        [ 0.91841112, -1.09875549, -1.41427195,  0.75762692],
#        [ 0.56063109, -0.78304432, -0.15894117, -1.34196722],
#        ...,
#        [ 0.10176443,  0.26222468,  0.60857171,  1.03109073],
#        [-0.29511614,  0.65180498, -3.14035748, -1.49352088],
#        [ 0.46568532,  0.26893106, -0.08917059,  0.80792751]])

# %%
data1.shape
# Out:
# (700, 4)

# %%
df1=pd.DataFrame(data=data1,columns=['A','B','C','D'])
df1
# Out:
#             A         B         C         D
# 0    0.645033  0.152167  1.106421  0.926882
# 1    0.918411 -1.098755 -1.414272  0.757627
# 2    0.560631 -0.783044 -0.158941 -1.341967
# 3    1.422845 -0.155355  0.446292 -0.911080
# 4   -0.964654 -0.111220 -1.246052 -0.498104
# ..        ...       ...       ...       ...
# 695 -1.040553  0.323960 -1.494209  0.404704
# 696  1.576571  0.574421  0.897446 -0.845634
# 697  0.101764  0.262225  0.608572  1.031091
# 698 -0.295116  0.651805 -3.140357 -1.493521
# 699  0.465685  0.268931 -0.089171  0.807928
#
# [700 rows x 4 columns]

# %%
data2=np.random.randn(20,3)
data2
# Out:
# array([[ 0.57671184, -1.19450985,  0.53034995],
#        [-0.36401501, -1.23377613, -0.46043535],
#        [-2.22337762, -1.03768882,  0.53972907],
#        [ 0.17273183, -1.46063957, -0.91215665],
#        [-0.44710448, -0.98177108,  0.69906708],
#        [-0.74269354,  0.56811841,  0.23449852],
#        [-2.63926987, -1.42571484, -0.35179236],
#        [ 0.1641409 , -0.08212856,  0.55098663],
#        [-0.04705628, -1.067901  , -0.76767882],
#        [-0.62255955,  2.17425802,  0.15314761],
#        [ 0.82314378, -0.25155165, -1.27663993],
#        [ 0.54988951,  0.03932735, -0.28885757],
#        [ 0.08413033,  0.98128842, -0.40840274],
#        [ 0.11860946, -0.11297898, -0.20893454],
#        [ 0.39607387, -0.68210396, -1.50022662],
#        [ 0.01415434, -0.27578691,  1.05100768],
#        [ 0.003287  ,  1.0264546 , -0.30363397],
#        [-1.03497184, -0.361631  , -1.13616469],
#        [ 1.02687619, -0.29767287,  0.86047351],
# ...

# %%
df1['E']=np.random.randn(700)
df1
# Out:
#             A         B         C         D         E
# 0    0.645033  0.152167  1.106421  0.926882  1.892217
# 1    0.918411 -1.098755 -1.414272  0.757627 -0.977776
# 2    0.560631 -0.783044 -0.158941 -1.341967  1.302092
# 3    1.422845 -0.155355  0.446292 -0.911080  0.835547
# 4   -0.964654 -0.111220 -1.246052 -0.498104  1.559320
# ..        ...       ...       ...       ...       ...
# 695 -1.040553  0.323960 -1.494209  0.404704  0.836126
# 696  1.576571  0.574421  0.897446 -0.845634 -0.105632
# 697  0.101764  0.262225  0.608572  1.031091  0.820391
# 698 -0.295116  0.651805 -3.140357 -1.493521 -0.602169
# 699  0.465685  0.268931 -0.089171  0.807928 -0.429706
#
# [700 rows x 5 columns]

# %%
col=['x','y','z']
df2=pd.DataFrame(data=data2,columns=col)
df2
# Out:
#            x         y         z
# 0   0.576712 -1.194510  0.530350
# 1  -0.364015 -1.233776 -0.460435
# 2  -2.223378 -1.037689  0.539729
# 3   0.172732 -1.460640 -0.912157
# 4  -0.447104 -0.981771  0.699067
# 5  -0.742694  0.568118  0.234499
# 6  -2.639270 -1.425715 -0.351792
# 7   0.164141 -0.082129  0.550987
# 8  -0.047056 -1.067901 -0.767679
# 9  -0.622560  2.174258  0.153148
# 10  0.823144 -0.251552 -1.276640
# 11  0.549890  0.039327 -0.288858
# 12  0.084130  0.981288 -0.408403
# 13  0.118609 -0.112979 -0.208935
# 14  0.396074 -0.682104 -1.500227
# 15  0.014154 -0.275787  1.051008
# 16  0.003287  1.026455 -0.303634
# 17 -1.034972 -0.361631 -1.136165
# 18  1.026876 -0.297673  0.860474
# 19 -2.241544 -1.234283  0.761611

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['B'].hist()
# Out:
# <Axes: >

# %%
df1['C'].hist(edgecolor='black',color='red')
# Out:
# <Axes: >

# %%
df2['x'].hist()
# Out:
# <Axes: >

# %%
df2['z'].hist(edgecolor='black',color='red')
# Out:
# <Axes: >

# %%
df2.plot.line(x='x',y='z',figsize=(10,10))
# Out:
# <Axes: xlabel='x'>

# %%
df1['D'].hist(edgecolor='black',color='red')
# Out:
# <Axes: >

# %%
df2['y'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
from numpy.random.mtrand import f
df1['A'].plot.bar(figsize=(10,10))
# Out:
# <Axes: >

# %%
data1=np.random.randn(400,4)
data1
# Out:
# array([[-1.0592849 , -0.77532601,  0.65764478,  0.14263655],
#        [ 0.62728422, -0.90208405, -0.69913371, -0.4138064 ],
#        [-0.75502005,  2.24438283, -1.85864466,  0.94353531],
#        ...,
#        [ 1.02886096, -0.45777955, -1.94535754,  0.32872857],
#        [-0.59534003,  1.71316775,  0.88069762, -0.04679967],
#        [-0.91144206,  0.16784125,  0.58740288, -0.17234899]])

# %%
data1.shape
# Out:
# (400, 4)

# %%
df1=pd.DataFrame(data=data1,columns=['w','e','r','t'])
df1
# Out:
#             w         e         r         t
# 0   -1.059285 -0.775326  0.657645  0.142637
# 1    0.627284 -0.902084 -0.699134 -0.413806
# 2   -0.755020  2.244383 -1.858645  0.943535
# 3   -0.626296 -1.200954 -1.035907 -1.018281
# 4    0.849027 -0.449384  2.068294 -1.244642
# ..        ...       ...       ...       ...
# 395 -0.164907 -0.835232 -0.851135  0.069771
# 396 -1.211799  1.349749  2.168652  1.336797
# 397  1.028861 -0.457780 -1.945358  0.328729
# 398 -0.595340  1.713168  0.880698 -0.046800
# 399 -0.911442  0.167841  0.587403 -0.172349
#
# [400 rows x 4 columns]

# %%
df1['g']=np.random.randn(400)
df1
# Out:
#             w         e         r         t         g
# 0   -1.059285 -0.775326  0.657645  0.142637 -1.154981
# 1    0.627284 -0.902084 -0.699134 -0.413806 -0.154466
# 2   -0.755020  2.244383 -1.858645  0.943535 -0.257329
# 3   -0.626296 -1.200954 -1.035907 -1.018281  0.742530
# 4    0.849027 -0.449384  2.068294 -1.244642  0.428404
# ..        ...       ...       ...       ...       ...
# 395 -0.164907 -0.835232 -0.851135  0.069771 -1.645467
# 396 -1.211799  1.349749  2.168652  1.336797 -0.256141
# 397  1.028861 -0.457780 -1.945358  0.328729  1.105907
# 398 -0.595340  1.713168  0.880698 -0.046800 -0.398640
# 399 -0.911442  0.167841  0.587403 -0.172349  2.061771
#
# [400 rows x 5 columns]

# %%
data2=np.random.randn(20,3)
data2
# Out:
# array([[-0.12793869, -0.64254051, -0.61863484],
#        [ 0.15501229, -0.11525013,  0.01067594],
#        [-1.11236829, -0.65539738,  0.33796365],
#        [-0.36661354,  2.47784098,  0.02693597],
#        [ 0.76519003, -0.00726638,  0.31243523],
#        [-1.2518165 , -0.75968382,  1.14491645],
#        [-0.02621088,  1.1241752 , -0.35711578],
#        [-1.24154155,  0.22890891,  0.32645718],
#        [-0.85552456,  0.93559621, -0.23651221],
#        [ 0.07541284,  2.46676118, -0.04026589],
#        [ 0.35004045,  0.82348649,  0.73126837],
#        [-0.83568918,  2.24787552,  0.28403187],
#        [-0.55519032,  2.39573442, -0.60770334],
#        [-0.10606202, -0.87795941,  0.360629  ],
#        [-1.20166511,  0.77456849, -0.11541998],
#        [-0.33802012, -1.21551738,  1.09447024],
#        [-0.00688829,  0.68926363,  0.72712406],
#        [-0.44414859, -0.04198562,  0.14636877],
#        [-0.05521985,  1.18058125,  0.76409479],
# ...

# %%
column=['a','s','d']
df2=pd.DataFrame(data=data2,columns=['a','s','d'])
df2
# Out:
#            a         s         d
# 0  -0.127939 -0.642541 -0.618635
# 1   0.155012 -0.115250  0.010676
# 2  -1.112368 -0.655397  0.337964
# 3  -0.366614  2.477841  0.026936
# 4   0.765190 -0.007266  0.312435
# 5  -1.251816 -0.759684  1.144916
# 6  -0.026211  1.124175 -0.357116
# 7  -1.241542  0.228909  0.326457
# 8  -0.855525  0.935596 -0.236512
# 9   0.075413  2.466761 -0.040266
# 10  0.350040  0.823486  0.731268
# 11 -0.835689  2.247876  0.284032
# 12 -0.555190  2.395734 -0.607703
# 13 -0.106062 -0.877959  0.360629
# 14 -1.201665  0.774568 -0.115420
# 15 -0.338020 -1.215517  1.094470
# 16 -0.006888  0.689264  0.727124
# 17 -0.444149 -0.041986  0.146369
# 18 -0.055220  1.180581  0.764095
# 19  0.461784 -0.598882 -0.707223

# %%
df2['a'].hist()
# Out:
# <Axes: >

# %%
df1['e'].hist(edgecolor='black',color='red',figsize=(10,10))
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
df1['e'].hist(edgecolor='black',color='red',figsize=(10,10))
# Out:
# <Axes: >

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df1['r'].plot(kind='hist',bins=20,edgecolor='black',color='red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.bar(figsize=(10,5))
# Out:
# <Axes: >

# %%
df1.plot.bar(figsize=(10,5))
# Out:
# <Axes: >
