# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'day':['1/12/2025','1/12/2025','2/12/2032'],
    'temperature':[30,40,4],
    'windspeed':[6,7,5],
    'event':['rain','sunny','cloudy']
}
df=pd.DataFrame(data)
df
# Out:
#          day  temperature  windspeed   event
# 0  1/12/2025           30          6    rain
# 1  1/12/2025           40          7   sunny
# 2  2/12/2032            4          5  cloudy

# %%
df['new']='a'
df
# Out:
#          day  temperature  windspeed   event new
# 0  1/12/2025           30          6    rain   a
# 1  1/12/2025           40          7   sunny   a
# 2  2/12/2032            4          5  cloudy   a

# %%
df['wind_percent']=df['windspeed']/df['temperature']*100
df
# Out:
#          day  temperature  windspeed   event new  wind_percent
# 0  1/12/2025           30          6    rain   a          20.0
# 1  1/12/2025           40          7   sunny   a          17.5
# 2  2/12/2032            4          5  cloudy   a         125.0
