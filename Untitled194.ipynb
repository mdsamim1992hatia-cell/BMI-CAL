# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled194.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data={
    'order_id':[1,2,3,4,5],
    'product':['pen','notebook','pen','pencil','notebook'],
    'price':[10,50,5,2,55],
    'quantity':[2,10,5,585,55],
    'customer':['alice','bob','charli','alice','nomm']
}
df=pd.DataFrame(data)
df
# Out:
#    order_id   product  price  quantity customer
# 0         1       pen     10         2    alice
# 1         2  notebook     50        10      bob
# 2         3       pen      5         5   charli
# 3         4    pencil      2       585    alice
# 4         5  notebook     55        55     nomm

# %%
df['totall']=df['price']*df['quantity']
df
# Out:
#    order_id   product  price  quantity customer  totall
# 0         1       pen     10         2    alice      20
# 1         2  notebook     50        10      bob     500
# 2         3       pen      5         5   charli      25
# 3         4    pencil      2       585    alice    1170
# 4         5  notebook     55        55     nomm    3025

# %%
df[['customer','totall']]
# Out:
#   customer  totall
# 0    alice      20
# 1      bob     500
# 2   charli      25
# 3    alice    1170
# 4     nomm    3025

# %%
df[df['customer']=='alice']
# Out:
#    order_id product  price  quantity customer  totall
# 0         1     pen     10         2    alice      20
# 3         4  pencil      2       585    alice    1170

# %%
df[df['totall']>30]
# Out:
#    order_id   product  price  quantity customer  totall
# 1         2  notebook     50        10      bob     500
# 3         4    pencil      2       585    alice    1170
# 4         5  notebook     55        55     nomm    3025

# %%
df[['customer','totall']]
# Out:
#   customer  totall
# 0    alice      20
# 1      bob     500
# 2   charli      25
# 3    alice    1170
# 4     nomm    3025

# %%
df[df['totall']>30][['customer','totall']]
# Out:
#   customer  totall
# 1      bob     500
# 3    alice    1170
# 4     nomm    3025

# %%
data1={
    'oreder':[1,2,3,4,5,6],
    'product':['pen','notebook','pen','pencil','notebook','pen'],
    'price':[22,55,858585,88,55,55],
    'quantity':[2,10,5,585,55,55],
    'customer':['alice','bob','charli','alice','nomm','bob']

}
df=pd.DataFrame(data1)
df
# Out:
#    oreder   product   price  quantity customer
# 0       1       pen      22         2    alice
# 1       2  notebook      55        10      bob
# 2       3       pen  858585         5   charli
# 3       4    pencil      88       585    alice
# 4       5  notebook      55        55     nomm
# 5       6       pen      55        55      bob

# %%
df['totall']=df['price']*df['quantity']
df
# Out:
#    oreder   product   price  quantity customer   totall
# 0       1       pen      22         2    alice       44
# 1       2  notebook      55        10      bob      550
# 2       3       pen  858585         5   charli  4292925
# 3       4    pencil      88       585    alice    51480
# 4       5  notebook      55        55     nomm     3025
# 5       6       pen      55        55      bob     3025

# %%
df[['customer','totall']]
# Out:
#   customer   totall
# 0    alice       44
# 1      bob      550
# 2   charli  4292925
# 3    alice    51480
# 4     nomm     3025
# 5      bob     3025

# %%
df[['customer','totall']]
# Out:
#   customer   totall
# 0    alice       44
# 1      bob      550
# 2   charli  4292925
# 3    alice    51480
# 4     nomm     3025
# 5      bob     3025

# %%
df['totall']=df['price']*df['quantity']
df
# Out:
#    oreder   product   price  quantity customer   totall
# 0       1       pen      22         2    alice       44
# 1       2  notebook      55        10      bob      550
# 2       3       pen  858585         5   charli  4292925
# 3       4    pencil      88       585    alice    51480
# 4       5  notebook      55        55     nomm     3025
# 5       6       pen      55        55      bob     3025

# %%
df[['customer','totall']]
# Out:
#   customer   totall
# 0    alice       44
# 1      bob      550
# 2   charli  4292925
# 3    alice    51480
# 4     nomm     3025
# 5      bob     3025

# %%
df['new toatal']=df['price']*df['quantity']
df
# Out:
#    oreder   product   price  quantity customer   totall  new toatal
# 0       1       pen      22         2    alice       44          44
# 1       2  notebook      55        10      bob      550         550
# 2       3       pen  858585         5   charli  4292925     4292925
# 3       4    pencil      88       585    alice    51480       51480
# 4       5  notebook      55        55     nomm     3025        3025
# 5       6       pen      55        55      bob     3025        3025

# %%
df[df['customer']=='alice']
# Out:
#    oreder product  price  quantity customer  totall  new toatal
# 0       1     pen     22         2    alice      44          44
# 3       4  pencil     88       585    alice   51480       51480

# %%
df[df['totall']>580]
# Out:
#    oreder   product   price  quantity customer   totall  new toatal
# 2       3       pen  858585         5   charli  4292925     4292925
# 3       4    pencil      88       585    alice    51480       51480
# 4       5  notebook      55        55     nomm     3025        3025
# 5       6       pen      55        55      bob     3025        3025

# %%
df[df['totall']>580][['customer','totall']]
# Out:
#   customer   totall
# 2   charli  4292925
# 3    alice    51480
# 4     nomm     3025
# 5      bob     3025

# %%
data3={
    'order_id':[1,2,3,4,5],
    'product':['pen','notebook','pen','pencil','notebook'],
    'price':[10,50,5,2,55],
    'quantity':[2,10,5,585,55],
    'customer':['alice','bob','charli','alice','nomm']
}
df=pd.DataFrame(data3)
df
# Out:
#    order_id   product  price  quantity customer
# 0         1       pen     10         2    alice
# 1         2  notebook     50        10      bob
# 2         3       pen      5         5   charli
# 3         4    pencil      2       585    alice
# 4         5  notebook     55        55     nomm

# %%
df['totall']=df['price']*df['quantity']
df
# Out:
#    order_id   product  price  quantity customer  totall
# 0         1       pen     10         2    alice      20
# 1         2  notebook     50        10      bob     500
# 2         3       pen      5         5   charli      25
# 3         4    pencil      2       585    alice    1170
# 4         5  notebook     55        55     nomm    3025

# %%
df[['customer','totall']]
# Out:
#   customer  totall
# 0    alice      20
# 1      bob     500
# 2   charli      25
# 3    alice    1170
# 4     nomm    3025

# %%
df[df['customer']=='bob']
# Out:
#    order_id   product  price  quantity customer  totall
# 1         2  notebook     50        10      bob     500

# %%
df[df['totall']>580]
# Out:
#    order_id   product  price  quantity customer  totall
# 3         4    pencil      2       585    alice    1170
# 4         5  notebook     55        55     nomm    3025

# %%
df[df['totall']>200][['customer','totall']]
# Out:
#   customer  totall
# 1      bob     500
# 3    alice    1170
# 4     nomm    3025

# %%
data5={
    'order_id':[1,244,3,444,5],
    'product':['pen','notebook','pen','pencil','notebook'],
    'price':[125250,50,5,2,55],
    'quantity':[2,1360,5,585,55],
    'customer':['alice','bob','charli','alice','nomm']
}
df=pd.DataFrame(data5)
df
# Out:
#    order_id   product   price  quantity customer
# 0         1       pen  125250         2    alice
# 1       244  notebook      50      1360      bob
# 2         3       pen       5         5   charli
# 3       444    pencil       2       585    alice
# 4         5  notebook      55        55     nomm

# %%
df['new']=df['price']*df['quantity' ]
df
# Out:
#    order_id   product   price  quantity customer     new
# 0         1       pen  125250         2    alice  250500
# 1       244  notebook      50      1360      bob   68000
# 2         3       pen       5         5   charli      25
# 3       444    pencil       2       585    alice    1170
# 4         5  notebook      55        55     nomm    3025

# %%
df[['customer','new']]
# Out:
#   customer     new
# 0    alice  250500
# 1      bob   68000
# 2   charli      25
# 3    alice    1170
# 4     nomm    3025

# %%
df[df['customer']=='alice']
# Out:
#    order_id product   price  quantity customer     new
# 0         1     pen  125250         2    alice  250500
# 3       444  pencil       2       585    alice    1170

# %%
df[df['price']>580]
# Out:
#    order_id product   price  quantity customer     new
# 0         1     pen  125250         2    alice  250500

# %%
df[df['new']>500][['customer','new']]
# Out:
#   customer     new
# 0    alice  250500
# 1      bob   68000
# 3    alice    1170
# 4     nomm    3025
