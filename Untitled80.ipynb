# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data={
    'a':[np.nan,20,3669,np.nan,np.nan],
    'b':[10,2660,39,np.nan,np.nan],
    'c':[10,np.nan,55,np.nan,np.nan],
    'd':[10,2000,39,np.nan,np.nan],
}
df=pd.DataFrame(data)
df
# Out:
#         a       b     c       d
# 0     NaN    10.0  10.0    10.0
# 1    20.0  2660.0   NaN  2000.0
# 2  3669.0    39.0  55.0    39.0
# 3     NaN     NaN   NaN     NaN
# 4     NaN     NaN   NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       2 non-null      float64
#  1   b       3 non-null      float64
#  2   c       2 non-null      float64
#  3   d       3 non-null      float64
# dtypes: float64(4)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#                  a            b          c            d
# count     2.000000     3.000000   2.000000     3.000000
# mean   1844.500000   903.000000  32.500000   683.000000
# std    2580.232645  1521.675721  31.819805  1140.647623
# min      20.000000    10.000000  10.000000    10.000000
# 25%     932.250000    24.500000  21.250000    24.500000
# 50%    1844.500000    39.000000  32.500000    39.000000
# 75%    2756.750000  1349.500000  43.750000  1019.500000
# max    3669.000000  2660.000000  55.000000  2000.000000

# %%
df.isnull()
# Out:
#        a      b      c      d
# 0   True  False  False  False
# 1  False  False   True  False
# 2  False  False  False  False
# 3   True   True   True   True
# 4   True   True   True   True

# %%
df.isnull().sum()
# Out:
# a    3
# b    2
# c    3
# d    2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(10)

# %%
df['a'].isna().sum()
# Out:
# np.int64(3)

# %%
df['b'].isna().sum()
# Out:
# np.int64(2)

# %%
df['c'].isnull().sum()
# Out:
# np.int64(3)

# %%
df.isna().sum().sum()
# Out:
# np.int64(10)

# %%
df['d'].mean().sum()
# Out:
# np.float64(683.0)

# %%
df['a'].isnull().sum()
# Out:
# np.int64(3)

# %%
df.notnull().sum().sum()
# Out:
# np.int64(10)

# %%
df.loc[2].mean()
# Out:
# np.float64(950.5)

# %%
df['a'].mean()
# Out:
# np.float64(1844.5)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(10)
