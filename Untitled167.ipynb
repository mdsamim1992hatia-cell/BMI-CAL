# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled167.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1=np.random.randn(500,3)
data1
# Out:
# array([[-2.0385898 , -1.46547269, -1.09247827],
#        [-0.82392014, -0.78969855, -1.03021725],
#        [ 0.70162102, -0.42345979, -0.74327983],
#        ...,
#        [-0.49292987, -0.60301502, -0.20448436],
#        [-0.2325118 , -0.1464202 ,  0.55691086],
#        [-0.27297507, -1.4615013 ,  0.71120379]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1=pd.DataFrame(data=data1,columns=['A','B','C',])
df1
# Out:
#             A         B         C
# 0   -2.038590 -1.465473 -1.092478
# 1   -0.823920 -0.789699 -1.030217
# 2    0.701621 -0.423460 -0.743280
# 3    0.597021 -0.031603 -2.188541
# 4   -1.386963  0.421677 -0.405006
# ..        ...       ...       ...
# 495  0.631138 -0.221335  0.082372
# 496 -0.078788 -1.279241  0.418787
# 497 -0.492930 -0.603015 -0.204484
# 498 -0.232512 -0.146420  0.556911
# 499 -0.272975 -1.461501  0.711204
#
# [500 rows x 3 columns]

# %%
df1['d']=np.random.rand(500)
df1
# Out:
#             A         B         C         d
# 0   -2.038590 -1.465473 -1.092478  0.626163
# 1   -0.823920 -0.789699 -1.030217  0.613814
# 2    0.701621 -0.423460 -0.743280  0.784101
# 3    0.597021 -0.031603 -2.188541  0.065081
# 4   -1.386963  0.421677 -0.405006  0.267066
# ..        ...       ...       ...       ...
# 495  0.631138 -0.221335  0.082372  0.129925
# 496 -0.078788 -1.279241  0.418787  0.443107
# 497 -0.492930 -0.603015 -0.204484  0.809195
# 498 -0.232512 -0.146420  0.556911  0.329963
# 499 -0.272975 -1.461501  0.711204  0.187203
#
# [500 rows x 4 columns]

# %%
data2=np.random.randn(20,3)
col=['X','Y','Z']
df2=pd.DataFrame(data=data2,columns=col)
df2
# Out:
#            X         Y         Z
# 0   1.204393  1.072962  0.174839
# 1  -1.458504  1.033855 -0.940937
# 2   1.046576 -0.623462  1.248338
# 3  -0.050366 -1.704782  0.588222
# 4  -0.255422 -0.544989 -2.417603
# 5   0.799004  0.592259  0.221042
# 6  -0.024318  0.637264  0.096411
# 7   0.591382  0.743684 -2.809969
# 8   0.795568 -0.264386 -0.659479
# 9  -1.571449 -0.809508  1.175770
# 10 -0.534309 -0.339177  1.113381
# 11 -0.281956 -0.294403 -0.280580
# 12  1.324617  1.619645  1.780777
# 13  0.578321 -0.640182 -0.818346
# 14  1.290935  0.462695  0.329180
# 15  1.153101 -0.692021  0.471645
# 16 -3.221614  0.803832  0.250624
# 17 -1.152872 -0.588124 -1.203937
# 18  0.919573 -0.539871  0.099033
# 19  0.892451 -0.203465  0.876659

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['B'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black',linewidth=1.2,bins=15)
# Out:
# <Axes: >

# %%
df1['B'].plot(kind='hist',bins=30,edgecolor='black',figsize=(12,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use('ggplot'),'dark_background'
df1['A'].plot(kind='hist',bins=30,edgecolor='black',figsize=(12,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2
# Out:
#            X         Y         Z
# 0   1.204393  1.072962  0.174839
# 1  -1.458504  1.033855 -0.940937
# 2   1.046576 -0.623462  1.248338
# 3  -0.050366 -1.704782  0.588222
# 4  -0.255422 -0.544989 -2.417603
# 5   0.799004  0.592259  0.221042
# 6  -0.024318  0.637264  0.096411
# 7   0.591382  0.743684 -2.809969
# 8   0.795568 -0.264386 -0.659479
# 9  -1.571449 -0.809508  1.175770
# 10 -0.534309 -0.339177  1.113381
# 11 -0.281956 -0.294403 -0.280580
# 12  1.324617  1.619645  1.780777
# 13  0.578321 -0.640182 -0.818346
# 14  1.290935  0.462695  0.329180
# 15  1.153101 -0.692021  0.471645
# 16 -3.221614  0.803832  0.250624
# 17 -1.152872 -0.588124 -1.203937
# 18  0.919573 -0.539871  0.099033
# 19  0.892451 -0.203465  0.876659

# %%
from numpy.random.mtrand import f
df2['X'].plot()
df2.plot.line(x='X',y='Y',figsize=(12,8))
# Out:
# <Axes: xlabel='X'>

# %%
df1.plot(kind='hist',bins=20,edgecolor='black',figsize=(12,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['C'].hist(bins=30)
# Out:
# <Axes: >

# %%
df1.iloc[10:20,0]=np.nan
df1
# Out:
#             A         B         C         d
# 0   -2.038590 -1.465473 -1.092478  0.626163
# 1   -0.823920 -0.789699 -1.030217  0.613814
# 2    0.701621 -0.423460 -0.743280  0.784101
# 3    0.597021 -0.031603 -2.188541  0.065081
# 4   -1.386963  0.421677 -0.405006  0.267066
# ..        ...       ...       ...       ...
# 495  0.631138 -0.221335  0.082372  0.129925
# 496 -0.078788 -1.279241  0.418787  0.443107
# 497 -0.492930 -0.603015 -0.204484  0.809195
# 498 -0.232512 -0.146420  0.556911  0.329963
# 499 -0.272975 -1.461501  0.711204  0.187203
#
# [500 rows x 4 columns]

# %%
df1=pd.concat([df1,df1.iloc[:5]])
df1
# Out:
#            A         B         C         d
# 0  -2.038590 -1.465473 -1.092478  0.626163
# 1  -0.823920 -0.789699 -1.030217  0.613814
# 2   0.701621 -0.423460 -0.743280  0.784101
# 3   0.597021 -0.031603 -2.188541  0.065081
# 4  -1.386963  0.421677 -0.405006  0.267066
# ..       ...       ...       ...       ...
# 0  -2.038590 -1.465473 -1.092478  0.626163
# 1  -0.823920 -0.789699 -1.030217  0.613814
# 2   0.701621 -0.423460 -0.743280  0.784101
# 3   0.597021 -0.031603 -2.188541  0.065081
# 4  -1.386963  0.421677 -0.405006  0.267066
#
# [505 rows x 4 columns]

# %%
plt.scatter(df1['A'],df1['B'])

# %%
df1.isnull()
# Out:
#         A      B      C      d
# 0   False  False  False  False
# 1   False  False  False  False
# 2   False  False  False  False
# 3   False  False  False  False
# 4   False  False  False  False
# ..    ...    ...    ...    ...
# 0   False  False  False  False
# 1   False  False  False  False
# 2   False  False  False  False
# 3   False  False  False  False
# 4   False  False  False  False
#
# [505 rows x 4 columns]

# %%
df2.plot.scatter(x='X',y='Y',figsize=(12,5))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X',y='Y',figsize=(12,5))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['Y'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['Z'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot(kind='hist',bins=30,figsize=(12,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['X'].plot.bar()
# Out:
# <Axes: >

# %%
df2['Y'].plot.bar(figsize=(12,8))
# Out:
# <Axes: >

# %%
df2['Z'].plot.bar(figsize=(12,8))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(12,8))
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True,figsize=(12,8))
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=False,figsize=(12,8))
# Out:
# <Axes: >

# %%
df2.plot.box(figsize=(12,8))
# Out:
# <Axes: >

# %%
df2.plot.density(figsize=(12,8))
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.barh(figsize=(12,8))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(12,8))
# Out:
# <Axes: >
