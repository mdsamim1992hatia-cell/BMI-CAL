# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled167.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1=np.random.randn(500,3)
data1
# Out:
# array([[ 0.61404663, -1.21228731, -0.41730157],
#        [-0.29242837,  0.47236791,  0.14719017],
#        [-0.891364  ,  0.48404947,  1.02472366],
#        ...,
#        [-0.6084322 ,  0.38804953,  0.03507205],
#        [-0.70891976,  1.23088292, -1.38735596],
#        [-1.50032659, -1.45244226,  0.38004266]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1=pd.DataFrame(data=data1,columns=['A','B','C',])
df1
# Out:
#             A         B         C
# 0    0.614047 -1.212287 -0.417302
# 1   -0.292428  0.472368  0.147190
# 2   -0.891364  0.484049  1.024724
# 3   -1.807324  0.333378  1.841873
# 4   -0.655626  1.147843  0.794117
# ..        ...       ...       ...
# 495  0.112804 -0.187590 -0.071218
# 496 -0.236886  0.226657  1.993307
# 497 -0.608432  0.388050  0.035072
# 498 -0.708920  1.230883 -1.387356
# 499 -1.500327 -1.452442  0.380043
#
# [500 rows x 3 columns]

# %%
df1['d']=np.random.rand(500)
df1
# Out:
#             A         B         C         d
# 0    0.614047 -1.212287 -0.417302  0.040450
# 1   -0.292428  0.472368  0.147190  0.424340
# 2   -0.891364  0.484049  1.024724  0.393203
# 3   -1.807324  0.333378  1.841873  0.503141
# 4   -0.655626  1.147843  0.794117  0.675131
# ..        ...       ...       ...       ...
# 495  0.112804 -0.187590 -0.071218  0.240281
# 496 -0.236886  0.226657  1.993307  0.371052
# 497 -0.608432  0.388050  0.035072  0.699805
# 498 -0.708920  1.230883 -1.387356  0.113984
# 499 -1.500327 -1.452442  0.380043  0.452544
#
# [500 rows x 4 columns]

# %%
data2=np.random.randn(20,3)
col=['x','y','z']
df2=pd.DataFrame(data=data2,columns=col)
df2
# Out:
#            x         y         z
# 0   0.616198 -1.898513  0.526228
# 1  -0.935788  1.236401  0.266141
# 2   0.082563 -0.906091 -1.332056
# 3  -0.571113  0.222058 -0.078677
# 4  -0.388815 -1.430712  1.057227
# 5   0.549030 -0.616610  0.277300
# 6   1.494885 -0.052800 -0.688088
# 7  -0.813482 -0.127731  0.616202
# 8   0.141575  0.577953 -0.186355
# 9   1.132905 -1.781472 -0.466305
# 10 -0.102069  0.764159  0.232886
# 11 -0.903638  1.415802  0.468295
# 12  0.355316 -0.600570  0.481847
# 13  0.190022 -0.106758 -0.199481
# 14  0.921331 -0.535138 -1.478213
# 15  0.440785 -0.059959  0.353372
# 16  0.167005  1.396151  0.748353
# 17 -0.841576  0.235420 -0.602516
# 18  0.545927 -0.601387 -1.970650
# 19 -0.600890 -0.344761 -1.092957

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['B'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black',linewidth=1.2,bins=15)
# Out:
# <Axes: >

# %%
df1['B'].plot(kind='hist',bins=30,edgecolor='black',figsize=(12,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use('ggplot'),'dark_background'
df1['A'].plot(kind='hist',bins=30,edgecolor='black',figsize=(12,8))
# Out:
# <Axes: ylabel='Frequency'>
