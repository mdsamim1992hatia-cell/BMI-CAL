# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled113.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data_dic={
    'col_1':['A','A','B','B','C',],
    'col_2':[111,222,333,111,555],
    'col_3':['alpha','bravo','cerry',np.nan,np.nan]
}
df=pd.DataFrame(data_dic)
df
# Out:
#   col_1  col_2  col_3
# 0     A    111  alpha
# 1     A    222  bravo
# 2     B    333  cerry
# 3     B    111    NaN
# 4     C    555    NaN

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df['col_1'].unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
print(df['col_1'].nunique())
print(df['col_2'].unique())
print(df['col_3'].nunique())
# Out:
# 3
# [111 222 333 555]
# 3

# %%
df.nunique()
# Out:
# col_1    3
# col_2    4
# col_3    3
# dtype: int64

# %%
print(df['col_1'].value_counts())
# Out:
# col_1
# A    2
# B    2
# C    1
# Name: count, dtype: int64

# %%
print(df['col_2'].nunique())
print(df['col_2'].nunique())
print(df['col_3'].nunique())
# Out:
# 4
# 4
# 3

# %%
df['col_1'].value_counts()
# Out:
# col_1
# A    2
# B    2
# C    1
# Name: count, dtype: int64

# %%
df['col_2'].count()
# Out:
# np.int64(5)

# %%
df['col_3'].count()
# Out:
# np.int64(3)

# %%
df.sort_values('col_2')
# Out:
#   col_1  col_2  col_3
# 0     A    111  alpha
# 3     B    111    NaN
# 1     A    222  bravo
# 2     B    333  cerry
# 4     C    555    NaN

# %%
def square(value):
    return value*value

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
newdf=df.drop('col_3',axis=1)
newdf
# Out:
#   col_1  col_2
# 0     A    111
# 1     A    222
# 2     B    333
# 3     B    111
# 4     C    555

# %%
aa=df.drop(1)
aa
# Out:
#   col_1  col_2  col_3
# 0     A    111  alpha
# 2     B    333  cerry
# 3     B    111    NaN
# 4     C    555    NaN

# %%
del aa['col_1']
aa
# Out:
#    col_2  col_3
# 0    111  alpha
# 2    333  cerry
# 3    111    NaN
# 4    555    NaN
