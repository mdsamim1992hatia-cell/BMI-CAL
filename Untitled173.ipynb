# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled173.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data1=np.random.randn(500,3)
data1
# Out:
# array([[-0.64574745,  0.28674451,  1.02467204],
#        [ 0.37013032,  0.2458734 , -0.84511055],
#        [ 1.03763616,  0.24719142, -1.5783404 ],
#        ...,
#        [-0.4778237 , -0.91631113, -2.3494681 ],
#        [ 1.01865347,  1.01886211,  2.35219627],
#        [-0.25742644,  2.28710234,  0.38703282]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1=pd.DataFrame(data1,columns=['A','B','C'])
df1
# Out:
#             A         B         C
# 0   -0.645747  0.286745  1.024672
# 1    0.370130  0.245873 -0.845111
# 2    1.037636  0.247191 -1.578340
# 3   -0.314379  0.097175 -1.366296
# 4    0.915087  1.082382  0.331391
# ..        ...       ...       ...
# 495  1.300076 -0.877139  2.783380
# 496  1.244598  1.711921  0.539267
# 497 -0.477824 -0.916311 -2.349468
# 498  1.018653  1.018862  2.352196
# 499 -0.257426  2.287102  0.387033
#
# [500 rows x 3 columns]

# %%
df1['d']=np.random.randn(500)
df1
# Out:
#             A         B         C         d
# 0   -0.645747  0.286745  1.024672  1.285868
# 1    0.370130  0.245873 -0.845111 -0.832252
# 2    1.037636  0.247191 -1.578340  2.233654
# 3   -0.314379  0.097175 -1.366296 -0.535621
# 4    0.915087  1.082382  0.331391 -0.227388
# ..        ...       ...       ...       ...
# 495  1.300076 -0.877139  2.783380 -1.354788
# 496  1.244598  1.711921  0.539267 -1.067911
# 497 -0.477824 -0.916311 -2.349468  0.025465
# 498  1.018653  1.018862  2.352196 -0.989931
# 499 -0.257426  2.287102  0.387033  1.404849
#
# [500 rows x 4 columns]

# %%
data2=np.random.randn(20,3)
col=['x','y','z']
df2=pd.DataFrame(data=data2,columns=col)
df2
# Out:
#            x         y         z
# 0  -1.858330 -0.739529 -0.116821
# 1  -0.451426 -1.275271 -0.617570
# 2  -0.910448  0.828531  0.789290
# 3  -2.327679 -0.956922 -0.260800
# 4  -1.168917  0.791777 -0.682491
# 5  -0.579354 -0.311684  0.105984
# 6   0.441395  1.485727 -0.958761
# 7  -0.209945  0.712358 -1.467143
# 8  -0.291318  1.306818  0.422388
# 9  -2.212811  1.076475  0.451339
# 10 -0.238259 -1.875650  0.325628
# 11  0.197168  0.242127 -1.056804
# 12  0.603159 -0.764717  0.678491
# 13 -1.816787 -1.299888 -0.376559
# 14  0.515030  1.687102 -1.592422
# 15  0.603799  0.506279 -0.373725
# 16 -0.724779 -0.028985 -1.997631
# 17 -1.218619 -1.129067 -0.225718
# 18  0.128375 -1.045974  0.643375
# 19 -0.750222 -0.170776  0.193728

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['B'].hist(edgecolor='black',bins=40,figsize=(10,5))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['C'].hist(edgecolor='black',bins=40,figsize=(10,5))
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30,edgecolor='black',figsize=(12,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['x'].plot()
# Out:
# <Axes: >

# %%
from numpy.random.mtrand import f
df2['y'].plot.line(x='x',y='y',figsize=(12,5))
# Out:
# <Axes: >

# %%
df1.plot(kind='hist',bins=30,edgecolor='black',figsize=(12,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.scatter(x='x',y='z',figsize=(12,5))
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
df2.plot.line(x='x',y='z',figsize=(12,5))
# Out:
# <Axes: xlabel='x'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['z'].plot(kind='hist',bins=30,edgecolor='black',figsize=(12,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['x'].plot.bar(figsize=(12,5))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(12,5))
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df2.plot.bar(figsize=(12,5))
# Out:
# <Axes: >
