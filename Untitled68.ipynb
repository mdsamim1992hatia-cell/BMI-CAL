# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled68.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'Name':['1/12/2025','2/12/2025','2/11/2026'],
    'Age':[12,13,14],
    'Sex':['M','F','M'],
    'Salary':[10000,20000,30000],
    'City':['Pune','Mumbai','Delhi'],
}
df=pd.DataFrame(data)
df
# Out:
#         Name  Age Sex  Salary    City
# 0  1/12/2025   12   M   10000    Pune
# 1  2/12/2025   13   F   20000  Mumbai
# 2  2/11/2026   14   M   30000   Delhi

# %%
df['new']='ass'
df
# Out:
#         Name  Age Sex  Salary    City  new
# 0  1/12/2025   12   M   10000    Pune  ass
# 1  2/12/2025   13   F   20000  Mumbai  ass
# 2  2/11/2026   14   M   30000   Delhi  ass

# %%
df['new-3']='a'
df
# Out:
#         Name  Age Sex  Salary    City  new new-3
# 0  1/12/2025   12   M   10000    Pune  ass     a
# 1  2/12/2025   13   F   20000  Mumbai  ass     a
# 2  2/11/2026   14   M   30000   Delhi  ass     a

# %%
df['new_4']='real'
df
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4
# 0  1/12/2025   12   M   10000    Pune  ass     a  real
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real

# %%
df['new_5']='am well'
df
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well

# %%
df['test']=np.nan
df
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5  test
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well   NaN
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well   NaN
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well   NaN

# %%
df.isna().sum()
# Out:
# Name      0
# Age       0
# Sex       0
# Salary    0
# City      0
# new       0
# new-3     0
# new_4     0
# new_5     0
# test      3
# dtype: int64

# %%
df.isna().any()
# Out:
# Name      False
# Age       False
# Sex       False
# Salary    False
# City      False
# new       False
# new-3     False
# new_4     False
# new_5     False
# test       True
# dtype: bool

# %%
def totall_nan(df):
    return df.isna().sum().sum()
totall_nan(df)
# Out:
# np.int64(3)

# %%
df_fill=df.fillna(1)
df_fill
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5  test
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well   1.0
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well   1.0
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well   1.0

# %%
bf_fill=df.bfill()
bf_fill
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5  test
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well   NaN
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well   NaN
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well   NaN

# %%
df_zero=df.fillna(0)
df_zero
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5  test
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well   0.0
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well   0.0
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well   0.0

# %%
df.head(2)
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5  test
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well   NaN
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well   NaN

# %%
df.tail(3)
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5  test
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well   NaN
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well   NaN
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well   NaN

# %%
df.describe()
# Out:
#         Age   Salary  test
# count   3.0      3.0   0.0
# mean   13.0  20000.0   NaN
# std     1.0  10000.0   NaN
# min    12.0  10000.0   NaN
# 25%    12.5  15000.0   NaN
# 50%    13.0  20000.0   NaN
# 75%    13.5  25000.0   NaN
# max    14.0  30000.0   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Sex     3 non-null      object
#  3   Salary  3 non-null      int64
#  4   City    3 non-null      object
#  5   new     3 non-null      object
#  6   new-3   3 non-null      object
#  7   new_4   3 non-null      object
#  8   new_5   3 non-null      object
#  9   test    0 non-null      float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 372.0+ bytes

# %%
df.mean
df
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5  test
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well   NaN
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well   NaN
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well   NaN

# %%
df.drop('test',axis=1)
# Out:
#         Name  Age Sex  Salary    City  new new-3 new_4    new_5
# 0  1/12/2025   12   M   10000    Pune  ass     a  real  am well
# 1  2/12/2025   13   F   20000  Mumbai  ass     a  real  am well
# 2  2/11/2026   14   M   30000   Delhi  ass     a  real  am well
