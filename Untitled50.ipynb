# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
climate_data={
    'day':['1/5/2025','1/6/2025','1/5/2032'],
    'temperature':[32,35,43],
    'windspeed':[6,7,2] ,
    'event' :['rain','sunny','snow']
}
df=pd.DataFrame(climate_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/5/2025           32          6   rain
# 1  1/6/2025           35          7  sunny
# 2  1/5/2032           43          2   snow

# %%
climate_data=[
    ('1/5/2025',32,6,'rain'),
    ('1/6/2025',35,5,'sunny'),
    ('2/6/2023',22,55,'cloudy'),

]
df=pd.DataFrame(climate_data,columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed   event
# 0  1/5/2025           32          6    rain
# 1  1/6/2025           35          5   sunny
# 2  2/6/2023           22         55  cloudy

# %%
climate_data=[
    {'day':'1/2/2025','temperature':32,'windspeed':6,'event':'rain'},
    {'day':'1/2/2025','temperature':32,'windspeed':6,'event':'rain'},
    {'day':'1/2/2025','temperature':32,'windspeed':6,'event':'rain'},



]
df=pd.DataFrame(climate_data)
df
# Out:
#         day  temperature  windspeed event
# 0  1/2/2025           32          6  rain
# 1  1/2/2025           32          6  rain
# 2  1/2/2025           32          6  rain
