# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled299.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#

# %%
data={
    'Name':['Alice','Bob','Claire'],
    'Age':[25,30,27],
    'Gender':['Female','Male','Female'],
    'Salary':[50000,60000,55000],
    'customer':['MW','WE',None],
    'product':['a','v',None],
    'QUANTITY':[3232,656,555,],


}
df=pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender  Salary customer product  QUANTITY
# 0   Alice   25  Female   50000       MW       a      3232
# 1     Bob   30    Male   60000       WE       v       656
# 2  Claire   27  Female   55000     None    None       555

# %%
df.isna()
# Out:
#     Name    Age  Gender  Salary  customer  product  QUANTITY
# 0  False  False   False   False     False    False     False
# 1  False  False   False   False     False    False     False
# 2  False  False   False   False      True     True     False

# %%
df.isna().sum().sum()
# Out:
# np.int64(2)

# %%
df.notna().sum()
# Out:
# Name        3
# Age         3
# Gender      3
# Salary      3
# customer    2
# product     2
# QUANTITY    3
# dtype: int64

# %%
df['customer'].fillna('unknown',inplace=True),
df['product'].fillna('unknown',inplace=True),
print(df)
# Out:
#      Name  Age  Gender  Salary customer  product  QUANTITY
# 0   Alice   25  Female   50000       MW        a      3232
# 1     Bob   30    Male   60000       WE        v       656
# 2  Claire   27  Female   55000  unknown  unknown       555

# %%
df.loc[2]
# Out:
# Name         Claire
# Age              27
# Gender       Female
# Salary        55000
# customer    unknown
# product     unknown
# QUANTITY        555
# Name: 2, dtype: object

# %%
df.iloc[2:4]
# Out:
#      Name  Age  Gender  Salary customer  product  QUANTITY
# 2  Claire   27  Female   55000  unknown  unknown       555

# %%
df['total_sales']=df['QUANTITY']*df['Salary']
df
# Out:
#      Name  Age  Gender  Salary customer  product  QUANTITY  total_sales
# 0   Alice   25  Female   50000       MW        a      3232    161600000
# 1     Bob   30    Male   60000       WE        v       656     39360000
# 2  Claire   27  Female   55000  unknown  unknown       555     30525000

# %%
total_revenue=df['total_sales'].sum()
total_revenue
# Out:
# np.int64(231485000)

# %%
customer_sales=df.groupby('customer')['total_sales'].sum()
customer_sales
# Out:
# customer
# MW         161600000
# WE          39360000
# unknown     30525000
# Name: total_sales, dtype: int64
