# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsamim1992hatia-cell/BMI-CAL/blob/main/Untitled160.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data1=np.random.rand(500,3)
data1
# Out:
# array([[0.10690483, 0.41663947, 0.97030378],
#        [0.55272087, 0.6026107 , 0.21371094],
#        [0.86513623, 0.69745073, 0.53882133],
#        ...,
#        [0.45415308, 0.75903557, 0.21587021],
#        [0.39717654, 0.70901438, 0.79606615],
#        [0.28855785, 0.06217817, 0.56835398]])

# %%
df1=pd.DataFrame(data1,columns=['A','B','C'])
df1
# Out:
#             A         B         C
# 0    0.106905  0.416639  0.970304
# 1    0.552721  0.602611  0.213711
# 2    0.865136  0.697451  0.538821
# 3    0.326515  0.857066  0.641519
# 4    0.987227  0.073354  0.539521
# ..        ...       ...       ...
# 495  0.706592  0.193668  0.817377
# 496  0.727411  0.855323  0.857782
# 497  0.454153  0.759036  0.215870
# 498  0.397177  0.709014  0.796066
# 499  0.288558  0.062178  0.568354
#
# [500 rows x 3 columns]

# %%
df1['d']=np.random.rand(500)
df1
# Out:
#             A         B         C         d
# 0    0.106905  0.416639  0.970304  0.711579
# 1    0.552721  0.602611  0.213711  0.061402
# 2    0.865136  0.697451  0.538821  0.120038
# 3    0.326515  0.857066  0.641519  0.217485
# 4    0.987227  0.073354  0.539521  0.799576
# ..        ...       ...       ...       ...
# 495  0.706592  0.193668  0.817377  0.016659
# 496  0.727411  0.855323  0.857782  0.684602
# 497  0.454153  0.759036  0.215870  0.042988
# 498  0.397177  0.709014  0.796066  0.698025
# 499  0.288558  0.062178  0.568354  0.286443
#
# [500 rows x 4 columns]

# %%
data2=np.random.rand(20,3)
data2
# Out:
# array([[0.05753836, 0.99863845, 0.63816507],
#        [0.3993833 , 0.91740583, 0.12600442],
#        [0.69592542, 0.58485343, 0.99889974],
#        [0.71249538, 0.98541629, 0.51033429],
#        [0.20638233, 0.98891222, 0.83189607],
#        [0.63779684, 0.44797585, 0.26806249],
#        [0.62450677, 0.90118882, 0.65969776],
#        [0.22419534, 0.1478588 , 0.52261146],
#        [0.06645173, 0.53009332, 0.24284546],
#        [0.37966739, 0.72047945, 0.93539792],
#        [0.32827264, 0.56901649, 0.42970838],
#        [0.24770193, 0.96065022, 0.6213653 ],
#        [0.68996535, 0.87620252, 0.65417625],
#        [0.74887504, 0.6867741 , 0.65509409],
#        [0.29367288, 0.25725806, 0.60471607],
#        [0.11983642, 0.4330144 , 0.63298802],
#        [0.39243956, 0.33115648, 0.5658677 ],
#        [0.43927385, 0.2515981 , 0.81273232],
#        [0.5052647 , 0.10089663, 0.49624405],
#        [0.76329147, 0.13121111, 0.10256471]])

# %%
col=['x','y','z']
df2=pd.DataFrame(data2,columns=col)
df2
# Out:
#            x         y         z
# 0   0.057538  0.998638  0.638165
# 1   0.399383  0.917406  0.126004
# 2   0.695925  0.584853  0.998900
# 3   0.712495  0.985416  0.510334
# 4   0.206382  0.988912  0.831896
# 5   0.637797  0.447976  0.268062
# 6   0.624507  0.901189  0.659698
# 7   0.224195  0.147859  0.522611
# 8   0.066452  0.530093  0.242845
# 9   0.379667  0.720479  0.935398
# 10  0.328273  0.569016  0.429708
# 11  0.247702  0.960650  0.621365
# 12  0.689965  0.876203  0.654176
# 13  0.748875  0.686774  0.655094
# 14  0.293673  0.257258  0.604716
# 15  0.119836  0.433014  0.632988
# 16  0.392440  0.331156  0.565868
# 17  0.439274  0.251598  0.812732
# 18  0.505265  0.100897  0.496244
# 19  0.763291  0.131211  0.102565

# %%
df1['A'].hist(edgecolor='black',bins=30)
# Out:
# <Axes: >

# %%
df1['B'].plot(kind='hist',bins=50,edgecolor='black',figsize=(12,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')
df1['B'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df1['B'].plot(kind='hist',bins=25,)
# Out:
# <Axes: ylabel='Frequency'>
